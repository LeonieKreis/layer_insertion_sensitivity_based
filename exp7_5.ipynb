# %% [markdown]
# ## Notebook for running single training and compare them

# %% [markdown]
# Imports and set seed optionally:

# %%
import torch
import random
import copy
import numpy as np
import matplotlib.pyplot as plt
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor


from layer_insertion_loop import layer_insertion_loop
from train_and_test_ import train, check_testerror
from nets import feed_forward, two_weight_resnet, one_weight_resnet
from utils import ema

h=3
random.seed(h)
np.random.seed(h)
torch.manual_seed(h)

torch.set_num_threads(8)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# Define and list hyperparameters:

# %%
no_hidden_layers_start = 2
fix_width = [100,50]
no_iters = 1
lr_decrease_after_li =0.8
epochs = [80,80]
wanted_testerror = 2.
_type = 'fwd'
act_fun = nn.ReLU
interval_testerror = 1

batch_size = 60000 #1000 #20 #200 # 60000 for full batch
save_grad_norms = True

lr_init = 1e-0
optimizer_type = 'SGD'
lrscheduler_type = 'StepLR'
lrscheduler_args = {'step_size': 40,
                    'gamma': 0.1}


# for classical 
epochs_classical = sum(epochs)
lr_init_classical = lr_init
lrscheduler_args_classical = {'step_size': 40,
                    'gamma': 0.1}

# %% [markdown]
# Load dataset:

# %%
MNIST = True
FMNIST = False
CIFAR10 = False

# %%
if MNIST:    
    # Download training data from open datasets.
    training_data = datasets.MNIST(
        root="data",
        train=True,
        download=True,
        transform=ToTensor(),
    )

    # Download test data from open datasets.
    test_data = datasets.MNIST(
        root="data",
        train=False,
        download=True,
        transform=ToTensor(),
    )

    tr_split_len = 60000#10000
    te_split_len = 10000#int(0.33*tr_split_len)
    training_data = torch.utils.data.random_split(training_data, [tr_split_len, len(training_data)-tr_split_len])[0]
    test_data = torch.utils.data.random_split(test_data, [te_split_len, len(test_data)-te_split_len])[0]

if FMNIST:
    # Download training data from open datasets.
    training_data = datasets.FashionMNIST(
        root="data",
        train=True,
        download=True,
        transform=ToTensor(),
    )

    # Download test data from open datasets.
    test_data = datasets.FashionMNIST(
        root="data",
        train=False,
        download=True,
        transform=ToTensor(),
    )

if CIFAR10:
    # Download training data from open datasets.
    training_data = datasets.CIFAR10(
        root="data",
        train=True,
        download=True,
        transform=ToTensor(),
    )

    # Download test data from open datasets.
    test_data = datasets.CIFAR10(
        root="data",
        train=False,
        download=True,
        transform=ToTensor(),
    )

# %%
print('no of iterations in one epoch:',int(len(training_data)/batch_size))
print(len(training_data))
print(len(test_data))
# Out:
# no of iterations in one epoch: 1
# 60000
# 10000

# %% [markdown]
# Create dataloader:

# %%
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=10000)

# %% [markdown]
# Build models:

# %%
kwargs_net ={
        'hidden_layers': no_hidden_layers_start,
        'dim_hidden_layers': fix_width,
        'act_fun': act_fun,
        'type': _type
}

dim_in = 28*28 #32*32 
dim_out = 10

# %%
# classical net
kwargs_net_classical = {
    'hidden_layers': 2,
    'dim_hidden_layers': [100,50],#fix_width,
    'act_fun': act_fun,
    'type': _type
}

# %% [markdown]
# Determine which trainings are run:

# %%
T1 = True
T2 = False
T3 = True

# %% [markdown]
# ## Training with layer insertion:

# %%
# build model
if _type=='fwd':
    model_init = feed_forward(dim_in, dim_out,**kwargs_net)
if _type=='res2':
    model_init = two_weight_resnet(dim_in, dim_out,**kwargs_net)
if _type=='res1':
    model_init = one_weight_resnet(dim_in, dim_out,**kwargs_net)

param_init = torch.nn.utils.parameters_to_vector(model_init.parameters())
param_init = copy.deepcopy(param_init.data)
param_init_class = copy.deepcopy(param_init.data)

# %% [markdown]
# Check initial test error of the model

# %%
print(check_testerror(test_dataloader,model_init))
initial_train_acc = check_testerror(train_dataloader,model_init)
print(check_testerror(train_dataloader,model_init))
# Out:
# 92.74
# 92.8

# %%
# train ali 1
if T1:
    model1, mb_losses1, test_errors_short1, test_errors1, exit_flag1, grad_norms1 = layer_insertion_loop(
        iters=no_iters,
        epochs=epochs,
        model= model_init,
        kwargs_net=kwargs_net,
        dim_in=dim_in,
        dim_out=dim_out,
        train_dataloader=train_dataloader,
        test_dataloader=test_dataloader,
        lr_init=lr_init,
        wanted_test_error=wanted_testerror,
        mode='abs max',
        optimizer_type=optimizer_type,
        lrschedule_type=lrscheduler_type,
        lrscheduler_args=lrscheduler_args,
        check_testerror_between=interval_testerror,
        decrease_after_li=lr_decrease_after_li,
        print_param_flag=False,
        start_with_backtracking=None,
        v2=False,
        save_grad_norms=save_grad_norms
    )
# Out:
# starting on 1. net !
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=100, out_features=50, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=50, out_features=10, bias=True)
# )
# mbloss:  2.3037943840026855
# (dataset)error at epoch 0 is 80.41
# mbloss:  2.279895305633545
# (dataset)error at epoch 1 is 70.32
# mbloss:  2.250500440597534
# (dataset)error at epoch 2 is 59.86
# mbloss:  2.2061901092529297
# (dataset)error at epoch 3 is 62.24
# mbloss:  2.1397385597229004
# (dataset)error at epoch 4 is 50.16
# mbloss:  2.039174795150757
# (dataset)error at epoch 5 is 61.99
# mbloss:  1.9197931289672852
# (dataset)error at epoch 6 is 77.56
# mbloss:  2.0683624744415283
# (dataset)error at epoch 7 is 82.41
# mbloss:  2.172621250152588
# (dataset)error at epoch 8 is 70.29
# mbloss:  2.074023485183716
# (dataset)error at epoch 9 is 55.42
# mbloss:  1.8130537271499634
# (dataset)error at epoch 10 is 53.239999999999995
# mbloss:  1.5955747365951538
# (dataset)error at epoch 11 is 74.28
# mbloss:  2.6975626945495605
# (dataset)error at epoch 12 is 89.31
# mbloss:  3.4697673320770264
# (dataset)error at epoch 13 is 89.7
# mbloss:  4.359946250915527
# (dataset)error at epoch 14 is 79.17
# mbloss:  2.3093371391296387
# (dataset)error at epoch 15 is 78.46000000000001
# mbloss:  2.234362840652466
# (dataset)error at epoch 16 is 76.64
# mbloss:  2.130237102508545
# (dataset)error at epoch 17 is 68.21
# mbloss:  1.9531596899032593
# (dataset)error at epoch 18 is 72.22
# mbloss:  1.8962196111679077
# (dataset)error at epoch 19 is 65.72999999999999
# mbloss:  2.2061214447021484
# (dataset)error at epoch 20 is 67.59
# mbloss:  1.9912941455841064
# (dataset)error at epoch 21 is 78.7
# mbloss:  2.278669595718384
# (dataset)error at epoch 22 is 63.03
# mbloss:  1.8390659093856812
# (dataset)error at epoch 23 is 69.2
# mbloss:  1.8550536632537842
# (dataset)error at epoch 24 is 65.78999999999999
# mbloss:  1.8582754135131836
# (dataset)error at epoch 25 is 51.46
# mbloss:  1.6380044221878052
# (dataset)error at epoch 26 is 44.489999999999995
# mbloss:  1.5351834297180176
# (dataset)error at epoch 27 is 60.730000000000004
# mbloss:  1.9471824169158936
# (dataset)error at epoch 28 is 71.56
# mbloss:  2.0817296504974365
# (dataset)error at epoch 29 is 80.89
# mbloss:  2.3950064182281494
# (dataset)error at epoch 30 is 76.35
# mbloss:  2.234523057937622
# (dataset)error at epoch 31 is 73.13
# mbloss:  2.108212471008301
# (dataset)error at epoch 32 is 73.14
# mbloss:  1.9459329843521118
# (dataset)error at epoch 33 is 69.42
# mbloss:  1.8131985664367676
# (dataset)error at epoch 34 is 70.37
# mbloss:  1.7158141136169434
# (dataset)error at epoch 35 is 54.77
# mbloss:  1.672446846961975
# (dataset)error at epoch 36 is 69.64
# mbloss:  1.7880338430404663
# (dataset)error at epoch 37 is 66.53999999999999
# mbloss:  2.156437397003174
# (dataset)error at epoch 38 is 69.36
# mbloss:  1.9407122135162354
# (dataset)error at epoch 39 is 58.15
# mbloss:  1.7689627408981323
# (dataset)error at epoch 40 is 58.68
# mbloss:  1.7438136339187622
# (dataset)error at epoch 41 is 59.089999999999996
# mbloss:  1.721611738204956
# (dataset)error at epoch 42 is 59.58
# mbloss:  1.7023825645446777
# (dataset)error at epoch 43 is 59.94
# mbloss:  1.685888409614563
# (dataset)error at epoch 44 is 60.120000000000005
# mbloss:  1.6714966297149658
# (dataset)error at epoch 45 is 60.29
# mbloss:  1.658676028251648
# (dataset)error at epoch 46 is 60.24
# mbloss:  1.6469624042510986
# (dataset)error at epoch 47 is 60.199999999999996
# mbloss:  1.636016607284546
# (dataset)error at epoch 48 is 60.120000000000005
# mbloss:  1.6255699396133423
# (dataset)error at epoch 49 is 59.97
# mbloss:  1.615419864654541
# (dataset)error at epoch 50 is 59.77
# mbloss:  1.6054235696792603
# (dataset)error at epoch 51 is 59.63
# mbloss:  1.5954561233520508
# (dataset)error at epoch 52 is 59.52
# mbloss:  1.5854133367538452
# (dataset)error at epoch 53 is 59.260000000000005
# mbloss:  1.5752177238464355
# (dataset)error at epoch 54 is 58.94
# mbloss:  1.5647876262664795
# (dataset)error at epoch 55 is 58.68
# mbloss:  1.5540872812271118
# (dataset)error at epoch 56 is 58.23
# mbloss:  1.543057918548584
# (dataset)error at epoch 57 is 57.769999999999996
# mbloss:  1.531633973121643
# (dataset)error at epoch 58 is 57.29
# mbloss:  1.5197806358337402
# (dataset)error at epoch 59 is 56.78
# mbloss:  1.5074479579925537
# (dataset)error at epoch 60 is 55.89
# mbloss:  1.4946273565292358
# (dataset)error at epoch 61 is 55.09
# mbloss:  1.481324553489685
# (dataset)error at epoch 62 is 54.339999999999996
# mbloss:  1.4675190448760986
# (dataset)error at epoch 63 is 53.47
# mbloss:  1.4532066583633423
# (dataset)error at epoch 64 is 52.489999999999995
# mbloss:  1.4384077787399292
# (dataset)error at epoch 65 is 51.56
# mbloss:  1.423150897026062
# (dataset)error at epoch 66 is 50.75
# mbloss:  1.407440423965454
# (dataset)error at epoch 67 is 49.39
# mbloss:  1.3913196325302124
# (dataset)error at epoch 68 is 48.160000000000004
# mbloss:  1.3748234510421753
# (dataset)error at epoch 69 is 47.040000000000006
# mbloss:  1.3579999208450317
# (dataset)error at epoch 70 is 46.14
# mbloss:  1.3408843278884888
# (dataset)error at epoch 71 is 45.199999999999996
# mbloss:  1.3235549926757812
# (dataset)error at epoch 72 is 44.279999999999994
# mbloss:  1.3060851097106934
# (dataset)error at epoch 73 is 43.60000000000001
# mbloss:  1.2885675430297852
# (dataset)error at epoch 74 is 42.879999999999995
# mbloss:  1.2710952758789062
# (dataset)error at epoch 75 is 42.15
# mbloss:  1.2537630796432495
# (dataset)error at epoch 76 is 41.37
# mbloss:  1.2366620302200317
# (dataset)error at epoch 77 is 40.66
# mbloss:  1.2199087142944336
# (dataset)error at epoch 78 is 39.949999999999996
# mbloss:  1.2035974264144897
# (dataset)error at epoch 79 is 39.0
# Test error after first step of loop 1 is 39.0!
# Insert layer at position 1 !
# starting on 2. net!
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=100, out_features=50, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=50, out_features=50, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=50, out_features=10, bias=True)
# )
# mbloss:  1.1877877712249756
# (dataset)error at epoch 0 is 38.89
# mbloss:  1.1863664388656616
# (dataset)error at epoch 1 is 38.81
# mbloss:  1.184753179550171
# (dataset)error at epoch 2 is 38.63999999999999
# mbloss:  1.1830744743347168
# (dataset)error at epoch 3 is 38.55
# mbloss:  1.1814160346984863
# (dataset)error at epoch 4 is 38.46000000000001
# mbloss:  1.1797621250152588
# (dataset)error at epoch 5 is 38.41
# mbloss:  1.1780924797058105
# (dataset)error at epoch 6 is 38.3
# mbloss:  1.1764352321624756
# (dataset)error at epoch 7 is 38.18
# mbloss:  1.17476224899292
# (dataset)error at epoch 8 is 38.1
# mbloss:  1.1731164455413818
# (dataset)error at epoch 9 is 38.05
# mbloss:  1.1714905500411987
# (dataset)error at epoch 10 is 38.0
# mbloss:  1.1698707342147827
# (dataset)error at epoch 11 is 37.96000000000001
# mbloss:  1.168259859085083
# (dataset)error at epoch 12 is 37.86000000000001
# mbloss:  1.1666558980941772
# (dataset)error at epoch 13 is 37.82
# mbloss:  1.1650593280792236
# (dataset)error at epoch 14 is 37.81
# mbloss:  1.1634706258773804
# (dataset)error at epoch 15 is 37.739999999999995
# mbloss:  1.161888837814331
# (dataset)error at epoch 16 is 37.64999999999999
# mbloss:  1.1603138446807861
# (dataset)error at epoch 17 is 37.57
# mbloss:  1.1587460041046143
# (dataset)error at epoch 18 is 37.51
# mbloss:  1.1571853160858154
# (dataset)error at epoch 19 is 37.45
# mbloss:  1.1556317806243896
# (dataset)error at epoch 20 is 37.419999999999995
# mbloss:  1.1540850400924683
# (dataset)error at epoch 21 is 37.339999999999996
# mbloss:  1.1525450944900513
# (dataset)error at epoch 22 is 37.239999999999995
# mbloss:  1.15101158618927
# (dataset)error at epoch 23 is 37.17
# mbloss:  1.1494849920272827
# (dataset)error at epoch 24 is 37.12
# mbloss:  1.1479647159576416
# (dataset)error at epoch 25 is 37.09
# mbloss:  1.1464508771896362
# (dataset)error at epoch 26 is 37.0
# mbloss:  1.1449435949325562
# (dataset)error at epoch 27 is 36.9
# mbloss:  1.143442988395691
# (dataset)error at epoch 28 is 36.809999999999995
# mbloss:  1.141948938369751
# (dataset)error at epoch 29 is 36.71
# mbloss:  1.1404615640640259
# (dataset)error at epoch 30 is 36.67
# mbloss:  1.1389801502227783
# (dataset)error at epoch 31 is 36.6
# mbloss:  1.1375051736831665
# (dataset)error at epoch 32 is 36.58
# mbloss:  1.1360366344451904
# (dataset)error at epoch 33 is 36.519999999999996
# mbloss:  1.1345739364624023
# (dataset)error at epoch 34 is 36.46
# mbloss:  1.1331181526184082
# (dataset)error at epoch 35 is 36.44
# mbloss:  1.1316689252853394
# (dataset)error at epoch 36 is 36.339999999999996
# mbloss:  1.130225658416748
# (dataset)error at epoch 37 is 36.260000000000005
# mbloss:  1.1287888288497925
# (dataset)error at epoch 38 is 36.160000000000004
# mbloss:  1.1273581981658936
# (dataset)error at epoch 39 is 36.11
# mbloss:  1.1259338855743408
# (dataset)error at epoch 40 is 36.12
# mbloss:  1.1257919073104858
# (dataset)error at epoch 41 is 36.1
# mbloss:  1.1256500482559204
# (dataset)error at epoch 42 is 36.11
# mbloss:  1.125508189201355
# (dataset)error at epoch 43 is 36.11
# mbloss:  1.125366449356079
# (dataset)error at epoch 44 is 36.08
# mbloss:  1.1252249479293823
# (dataset)error at epoch 45 is 36.09
# mbloss:  1.125083088874817
# (dataset)error at epoch 46 is 36.09
# mbloss:  1.1249417066574097
# (dataset)error at epoch 47 is 36.09
# mbloss:  1.1248000860214233
# (dataset)error at epoch 48 is 36.09
# mbloss:  1.1246587038040161
# (dataset)error at epoch 49 is 36.07
# mbloss:  1.1245173215866089
# (dataset)error at epoch 50 is 36.07
# mbloss:  1.1243760585784912
# (dataset)error at epoch 51 is 36.06
# mbloss:  1.124234914779663
# (dataset)error at epoch 52 is 36.06
# mbloss:  1.1240938901901245
# (dataset)error at epoch 53 is 36.06
# mbloss:  1.1239527463912964
# (dataset)error at epoch 54 is 36.06
# mbloss:  1.1238116025924683
# (dataset)error at epoch 55 is 36.050000000000004
# mbloss:  1.1236706972122192
# (dataset)error at epoch 56 is 36.029999999999994
# mbloss:  1.1235297918319702
# (dataset)error at epoch 57 is 36.01
# mbloss:  1.1233892440795898
# (dataset)error at epoch 58 is 36.0
# mbloss:  1.1232482194900513
# (dataset)error at epoch 59 is 36.0
# mbloss:  1.123107671737671
# (dataset)error at epoch 60 is 35.980000000000004
# mbloss:  1.1229667663574219
# (dataset)error at epoch 61 is 35.980000000000004
# mbloss:  1.1228264570236206
# (dataset)error at epoch 62 is 35.980000000000004
# mbloss:  1.1226857900619507
# (dataset)error at epoch 63 is 35.97
# mbloss:  1.1225451231002808
# (dataset)error at epoch 64 is 35.96000000000001
# mbloss:  1.122404932975769
# (dataset)error at epoch 65 is 35.96000000000001
# mbloss:  1.1222646236419678
# (dataset)error at epoch 66 is 35.96000000000001
# mbloss:  1.122124195098877
# (dataset)error at epoch 67 is 35.94000000000001
# mbloss:  1.1219840049743652
# (dataset)error at epoch 68 is 35.95
# mbloss:  1.121843695640564
# (dataset)error at epoch 69 is 35.95
# mbloss:  1.1217036247253418
# (dataset)error at epoch 70 is 35.95
# mbloss:  1.1215636730194092
# (dataset)error at epoch 71 is 35.95
# mbloss:  1.1214237213134766
# (dataset)error at epoch 72 is 35.95
# mbloss:  1.1212836503982544
# (dataset)error at epoch 73 is 35.95
# mbloss:  1.1211439371109009
# (dataset)error at epoch 74 is 35.95
# mbloss:  1.1210039854049683
# (dataset)error at epoch 75 is 35.94000000000001
# mbloss:  1.1208642721176147
# (dataset)error at epoch 76 is 35.900000000000006
# mbloss:  1.1207245588302612
# (dataset)error at epoch 77 is 35.89
# mbloss:  1.1205852031707764
# (dataset)error at epoch 78 is 35.89
# mbloss:  1.1204456090927124
# (dataset)error at epoch 79 is 35.89
# Test error of loop 2 is 35.89!
# The final model has the architecture: Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=100, out_features=50, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=50, out_features=50, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=50, out_features=10, bias=True)
# )

# %%
print('test error: ',check_testerror(test_dataloader, model1))
train_acc = check_testerror(train_dataloader, model1)
print('train error: ',train_acc)
# Out:
# test error:  35.89
# train error:  36.27666666666667

# %% [markdown]
# plot results:

# %%
end_list=[]
for i,e in enumerate(epochs):
    end_list.append(int(e*len(training_data)/batch_size))
    end_list.append(1) 
end_list.pop() # removes last 1 which was too much

# todo plot
if T1:
    plt.figure(figsize=(20,5))
    plt.grid(which='major', axis='x', zorder=-1.0)
    xfull = range(1,len(mb_losses1)+1)
    yfull = mb_losses1
    begin=0
    end=0
    for i in range(len(end_list)):
        end=end+end_list[i]
        x_curr= xfull[begin:end]
        y_curr= yfull[begin:end]
        begin=end
        plt.plot(x_curr,y_curr,'o')
    plt.xlabel('minibatch iterations')
    plt.ylabel('minibatch loss')

    plt.yscale('log')
    #plt.ylim((0.4,.6))
    #plt.xlim((99300,99800))
    
    plt.grid()
    plt.plot(np.zeros(len(mb_losses1)))

# %%
# todo plot
if T1:
    plt.figure(figsize=(20,5))
    plt.grid(which='major', axis='x', zorder=-1.0)
    xfull = range(1,len(grad_norms1)+1)
    yfull = grad_norms1
    begin=0
    end=0
    for i in range(len(end_list)):
        end=end+end_list[i]
        x_curr= xfull[begin:end]
        y_curr= yfull[begin:end]
        begin=end
        plt.plot(x_curr,y_curr,'o')
    plt.xlabel('minibatch iterations')
    plt.ylabel('squared grad norm')

    plt.yscale('log')
    #plt.ylim((0.4,.6))
    #plt.xlim((99300,99800))
    
    plt.grid()
    plt.plot(np.zeros(len(grad_norms1)))

# %%
plt.figure(figsize=(20,5))
plt.plot([initial_train_acc]+test_errors1)#,'o')
plt.ylim(top=100,bottom=0)
plt.grid()
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# ## Second training

# %%
# build net
if _type=='fwd':
    model_init2 = feed_forward(dim_in, dim_out,**kwargs_net)
if _type=='res2':
    model_init2 = two_weight_resnet(dim_in, dim_out,**kwargs_net)
if _type=='res1':
    model_init2 = one_weight_resnet(dim_in, dim_out,**kwargs_net)

torch.nn.utils.vector_to_parameters(param_init, model_init2.parameters())

# %%
print(check_testerror(test_dataloader,model_init2))
initial_train_acc2 = check_testerror(train_dataloader,model_init2)
print(check_testerror(train_dataloader,model_init2))
# Out:
# 92.74
# 92.8

# %%
if T2:
    model2, mb_losses2, test_errors_short2, test_errors2, exit_flag2, grad_norms2 = layer_insertion_loop(
        iters=no_iters,
        epochs=epochs,
        model= model_init2,
        kwargs_net=kwargs_net,
        dim_in=dim_in,
        dim_out=dim_out,
        train_dataloader=train_dataloader,
        test_dataloader=test_dataloader,
        lr_init=lr_init,
        wanted_test_error=wanted_testerror,
        mode='abs min',#'threshold',
        optimizer_type=optimizer_type,
        lrschedule_type=lrscheduler_type,
        lrscheduler_args=lrscheduler_args,
        check_testerror_between=interval_testerror,
        decrease_after_li=lr_decrease_after_li,
        print_param_flag=False,
        start_with_backtracking=None,
        v2=False,
        save_grad_norms=save_grad_norms
    )

# %%
if T2:
    print('test error: ',check_testerror(test_dataloader, model2))
    print('train error: ',check_testerror(train_dataloader, model2))

# %% [markdown]
# plot results:

# %%
# todo plot
if T2:
    plt.figure(figsize=(20,5))
    plt.grid(which='major', axis='x', zorder=-1.0)
    xfull = range(1,len(mb_losses2)+1)
    yfull = mb_losses2
    begin=0
    end=0
    for i in range(len(end_list)):
        end=end+end_list[i]
        x_curr= xfull[begin:end]
        y_curr= yfull[begin:end]
        begin=end
        plt.plot(x_curr,y_curr,'o')
    plt.xlabel('minibatch iterations')
    plt.ylabel('minibatch loss')

    plt.yscale('log')
    #plt.ylim((0.4,.6))
    #plt.xlim((99300,99800))
    
    plt.grid()
    plt.plot(np.zeros(len(mb_losses2)))

# %%
# todo plot
if T2:
    plt.figure(figsize=(20,5))
    plt.grid(which='major', axis='x', zorder=-1.0)
    xfull = range(1,len(grad_norms2)+1)
    yfull = grad_norms2
    begin=0
    end=0
    for i in range(len(end_list)):
        end=end+end_list[i]
        x_curr= xfull[begin:end]
        y_curr= yfull[begin:end]
        begin=end
        plt.plot(x_curr,y_curr,'o')
    plt.xlabel('minibatch iterations')
    plt.ylabel('squared grad norm')

    plt.yscale('log')
    #plt.ylim((0.4,.6))
    #plt.xlim((99300,99800))
    
    plt.grid()
    plt.plot(np.zeros(len(grad_norms2)))

# %%
if T2:
    plt.figure(figsize=(20,5))
    #plt.ylim((0,100))
    plt.plot([initial_train_acc2]+test_errors2,'o')
    plt.ylim(bottom=0)
    plt.grid()

# %% [markdown]
# ## Third training

# %%
# build model
if _type=='fwd':
    model_classical = feed_forward(dim_in, dim_out,**kwargs_net_classical)
if _type=='res2':
    model_classical = two_weight_resnet(dim_in, dim_out,**kwargs_net_classical)
if _type=='res1':
    model_classical = one_weight_resnet(dim_in, dim_out,**kwargs_net_classical)

torch.nn.utils.vector_to_parameters(param_init_class,model_classical.parameters())

# %%
print('test error: ',check_testerror(test_dataloader, model_classical))
print('train error: ',check_testerror(train_dataloader, model_classical))
initial_train_acc_class = check_testerror(train_dataloader, model_classical)
# Out:
# test error:  92.74
# train error:  92.8

# %%
# build optimizer
if optimizer_type == 'SGD':
    optimizer_classical = torch.optim.SGD(model_classical.parameters(), lr_init_classical)
if optimizer_type == 'Adam':
    optimizer_classical = torch.optim.Adam(model_classical.parameters(), lr_init_classical)

# build lr scheduler
if lrscheduler_type == 'StepLR':
    step_size = lrscheduler_args_classical['step_size']
    gamma = lrscheduler_args_classical['gamma']
    lrscheduler_classical = torch.optim.lr_scheduler.StepLR(
            optimizer_classical, step_size=step_size, gamma=gamma)

# %%
if T3:
    print('training classically on model', model_classical)
    mblosses_classical, lr_end, test_error_classical, exit_flag_classical, grad_norms_classical = train(model_classical,
                                                             train_dataloader=train_dataloader,
                                                             epochs=epochs_classical,
                                                             optimizer=optimizer_classical,
                                                             scheduler=lrscheduler_classical,
                                                             wanted_testerror=wanted_testerror,
                                                             start_with_backtracking=None,
                                                             check_testerror_between=interval_testerror,
                                                             test_dataloader=test_dataloader,
                                                             print_param_flag=False,
                                                             save_grad_norms=save_grad_norms
                                                             )
# Out:
# training classically on model Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=100, out_features=50, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=50, out_features=10, bias=True)
# )
# mbloss:  2.3037943840026855
# (dataset)error at epoch 0 is 80.41
# mbloss:  2.279895305633545
# (dataset)error at epoch 1 is 70.32
# mbloss:  2.250500440597534
# (dataset)error at epoch 2 is 59.86
# mbloss:  2.2061901092529297
# (dataset)error at epoch 3 is 62.24
# mbloss:  2.1397385597229004
# (dataset)error at epoch 4 is 50.16
# mbloss:  2.039174795150757
# (dataset)error at epoch 5 is 61.99
# mbloss:  1.9197931289672852
# (dataset)error at epoch 6 is 77.56
# mbloss:  2.0683624744415283
# (dataset)error at epoch 7 is 82.41
# mbloss:  2.172621250152588
# (dataset)error at epoch 8 is 70.29
# mbloss:  2.074023485183716
# (dataset)error at epoch 9 is 55.42
# mbloss:  1.8130537271499634
# (dataset)error at epoch 10 is 53.239999999999995
# mbloss:  1.5955747365951538
# (dataset)error at epoch 11 is 74.28
# mbloss:  2.6975626945495605
# (dataset)error at epoch 12 is 89.31
# mbloss:  3.4697673320770264
# (dataset)error at epoch 13 is 89.7
# mbloss:  4.359946250915527
# (dataset)error at epoch 14 is 79.17
# mbloss:  2.3093371391296387
# (dataset)error at epoch 15 is 78.46000000000001
# mbloss:  2.234362840652466
# (dataset)error at epoch 16 is 76.64
# mbloss:  2.130237102508545
# (dataset)error at epoch 17 is 68.21
# mbloss:  1.9531596899032593
# (dataset)error at epoch 18 is 72.22
# mbloss:  1.8962196111679077
# (dataset)error at epoch 19 is 65.72999999999999
# mbloss:  2.2061214447021484
# (dataset)error at epoch 20 is 67.59
# mbloss:  1.9912941455841064
# (dataset)error at epoch 21 is 78.7
# mbloss:  2.278669595718384
# (dataset)error at epoch 22 is 63.03
# mbloss:  1.8390659093856812
# (dataset)error at epoch 23 is 69.2
# mbloss:  1.8550536632537842
# (dataset)error at epoch 24 is 65.78999999999999
# mbloss:  1.8582754135131836
# (dataset)error at epoch 25 is 51.46
# mbloss:  1.6380044221878052
# (dataset)error at epoch 26 is 44.489999999999995
# mbloss:  1.5351834297180176
# (dataset)error at epoch 27 is 60.730000000000004
# mbloss:  1.9471824169158936
# (dataset)error at epoch 28 is 71.56
# mbloss:  2.0817296504974365
# (dataset)error at epoch 29 is 80.89
# mbloss:  2.3950064182281494
# (dataset)error at epoch 30 is 76.35
# mbloss:  2.234523057937622
# (dataset)error at epoch 31 is 73.13
# mbloss:  2.108212471008301
# (dataset)error at epoch 32 is 73.14
# mbloss:  1.9459329843521118
# (dataset)error at epoch 33 is 69.42
# mbloss:  1.8131985664367676
# (dataset)error at epoch 34 is 70.37
# mbloss:  1.7158141136169434
# (dataset)error at epoch 35 is 54.77
# mbloss:  1.672446846961975
# (dataset)error at epoch 36 is 69.64
# mbloss:  1.7880338430404663
# (dataset)error at epoch 37 is 66.53999999999999
# mbloss:  2.156437397003174
# (dataset)error at epoch 38 is 69.36
# mbloss:  1.9407122135162354
# (dataset)error at epoch 39 is 58.15
# mbloss:  1.7689627408981323
# (dataset)error at epoch 40 is 58.68
# mbloss:  1.7438136339187622
# (dataset)error at epoch 41 is 59.089999999999996
# mbloss:  1.721611738204956
# (dataset)error at epoch 42 is 59.58
# mbloss:  1.7023825645446777
# (dataset)error at epoch 43 is 59.94
# mbloss:  1.685888409614563
# (dataset)error at epoch 44 is 60.120000000000005
# mbloss:  1.6714966297149658
# (dataset)error at epoch 45 is 60.29
# mbloss:  1.658676028251648
# (dataset)error at epoch 46 is 60.24
# mbloss:  1.6469624042510986
# (dataset)error at epoch 47 is 60.199999999999996
# mbloss:  1.636016607284546
# (dataset)error at epoch 48 is 60.120000000000005
# mbloss:  1.6255699396133423
# (dataset)error at epoch 49 is 59.97
# mbloss:  1.615419864654541
# (dataset)error at epoch 50 is 59.77
# mbloss:  1.6054235696792603
# (dataset)error at epoch 51 is 59.63
# mbloss:  1.5954561233520508
# (dataset)error at epoch 52 is 59.52
# mbloss:  1.5854133367538452
# (dataset)error at epoch 53 is 59.260000000000005
# mbloss:  1.5752177238464355
# (dataset)error at epoch 54 is 58.94
# mbloss:  1.5647876262664795
# (dataset)error at epoch 55 is 58.68
# mbloss:  1.5540872812271118
# (dataset)error at epoch 56 is 58.23
# mbloss:  1.543057918548584
# (dataset)error at epoch 57 is 57.769999999999996
# mbloss:  1.531633973121643
# (dataset)error at epoch 58 is 57.29
# mbloss:  1.5197806358337402
# (dataset)error at epoch 59 is 56.78
# mbloss:  1.5074479579925537
# (dataset)error at epoch 60 is 55.89
# mbloss:  1.4946273565292358
# (dataset)error at epoch 61 is 55.09
# mbloss:  1.481324553489685
# (dataset)error at epoch 62 is 54.339999999999996
# mbloss:  1.4675190448760986
# (dataset)error at epoch 63 is 53.47
# mbloss:  1.4532066583633423
# (dataset)error at epoch 64 is 52.489999999999995
# mbloss:  1.4384077787399292
# (dataset)error at epoch 65 is 51.56
# mbloss:  1.423150897026062
# (dataset)error at epoch 66 is 50.75
# mbloss:  1.407440423965454
# (dataset)error at epoch 67 is 49.39
# mbloss:  1.3913196325302124
# (dataset)error at epoch 68 is 48.160000000000004
# mbloss:  1.3748234510421753
# (dataset)error at epoch 69 is 47.040000000000006
# mbloss:  1.3579999208450317
# (dataset)error at epoch 70 is 46.14
# mbloss:  1.3408843278884888
# (dataset)error at epoch 71 is 45.199999999999996
# mbloss:  1.3235549926757812
# (dataset)error at epoch 72 is 44.279999999999994
# mbloss:  1.3060851097106934
# (dataset)error at epoch 73 is 43.60000000000001
# mbloss:  1.2885675430297852
# (dataset)error at epoch 74 is 42.879999999999995
# mbloss:  1.2710952758789062
# (dataset)error at epoch 75 is 42.15
# mbloss:  1.2537630796432495
# (dataset)error at epoch 76 is 41.37
# mbloss:  1.2366620302200317
# (dataset)error at epoch 77 is 40.66
# mbloss:  1.2199087142944336
# (dataset)error at epoch 78 is 39.949999999999996
# mbloss:  1.2035974264144897
# (dataset)error at epoch 79 is 39.0
# mbloss:  1.1877877712249756
# (dataset)error at epoch 80 is 38.89
# mbloss:  1.186249017715454
# (dataset)error at epoch 81 is 38.82
# mbloss:  1.1847152709960938
# (dataset)error at epoch 82 is 38.71
# mbloss:  1.1831873655319214
# (dataset)error at epoch 83 is 38.629999999999995
# mbloss:  1.181665062904358
# (dataset)error at epoch 84 is 38.56
# mbloss:  1.1801484823226929
# (dataset)error at epoch 85 is 38.470000000000006
# mbloss:  1.178637146949768
# (dataset)error at epoch 86 is 38.38
# mbloss:  1.1771314144134521
# (dataset)error at epoch 87 is 38.32
# mbloss:  1.1756312847137451
# (dataset)error at epoch 88 is 38.29
# mbloss:  1.1741364002227783
# (dataset)error at epoch 89 is 38.2
# mbloss:  1.1726479530334473
# (dataset)error at epoch 90 is 38.1
# mbloss:  1.171164870262146
# (dataset)error at epoch 91 is 38.05
# mbloss:  1.169688105583191
# (dataset)error at epoch 92 is 37.99
# mbloss:  1.1682173013687134
# (dataset)error at epoch 93 is 37.93
# mbloss:  1.1667518615722656
# (dataset)error at epoch 94 is 37.83
# mbloss:  1.1652920246124268
# (dataset)error at epoch 95 is 37.74999999999999
# mbloss:  1.1638383865356445
# (dataset)error at epoch 96 is 37.660000000000004
# mbloss:  1.1623907089233398
# (dataset)error at epoch 97 is 37.580000000000005
# mbloss:  1.160948395729065
# (dataset)error at epoch 98 is 37.53999999999999
# mbloss:  1.1595115661621094
# (dataset)error at epoch 99 is 37.480000000000004
# mbloss:  1.158079743385315
# (dataset)error at epoch 100 is 37.370000000000005
# mbloss:  1.1566537618637085
# (dataset)error at epoch 101 is 37.27
# mbloss:  1.155233383178711
# (dataset)error at epoch 102 is 37.239999999999995
# mbloss:  1.153818964958191
# (dataset)error at epoch 103 is 37.22
# mbloss:  1.1524101495742798
# (dataset)error at epoch 104 is 37.17
# mbloss:  1.151006817817688
# (dataset)error at epoch 105 is 37.07
# mbloss:  1.1496086120605469
# (dataset)error at epoch 106 is 36.980000000000004
# mbloss:  1.148215889930725
# (dataset)error at epoch 107 is 36.919999999999995
# mbloss:  1.1468288898468018
# (dataset)error at epoch 108 is 36.870000000000005
# mbloss:  1.1454468965530396
# (dataset)error at epoch 109 is 36.83
# mbloss:  1.1440702676773071
# (dataset)error at epoch 110 is 36.77
# mbloss:  1.1426997184753418
# (dataset)error at epoch 111 is 36.73
# mbloss:  1.1413346529006958
# (dataset)error at epoch 112 is 36.69
# mbloss:  1.1399755477905273
# (dataset)error at epoch 113 is 36.650000000000006
# mbloss:  1.1386224031448364
# (dataset)error at epoch 114 is 36.62
# mbloss:  1.1372747421264648
# (dataset)error at epoch 115 is 36.529999999999994
# mbloss:  1.1359328031539917
# (dataset)error at epoch 116 is 36.47
# mbloss:  1.1345958709716797
# (dataset)error at epoch 117 is 36.41
# mbloss:  1.1332645416259766
# (dataset)error at epoch 118 is 36.41
# mbloss:  1.1319386959075928
# (dataset)error at epoch 119 is 36.309999999999995
# mbloss:  1.1306178569793701
# (dataset)error at epoch 120 is 36.3
# mbloss:  1.130486249923706
# (dataset)error at epoch 121 is 36.29
# mbloss:  1.1303545236587524
# (dataset)error at epoch 122 is 36.3
# mbloss:  1.1302229166030884
# (dataset)error at epoch 123 is 36.3
# mbloss:  1.1300915479660034
# (dataset)error at epoch 124 is 36.3
# mbloss:  1.129960060119629
# (dataset)error at epoch 125 is 36.3
# mbloss:  1.129828691482544
# (dataset)error at epoch 126 is 36.309999999999995
# mbloss:  1.129697322845459
# (dataset)error at epoch 127 is 36.309999999999995
# mbloss:  1.1295660734176636
# (dataset)error at epoch 128 is 36.3
# mbloss:  1.1294348239898682
# (dataset)error at epoch 129 is 36.3
# mbloss:  1.1293035745620728
# (dataset)error at epoch 130 is 36.3
# mbloss:  1.129172444343567
# (dataset)error at epoch 131 is 36.3
# mbloss:  1.1290415525436401
# (dataset)error at epoch 132 is 36.309999999999995
# mbloss:  1.1289104223251343
# (dataset)error at epoch 133 is 36.309999999999995
# mbloss:  1.128779411315918
# (dataset)error at epoch 134 is 36.309999999999995
# mbloss:  1.1286484003067017
# (dataset)error at epoch 135 is 36.3
# mbloss:  1.128517746925354
# (dataset)error at epoch 136 is 36.3
# mbloss:  1.1283868551254272
# (dataset)error at epoch 137 is 36.28
# mbloss:  1.128255844116211
# (dataset)error at epoch 138 is 36.27
# mbloss:  1.1281253099441528
# (dataset)error at epoch 139 is 36.260000000000005
# mbloss:  1.1279945373535156
# (dataset)error at epoch 140 is 36.260000000000005
# mbloss:  1.1278640031814575
# (dataset)error at epoch 141 is 36.25000000000001
# mbloss:  1.1277333498001099
# (dataset)error at epoch 142 is 36.260000000000005
# mbloss:  1.1276028156280518
# (dataset)error at epoch 143 is 36.24000000000001
# mbloss:  1.1274725198745728
# (dataset)error at epoch 144 is 36.23
# mbloss:  1.1273421049118042
# (dataset)error at epoch 145 is 36.22
# mbloss:  1.1272116899490356
# (dataset)error at epoch 146 is 36.22
# mbloss:  1.1270813941955566
# (dataset)error at epoch 147 is 36.199999999999996
# mbloss:  1.1269512176513672
# (dataset)error at epoch 148 is 36.21
# mbloss:  1.1268210411071777
# (dataset)error at epoch 149 is 36.22
# mbloss:  1.1266908645629883
# (dataset)error at epoch 150 is 36.199999999999996
# mbloss:  1.126560926437378
# (dataset)error at epoch 151 is 36.199999999999996
# mbloss:  1.1264309883117676
# (dataset)error at epoch 152 is 36.19
# mbloss:  1.1263009309768677
# (dataset)error at epoch 153 is 36.18
# mbloss:  1.1261709928512573
# (dataset)error at epoch 154 is 36.18
# mbloss:  1.126041054725647
# (dataset)error at epoch 155 is 36.18
# mbloss:  1.1259113550186157
# (dataset)error at epoch 156 is 36.160000000000004
# mbloss:  1.125781774520874
# (dataset)error at epoch 157 is 36.150000000000006
# mbloss:  1.1256519556045532
# (dataset)error at epoch 158 is 36.14000000000001
# mbloss:  1.1255221366882324
# (dataset)error at epoch 159 is 36.12

# %% [markdown]
# plot results:

# %%
if T3:
    print('test error: ',check_testerror(test_dataloader, model_classical))
    print('train error: ',check_testerror(train_dataloader, model_classical))
# Out:
# test error:  36.12
# train error:  36.53333333333333

# %%
if T3:
    plt.figure(figsize=(20,5))
    plt.plot(mblosses_classical,'o')
    plt.yscale('log')
    
    #plt.xlim((-10,3000))
    #plt.ylim((0.68,0.8))

# %%
if T3:
    plt.figure(figsize=(20,5))
    plt.plot(grad_norms_classical,'o')
    plt.yscale('log')

# %%
if T3:
    plt.figure(figsize=(20,5))
    plt.plot([initial_train_acc_class]+test_error_classical,'o')
    plt.ylim(bottom=0)
    plt.grid()

# %% [markdown]
# ## Comparison of the trainings as plot:

# %%
plt.figure(figsize=(20,5))

#if T2:
#    plt.plot(np.zeros(max(len(mb_losses1),len(mb_losses2))))#,len(mblosses_classical))))
if T3:
    plt.plot(mblosses_classical, label='classical coarse')
if T2:
    plt.plot(mb_losses2, label='ali min')
plt.plot(mb_losses1,label='ali max')

plt.yscale('log')

plt.legend()
#plt.ylim((1e-8,1.1))
#plt.xlim((80,100))
plt.show()

# %%
smooth_factor = 0.95
s1= ema(mb_losses1, smooth_factor)
if T2:
    s2= ema(mb_losses2, smooth_factor)
if T3:
    s3 = ema(mblosses_classical, smooth_factor)

# %%
plt.figure(figsize=(20,5))
if T2:
    plt.plot(np.zeros(max(len(s1),len(s2))))#,len(s3))))

if T2:
    plt.plot(s2, label='ali min')
plt.plot(s1,label='ali max')
if T3:
    plt.plot(s3, label='classical coarse')
plt.yscale('log')

plt.legend()
#plt.ylim((1e-8,1.1))
#plt.xlim((99800,102000))
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.plot(test_errors1,'o',label='absmax')
if T2:
    plt.plot(test_errors2,'o', label='absmin')
if T3:
    plt.plot(test_error_classical,'o',label='comparison')
plt.grid()
plt.ylim(bottom=0)
plt.legend()
