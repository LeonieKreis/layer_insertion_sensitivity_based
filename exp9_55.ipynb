# %% [markdown]
# ## Notebook for running single training and compare them

# %% [markdown]
# Imports and set seed optionally:

# %%
import torch
import random
import copy
import numpy as np
import matplotlib.pyplot as plt
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor


from layer_insertion_loop import layer_insertion_loop
from train_and_test_ import train, check_testerror
from nets import feed_forward, two_weight_resnet, one_weight_resnet
from utils import ema
from activation_functions import TanhLU_shifted


h = random.randint(0,100)
print(h)
random.seed(h)
np.random.seed(h)
torch.manual_seed(h)

torch.set_num_threads(8)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# Define and list hyperparameters:

# %%
no_hidden_layers_start = 2
fix_width = [100,50]
no_iters = 1
lr_decrease_after_li =0.8
epochs = [50,70]
wanted_testerror = 2.
_type = 'fwd'
act_fun = TanhLU_shifted
interval_testerror = 1

batch_size = 60000 #1000 #20 #200 # 60000 for full batch
save_grad_norms = True

lr_init = 1e-0
optimizer_type = 'SGD'
lrscheduler_type = 'StepLR'
lrscheduler_args = {'step_size': 40,
                    'gamma': 0.1}


# for classical 
epochs_classical = sum(epochs)
lr_init_classical = lr_init
lrscheduler_args_classical = {'step_size': 40,
                    'gamma': 0.1}

# %% [markdown]
# Load dataset:

# %%
MNIST = True
FMNIST = False
CIFAR10 = False

# %%
if MNIST:    
    # Download training data from open datasets.
    training_data = datasets.MNIST(
        root="data",
        train=True,
        download=True,
        transform=ToTensor(),
    )

    # Download test data from open datasets.
    test_data = datasets.MNIST(
        root="data",
        train=False,
        download=True,
        transform=ToTensor(),
    )

    tr_split_len = 60000#10000
    te_split_len = 10000#int(0.33*tr_split_len)
    training_data = torch.utils.data.random_split(training_data, [tr_split_len, len(training_data)-tr_split_len])[0]
    test_data = torch.utils.data.random_split(test_data, [te_split_len, len(test_data)-te_split_len])[0]

if FMNIST:
    # Download training data from open datasets.
    training_data = datasets.FashionMNIST(
        root="data",
        train=True,
        download=True,
        transform=ToTensor(),
    )

    # Download test data from open datasets.
    test_data = datasets.FashionMNIST(
        root="data",
        train=False,
        download=True,
        transform=ToTensor(),
    )

if CIFAR10:
    # Download training data from open datasets.
    training_data = datasets.CIFAR10(
        root="data",
        train=True,
        download=True,
        transform=ToTensor(),
    )

    # Download test data from open datasets.
    test_data = datasets.CIFAR10(
        root="data",
        train=False,
        download=True,
        transform=ToTensor(),
    )

# %%
print('no of iterations in one epoch:',int(len(training_data)/batch_size))
print(len(training_data))
print(len(test_data))
# Out:
# no of iterations in one epoch: 1
# 60000
# 10000

# %% [markdown]
# Create dataloader:

# %%
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=10000)

# %% [markdown]
# Build models:

# %%
kwargs_net ={
        'hidden_layers': no_hidden_layers_start,
        'dim_hidden_layers': fix_width,
        'act_fun': act_fun,
        'type': _type
}

dim_in = 28*28 #32*32 
dim_out = 10

# %%
# classical net
kwargs_net_classical = {
    'hidden_layers': 2,
    'dim_hidden_layers': [100,50],#fix_width,
    'act_fun': act_fun,
    'type': _type
}

# %% [markdown]
# Determine which trainings are run:

# %%
T1 = True
T2 = True
T3 = False

# %% [markdown]
# ## Training with layer insertion:

# %%
# build model
if _type=='fwd':
    model_init = feed_forward(dim_in, dim_out,**kwargs_net)
if _type=='res2':
    model_init = two_weight_resnet(dim_in, dim_out,**kwargs_net)
if _type=='res1':
    model_init = one_weight_resnet(dim_in, dim_out,**kwargs_net)

param_init = torch.nn.utils.parameters_to_vector(model_init.parameters())
param_init = copy.deepcopy(param_init.data)
param_init_class = copy.deepcopy(param_init.data)

# %% [markdown]
# Check initial test error of the model

# %%
print(check_testerror(test_dataloader,model_init))
initial_train_acc = check_testerror(train_dataloader,model_init)
print(check_testerror(train_dataloader,model_init))
# Out:
# 92.01
# 92.055

# %%
# train ali 1
if T1:
    model1, mb_losses1, test_errors_short1, test_errors1, exit_flag1, grad_norms1 = layer_insertion_loop(
        iters=no_iters,
        epochs=epochs,
        model= model_init,
        kwargs_net=kwargs_net,
        dim_in=dim_in,
        dim_out=dim_out,
        train_dataloader=train_dataloader,
        test_dataloader=test_dataloader,
        lr_init=lr_init,
        wanted_test_error=wanted_testerror,
        mode='abs max',
        optimizer_type=optimizer_type,
        lrschedule_type=lrscheduler_type,
        lrscheduler_args=lrscheduler_args,
        check_testerror_between=interval_testerror,
        decrease_after_li=lr_decrease_after_li,
        print_param_flag=False,
        start_with_backtracking=None,
        v2=False,
        save_grad_norms=save_grad_norms
    )
# Out:
# starting on 1. net !
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): TanhLU_shifted()
#   (3): Linear(in_features=100, out_features=50, bias=True)
#   (4): TanhLU_shifted()
#   (5): Linear(in_features=50, out_features=10, bias=True)
# )
# mbloss:  2.3102364540100098
# (dataset)error at epoch 0 is 88.39
# mbloss:  2.2862839698791504
# (dataset)error at epoch 1 is 78.94
# mbloss:  2.2576422691345215
# (dataset)error at epoch 2 is 61.84
# mbloss:  2.213818073272705
# (dataset)error at epoch 3 is 52.52
# mbloss:  2.146496295928955
# (dataset)error at epoch 4 is 47.84
# mbloss:  2.042055606842041
# (dataset)error at epoch 5 is 52.22
# mbloss:  1.887965440750122
# (dataset)error at epoch 6 is 51.18
# mbloss:  1.7531884908676147
# (dataset)error at epoch 7 is 89.8
# mbloss:  3.246375322341919
# (dataset)error at epoch 8 is 77.35
# mbloss:  2.421201705932617
# (dataset)error at epoch 9 is 89.7
# mbloss:  2.561560869216919
# (dataset)error at epoch 10 is 74.75999999999999
# mbloss:  2.2724480628967285
# (dataset)error at epoch 11 is 67.82
# mbloss:  2.1935606002807617
# (dataset)error at epoch 12 is 56.45
# mbloss:  2.0809075832366943
# (dataset)error at epoch 13 is 55.79
# mbloss:  1.931295394897461
# (dataset)error at epoch 14 is 56.25
# mbloss:  1.8086251020431519
# (dataset)error at epoch 15 is 74.73
# mbloss:  2.232314348220825
# (dataset)error at epoch 16 is 83.78
# mbloss:  2.168522834777832
# (dataset)error at epoch 17 is 86.1
# mbloss:  2.5607845783233643
# (dataset)error at epoch 18 is 81.46000000000001
# mbloss:  2.271956443786621
# (dataset)error at epoch 19 is 73.94
# mbloss:  2.1658687591552734
# (dataset)error at epoch 20 is 74.12
# mbloss:  1.967061161994934
# (dataset)error at epoch 21 is 60.61
# mbloss:  1.8026766777038574
# (dataset)error at epoch 22 is 69.15
# mbloss:  2.0698907375335693
# (dataset)error at epoch 23 is 62.51
# mbloss:  1.9220629930496216
# (dataset)error at epoch 24 is 68.1
# mbloss:  1.9597147703170776
# (dataset)error at epoch 25 is 53.839999999999996
# mbloss:  1.6620278358459473
# (dataset)error at epoch 26 is 45.14
# mbloss:  1.550961971282959
# (dataset)error at epoch 27 is 54.25
# mbloss:  1.6997103691101074
# (dataset)error at epoch 28 is 63.54
# mbloss:  1.840597152709961
# (dataset)error at epoch 29 is 48.85
# mbloss:  1.5799667835235596
# (dataset)error at epoch 30 is 50.519999999999996
# mbloss:  1.4198939800262451
# (dataset)error at epoch 31 is 53.83
# mbloss:  1.5979118347167969
# (dataset)error at epoch 32 is 57.62
# mbloss:  1.9379589557647705
# (dataset)error at epoch 33 is 67.09
# mbloss:  2.162787675857544
# (dataset)error at epoch 34 is 72.93
# mbloss:  1.932254672050476
# (dataset)error at epoch 35 is 45.48
# mbloss:  1.5825164318084717
# (dataset)error at epoch 36 is 40.87
# mbloss:  1.2098093032836914
# (dataset)error at epoch 37 is 35.83
# mbloss:  1.0192253589630127
# (dataset)error at epoch 38 is 41.690000000000005
# mbloss:  1.0578105449676514
# (dataset)error at epoch 39 is 53.1
# mbloss:  1.7596746683120728
# (dataset)error at epoch 40 is 43.68
# mbloss:  1.3398089408874512
# (dataset)error at epoch 41 is 40.55
# mbloss:  1.2168163061141968
# (dataset)error at epoch 42 is 38.519999999999996
# mbloss:  1.145142674446106
# (dataset)error at epoch 43 is 37.01
# mbloss:  1.0933945178985596
# (dataset)error at epoch 44 is 35.72999999999999
# mbloss:  1.0521596670150757
# (dataset)error at epoch 45 is 34.150000000000006
# mbloss:  1.0172773599624634
# (dataset)error at epoch 46 is 32.28
# mbloss:  0.9865060448646545
# (dataset)error at epoch 47 is 30.30000000000001
# mbloss:  0.9584373235702515
# (dataset)error at epoch 48 is 28.64
# mbloss:  0.9320395588874817
# (dataset)error at epoch 49 is 27.75
# Test error after first step of loop 1 is 27.75!
# the averaged shadow prices  of all available positions: [tensor(9.3677e-06), tensor(3.7094e-05)]
# Insert layer at position 1 !
# starting on 2. net!
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): TanhLU_shifted()
#   (3): Linear(in_features=100, out_features=50, bias=True)
#   (4): TanhLU_shifted()
#   (5): Linear(in_features=50, out_features=50, bias=True)
#   (6): TanhLU_shifted()
#   (7): Linear(in_features=50, out_features=10, bias=True)
# )
# mbloss:  0.905219316482544
# (dataset)error at epoch 0 is 26.86
# mbloss:  0.8787378668785095
# (dataset)error at epoch 1 is 26.14
# mbloss:  0.8550968766212463
# (dataset)error at epoch 2 is 25.599999999999994
# mbloss:  0.8328383564949036
# (dataset)error at epoch 3 is 24.799999999999997
# mbloss:  0.811809778213501
# (dataset)error at epoch 4 is 24.22999999999999
# mbloss:  0.7919989824295044
# (dataset)error at epoch 5 is 23.58
# mbloss:  0.7735204696655273
# (dataset)error at epoch 6 is 23.0
# mbloss:  0.7564972043037415
# (dataset)error at epoch 7 is 22.379999999999995
# mbloss:  0.7409893870353699
# (dataset)error at epoch 8 is 21.960000000000008
# mbloss:  0.7269759178161621
# (dataset)error at epoch 9 is 21.61999999999999
# mbloss:  0.7143966555595398
# (dataset)error at epoch 10 is 21.269999999999996
# mbloss:  0.7031354308128357
# (dataset)error at epoch 11 is 20.92
# mbloss:  0.6930629014968872
# (dataset)error at epoch 12 is 20.63000000000001
# mbloss:  0.684036374092102
# (dataset)error at epoch 13 is 20.299999999999997
# mbloss:  0.6759060621261597
# (dataset)error at epoch 14 is 20.0
# mbloss:  0.6685490608215332
# (dataset)error at epoch 15 is 19.74000000000001
# mbloss:  0.6618639230728149
# (dataset)error at epoch 16 is 19.650000000000006
# mbloss:  0.6557371616363525
# (dataset)error at epoch 17 is 19.590000000000003
# mbloss:  0.650072455406189
# (dataset)error at epoch 18 is 19.430000000000007
# mbloss:  0.6448063850402832
# (dataset)error at epoch 19 is 19.310000000000002
# mbloss:  0.6398786306381226
# (dataset)error at epoch 20 is 19.14
# mbloss:  0.6352391242980957
# (dataset)error at epoch 21 is 19.08
# mbloss:  0.630852222442627
# (dataset)error at epoch 22 is 18.97999999999999
# mbloss:  0.6266870498657227
# (dataset)error at epoch 23 is 18.89999999999999
# mbloss:  0.6227143406867981
# (dataset)error at epoch 24 is 18.789999999999992
# mbloss:  0.6189122796058655
# (dataset)error at epoch 25 is 18.739999999999995
# mbloss:  0.61525958776474
# (dataset)error at epoch 26 is 18.540000000000006
# mbloss:  0.6117439270019531
# (dataset)error at epoch 27 is 18.39
# mbloss:  0.6083551645278931
# (dataset)error at epoch 28 is 18.239999999999995
# mbloss:  0.6050832271575928
# (dataset)error at epoch 29 is 18.120000000000005
# mbloss:  0.6019154787063599
# (dataset)error at epoch 30 is 18.049999999999997
# mbloss:  0.5988422632217407
# (dataset)error at epoch 31 is 17.97
# mbloss:  0.5958552956581116
# (dataset)error at epoch 32 is 17.909999999999997
# mbloss:  0.5929500460624695
# (dataset)error at epoch 33 is 17.810000000000002
# mbloss:  0.590119481086731
# (dataset)error at epoch 34 is 17.679999999999993
# mbloss:  0.5873587727546692
# (dataset)error at epoch 35 is 17.61
# mbloss:  0.5846623182296753
# (dataset)error at epoch 36 is 17.540000000000006
# mbloss:  0.5820258259773254
# (dataset)error at epoch 37 is 17.47
# mbloss:  0.5794464349746704
# (dataset)error at epoch 38 is 17.36999999999999
# mbloss:  0.5769200325012207
# (dataset)error at epoch 39 is 17.320000000000007
# mbloss:  0.5744435787200928
# (dataset)error at epoch 40 is 17.310000000000002
# mbloss:  0.5741994976997375
# (dataset)error at epoch 41 is 17.30000000000001
# mbloss:  0.5739560127258301
# (dataset)error at epoch 42 is 17.30000000000001
# mbloss:  0.5737128853797913
# (dataset)error at epoch 43 is 17.290000000000006
# mbloss:  0.5734702348709106
# (dataset)error at epoch 44 is 17.269999999999996
# mbloss:  0.5732280611991882
# (dataset)error at epoch 45 is 17.25999999999999
# mbloss:  0.5729862451553345
# (dataset)error at epoch 46 is 17.210000000000008
# mbloss:  0.5727448463439941
# (dataset)error at epoch 47 is 17.190000000000012
# mbloss:  0.5725040435791016
# (dataset)error at epoch 48 is 17.190000000000012
# mbloss:  0.5722636580467224
# (dataset)error at epoch 49 is 17.190000000000012
# mbloss:  0.5720235705375671
# (dataset)error at epoch 50 is 17.179999999999993
# mbloss:  0.5717841386795044
# (dataset)error at epoch 51 is 17.159999999999997
# mbloss:  0.5715450048446655
# (dataset)error at epoch 52 is 17.14
# mbloss:  0.5713062286376953
# (dataset)error at epoch 53 is 17.129999999999995
# mbloss:  0.5710680484771729
# (dataset)error at epoch 54 is 17.120000000000005
# mbloss:  0.570830225944519
# (dataset)error at epoch 55 is 17.11
# mbloss:  0.5705927610397339
# (dataset)error at epoch 56 is 17.10000000000001
# mbloss:  0.5703557729721069
# (dataset)error at epoch 57 is 17.11
# mbloss:  0.5701192021369934
# (dataset)error at epoch 58 is 17.10000000000001
# mbloss:  0.5698830485343933
# (dataset)error at epoch 59 is 17.10000000000001
# mbloss:  0.5696473121643066
# (dataset)error at epoch 60 is 17.10000000000001
# mbloss:  0.5694119930267334
# (dataset)error at epoch 61 is 17.10000000000001
# mbloss:  0.5691770911216736
# (dataset)error at epoch 62 is 17.10000000000001
# mbloss:  0.568942666053772
# (dataset)error at epoch 63 is 17.10000000000001
# mbloss:  0.568708598613739
# (dataset)error at epoch 64 is 17.10000000000001
# mbloss:  0.5684748888015747
# (dataset)error at epoch 65 is 17.10000000000001
# mbloss:  0.568241536617279
# (dataset)error at epoch 66 is 17.10000000000001
# mbloss:  0.5680087208747864
# (dataset)error at epoch 67 is 17.090000000000003
# mbloss:  0.5677761435508728
# (dataset)error at epoch 68 is 17.090000000000003
# mbloss:  0.5675441026687622
# (dataset)error at epoch 69 is 17.060000000000002
# Test error of loop 2 is 17.060000000000002!
# The final model has the architecture: Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): TanhLU_shifted()
#   (3): Linear(in_features=100, out_features=50, bias=True)
#   (4): TanhLU_shifted()
#   (5): Linear(in_features=50, out_features=50, bias=True)
#   (6): TanhLU_shifted()
#   (7): Linear(in_features=50, out_features=10, bias=True)
# )

# %%
print('test error: ',check_testerror(test_dataloader, model1))
train_acc = check_testerror(train_dataloader, model1)
print('train error: ',train_acc)
# Out:
# test error:  17.060000000000002
# train error:  17.701666666666668

# %% [markdown]
# plot results:

# %%
end_list=[]
for i,e in enumerate(epochs):
    end_list.append(int(e*len(training_data)/batch_size))
    end_list.append(1) 
end_list.pop() # removes last 1 which was too much

# todo plot
if T1:
    plt.figure(figsize=(20,5))
    plt.grid(which='major', axis='x', zorder=-1.0)
    xfull = range(1,len(mb_losses1)+1)
    yfull = mb_losses1
    begin=0
    end=0
    for i in range(len(end_list)):
        end=end+end_list[i]
        x_curr= xfull[begin:end]
        y_curr= yfull[begin:end]
        begin=end
        plt.plot(x_curr,y_curr,'o')
    plt.xlabel('minibatch iterations')
    plt.ylabel('minibatch loss')

    plt.yscale('log')
    #plt.ylim((0.4,.6))
    #plt.xlim((99300,99800))
    
    plt.grid()
    plt.plot(np.zeros(len(mb_losses1)))

# %%
# todo plot
if T1:
    plt.figure(figsize=(20,5))
    plt.grid(which='major', axis='x', zorder=-1.0)
    xfull = range(1,len(grad_norms1)+1)
    yfull = grad_norms1
    begin=0
    end=0
    for i in range(len(end_list)):
        end=end+end_list[i]
        x_curr= xfull[begin:end]
        y_curr= yfull[begin:end]
        begin=end
        plt.plot(x_curr,y_curr,'o')
    plt.xlabel('minibatch iterations')
    plt.ylabel('squared grad norm')

    plt.yscale('log')
    #plt.ylim((0.4,.6))
    #plt.xlim((99300,99800))
    
    plt.grid()
    plt.plot(np.zeros(len(grad_norms1)))

# %%
plt.figure(figsize=(20,5))
plt.plot([initial_train_acc]+test_errors1)#,'o')
plt.ylim(top=100,bottom=0)
plt.grid()
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# ## Second training

# %%
# build net
if _type=='fwd':
    model_init2 = feed_forward(dim_in, dim_out,**kwargs_net)
if _type=='res2':
    model_init2 = two_weight_resnet(dim_in, dim_out,**kwargs_net)
if _type=='res1':
    model_init2 = one_weight_resnet(dim_in, dim_out,**kwargs_net)

torch.nn.utils.vector_to_parameters(param_init, model_init2.parameters())

# %%
print(check_testerror(test_dataloader,model_init2))
initial_train_acc2 = check_testerror(train_dataloader,model_init2)
print(check_testerror(train_dataloader,model_init2))
# Out:
# 92.01
# 92.055

# %%
if T2:
    model2, mb_losses2, test_errors_short2, test_errors2, exit_flag2, grad_norms2 = layer_insertion_loop(
        iters=no_iters,
        epochs=epochs,
        model= model_init2,
        kwargs_net=kwargs_net,
        dim_in=dim_in,
        dim_out=dim_out,
        train_dataloader=train_dataloader,
        test_dataloader=test_dataloader,
        lr_init=lr_init,
        wanted_test_error=wanted_testerror,
        mode='abs min',#'threshold',
        optimizer_type=optimizer_type,
        lrschedule_type=lrscheduler_type,
        lrscheduler_args=lrscheduler_args,
        check_testerror_between=interval_testerror,
        decrease_after_li=lr_decrease_after_li,
        print_param_flag=False,
        start_with_backtracking=None,
        v2=False,
        save_grad_norms=save_grad_norms
    )
# Out:
# starting on 1. net !
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): TanhLU_shifted()
#   (3): Linear(in_features=100, out_features=50, bias=True)
#   (4): TanhLU_shifted()
#   (5): Linear(in_features=50, out_features=10, bias=True)
# )
# mbloss:  2.3102364540100098
# (dataset)error at epoch 0 is 88.39
# mbloss:  2.2862839698791504
# (dataset)error at epoch 1 is 78.94
# mbloss:  2.2576422691345215
# (dataset)error at epoch 2 is 61.84
# mbloss:  2.213818073272705
# (dataset)error at epoch 3 is 52.52
# mbloss:  2.146496295928955
# (dataset)error at epoch 4 is 47.84
# mbloss:  2.042055606842041
# (dataset)error at epoch 5 is 52.22
# mbloss:  1.887965440750122
# (dataset)error at epoch 6 is 51.18
# mbloss:  1.7531884908676147
# (dataset)error at epoch 7 is 89.8
# mbloss:  3.246375322341919
# (dataset)error at epoch 8 is 77.35
# mbloss:  2.421201705932617
# (dataset)error at epoch 9 is 89.7
# mbloss:  2.561560869216919
# (dataset)error at epoch 10 is 74.75999999999999
# mbloss:  2.2724480628967285
# (dataset)error at epoch 11 is 67.82
# mbloss:  2.1935606002807617
# (dataset)error at epoch 12 is 56.45
# mbloss:  2.0809075832366943
# (dataset)error at epoch 13 is 55.79
# mbloss:  1.931295394897461
# (dataset)error at epoch 14 is 56.25
# mbloss:  1.8086251020431519
# (dataset)error at epoch 15 is 74.73
# mbloss:  2.232314348220825
# (dataset)error at epoch 16 is 83.78
# mbloss:  2.168522834777832
# (dataset)error at epoch 17 is 86.1
# mbloss:  2.5607845783233643
# (dataset)error at epoch 18 is 81.46000000000001
# mbloss:  2.271956443786621
# (dataset)error at epoch 19 is 73.94
# mbloss:  2.1658687591552734
# (dataset)error at epoch 20 is 74.12
# mbloss:  1.967061161994934
# (dataset)error at epoch 21 is 60.61
# mbloss:  1.8026766777038574
# (dataset)error at epoch 22 is 69.15
# mbloss:  2.0698907375335693
# (dataset)error at epoch 23 is 62.51
# mbloss:  1.9220629930496216
# (dataset)error at epoch 24 is 68.1
# mbloss:  1.9597147703170776
# (dataset)error at epoch 25 is 53.839999999999996
# mbloss:  1.6620278358459473
# (dataset)error at epoch 26 is 45.14
# mbloss:  1.550961971282959
# (dataset)error at epoch 27 is 54.25
# mbloss:  1.6997103691101074
# (dataset)error at epoch 28 is 63.54
# mbloss:  1.840597152709961
# (dataset)error at epoch 29 is 48.85
# mbloss:  1.5799667835235596
# (dataset)error at epoch 30 is 50.519999999999996
# mbloss:  1.4198939800262451
# (dataset)error at epoch 31 is 53.83
# mbloss:  1.5979118347167969
# (dataset)error at epoch 32 is 57.62
# mbloss:  1.9379589557647705
# (dataset)error at epoch 33 is 67.09
# mbloss:  2.162787675857544
# (dataset)error at epoch 34 is 72.93
# mbloss:  1.932254672050476
# (dataset)error at epoch 35 is 45.48
# mbloss:  1.5825164318084717
# (dataset)error at epoch 36 is 40.87
# mbloss:  1.2098093032836914
# (dataset)error at epoch 37 is 35.83
# mbloss:  1.0192253589630127
# (dataset)error at epoch 38 is 41.690000000000005
# mbloss:  1.0578105449676514
# (dataset)error at epoch 39 is 53.1
# mbloss:  1.7596746683120728
# (dataset)error at epoch 40 is 43.68
# mbloss:  1.3398089408874512
# (dataset)error at epoch 41 is 40.55
# mbloss:  1.2168163061141968
# (dataset)error at epoch 42 is 38.519999999999996
# mbloss:  1.145142674446106
# (dataset)error at epoch 43 is 37.01
# mbloss:  1.0933945178985596
# (dataset)error at epoch 44 is 35.72999999999999
# mbloss:  1.0521596670150757
# (dataset)error at epoch 45 is 34.150000000000006
# mbloss:  1.0172773599624634
# (dataset)error at epoch 46 is 32.28
# mbloss:  0.9865060448646545
# (dataset)error at epoch 47 is 30.30000000000001
# mbloss:  0.9584373235702515
# (dataset)error at epoch 48 is 28.64
# mbloss:  0.9320395588874817
# (dataset)error at epoch 49 is 27.75
# Test error after first step of loop 1 is 27.75!
# the averaged shadow prices  of all available positions: [tensor(9.3677e-06), tensor(3.7094e-05)]
# Insert layer at position 0 !
# starting on 2. net!
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): TanhLU_shifted()
#   (3): Linear(in_features=100, out_features=100, bias=True)
#   (4): TanhLU_shifted()
#   (5): Linear(in_features=100, out_features=50, bias=True)
#   (6): TanhLU_shifted()
#   (7): Linear(in_features=50, out_features=10, bias=True)
# )
# mbloss:  0.907564103603363
# (dataset)error at epoch 0 is 26.99000000000001
# mbloss:  0.8810145258903503
# (dataset)error at epoch 1 is 26.319999999999993
# mbloss:  0.8570768237113953
# (dataset)error at epoch 2 is 25.590000000000003
# mbloss:  0.8341631293296814
# (dataset)error at epoch 3 is 24.819999999999993
# mbloss:  0.8122390508651733
# (dataset)error at epoch 4 is 24.209999999999994
# mbloss:  0.791466236114502
# (dataset)error at epoch 5 is 23.560000000000002
# mbloss:  0.7720727920532227
# (dataset)error at epoch 6 is 22.950000000000003
# mbloss:  0.7542168498039246
# (dataset)error at epoch 7 is 22.310000000000002
# mbloss:  0.7380192279815674
# (dataset)error at epoch 8 is 21.86
# mbloss:  0.7235087156295776
# (dataset)error at epoch 9 is 21.430000000000007
# mbloss:  0.7106021046638489
# (dataset)error at epoch 10 is 21.03
# mbloss:  0.6991687417030334
# (dataset)error at epoch 11 is 20.74000000000001
# mbloss:  0.6890503168106079
# (dataset)error at epoch 12 is 20.42
# mbloss:  0.6800606846809387
# (dataset)error at epoch 13 is 20.13000000000001
# mbloss:  0.6720487475395203
# (dataset)error at epoch 14 is 19.86
# mbloss:  0.6648660898208618
# (dataset)error at epoch 15 is 19.620000000000005
# mbloss:  0.6583654284477234
# (dataset)error at epoch 16 is 19.590000000000003
# mbloss:  0.6524405479431152
# (dataset)error at epoch 17 is 19.510000000000005
# mbloss:  0.6469974517822266
# (dataset)error at epoch 18 is 19.41000000000001
# mbloss:  0.6419467926025391
# (dataset)error at epoch 19 is 19.289999999999992
# mbloss:  0.6372203230857849
# (dataset)error at epoch 20 is 19.08
# mbloss:  0.6327763199806213
# (dataset)error at epoch 21 is 18.870000000000005
# mbloss:  0.6285790801048279
# (dataset)error at epoch 22 is 18.820000000000007
# mbloss:  0.6245906352996826
# (dataset)error at epoch 23 is 18.710000000000008
# mbloss:  0.6207849979400635
# (dataset)error at epoch 24 is 18.64
# mbloss:  0.6171371340751648
# (dataset)error at epoch 25 is 18.61
# mbloss:  0.6136282682418823
# (dataset)error at epoch 26 is 18.5
# mbloss:  0.6102438569068909
# (dataset)error at epoch 27 is 18.379999999999995
# mbloss:  0.6069732904434204
# (dataset)error at epoch 28 is 18.25
# mbloss:  0.6038075685501099
# (dataset)error at epoch 29 is 18.189999999999998
# mbloss:  0.6007358431816101
# (dataset)error at epoch 30 is 18.069999999999993
# mbloss:  0.597750723361969
# (dataset)error at epoch 31 is 17.989999999999995
# mbloss:  0.5948460698127747
# (dataset)error at epoch 32 is 17.900000000000006
# mbloss:  0.5920129418373108
# (dataset)error at epoch 33 is 17.78
# mbloss:  0.5892472267150879
# (dataset)error at epoch 34 is 17.659999999999997
# mbloss:  0.5865455269813538
# (dataset)error at epoch 35 is 17.549999999999997
# mbloss:  0.5839029550552368
# (dataset)error at epoch 36 is 17.47
# mbloss:  0.581317663192749
# (dataset)error at epoch 37 is 17.39
# mbloss:  0.5787851810455322
# (dataset)error at epoch 38 is 17.28
# mbloss:  0.5763017535209656
# (dataset)error at epoch 39 is 17.190000000000012
# mbloss:  0.5738661885261536
# (dataset)error at epoch 40 is 17.190000000000012
# mbloss:  0.5736264586448669
# (dataset)error at epoch 41 is 17.179999999999993
# mbloss:  0.5733868479728699
# (dataset)error at epoch 42 is 17.190000000000012
# mbloss:  0.5731477737426758
# (dataset)error at epoch 43 is 17.179999999999993
# mbloss:  0.5729091167449951
# (dataset)error at epoch 44 is 17.179999999999993
# mbloss:  0.5726706981658936
# (dataset)error at epoch 45 is 17.17
# mbloss:  0.5724327564239502
# (dataset)error at epoch 46 is 17.150000000000006
# mbloss:  0.5721951723098755
# (dataset)error at epoch 47 is 17.14
# mbloss:  0.5719581842422485
# (dataset)error at epoch 48 is 17.129999999999995
# mbloss:  0.5717213749885559
# (dataset)error at epoch 49 is 17.14
# mbloss:  0.5714851021766663
# (dataset)error at epoch 50 is 17.10000000000001
# mbloss:  0.5712490677833557
# (dataset)error at epoch 51 is 17.090000000000003
# mbloss:  0.5710135698318481
# (dataset)error at epoch 52 is 17.090000000000003
# mbloss:  0.5707783699035645
# (dataset)error at epoch 53 is 17.08
# mbloss:  0.570543646812439
# (dataset)error at epoch 54 is 17.08
# mbloss:  0.5703092813491821
# (dataset)error at epoch 55 is 17.08
# mbloss:  0.570075273513794
# (dataset)error at epoch 56 is 17.08
# mbloss:  0.5698416829109192
# (dataset)error at epoch 57 is 17.069999999999993
# mbloss:  0.5696083307266235
# (dataset)error at epoch 58 is 17.049999999999997
# mbloss:  0.5693755149841309
# (dataset)error at epoch 59 is 17.060000000000002
# mbloss:  0.5691429972648621
# (dataset)error at epoch 60 is 17.060000000000002
# mbloss:  0.5689107775688171
# (dataset)error at epoch 61 is 17.049999999999997
# mbloss:  0.5686790347099304
# (dataset)error at epoch 62 is 17.049999999999997
# mbloss:  0.5684475302696228
# (dataset)error at epoch 63 is 17.049999999999997
# mbloss:  0.5682164430618286
# (dataset)error at epoch 64 is 17.040000000000006
# mbloss:  0.5679858326911926
# (dataset)error at epoch 65 is 17.040000000000006
# mbloss:  0.567755401134491
# (dataset)error at epoch 66 is 17.03
# mbloss:  0.5675254464149475
# (dataset)error at epoch 67 is 17.019999999999996
# mbloss:  0.5672959685325623
# (dataset)error at epoch 68 is 17.010000000000005
# mbloss:  0.5670666694641113
# (dataset)error at epoch 69 is 17.010000000000005
# Test error of loop 2 is 17.010000000000005!
# The final model has the architecture: Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): TanhLU_shifted()
#   (3): Linear(in_features=100, out_features=100, bias=True)
#   (4): TanhLU_shifted()
#   (5): Linear(in_features=100, out_features=50, bias=True)
#   (6): TanhLU_shifted()
#   (7): Linear(in_features=50, out_features=10, bias=True)
# )

# %%
if T2:
    print('test error: ',check_testerror(test_dataloader, model2))
    print('train error: ',check_testerror(train_dataloader, model2))
# Out:
# test error:  17.010000000000005
# train error:  17.616666666666674

# %% [markdown]
# plot results:

# %%
# todo plot
if T2:
    plt.figure(figsize=(20,5))
    plt.grid(which='major', axis='x', zorder=-1.0)
    xfull = range(1,len(mb_losses2)+1)
    yfull = mb_losses2
    begin=0
    end=0
    for i in range(len(end_list)):
        end=end+end_list[i]
        x_curr= xfull[begin:end]
        y_curr= yfull[begin:end]
        begin=end
        plt.plot(x_curr,y_curr,'o')
    plt.xlabel('minibatch iterations')
    plt.ylabel('minibatch loss')

    plt.yscale('log')
    #plt.ylim((0.4,.6))
    #plt.xlim((99300,99800))
    
    plt.grid()
    plt.plot(np.zeros(len(mb_losses2)))

# %%
# todo plot
if T2:
    plt.figure(figsize=(20,5))
    plt.grid(which='major', axis='x', zorder=-1.0)
    xfull = range(1,len(grad_norms2)+1)
    yfull = grad_norms2
    begin=0
    end=0
    for i in range(len(end_list)):
        end=end+end_list[i]
        x_curr= xfull[begin:end]
        y_curr= yfull[begin:end]
        begin=end
        plt.plot(x_curr,y_curr,'o')
    plt.xlabel('minibatch iterations')
    plt.ylabel('squared grad norm')

    plt.yscale('log')
    #plt.ylim((0.4,.6))
    #plt.xlim((99300,99800))
    
    plt.grid()
    plt.plot(np.zeros(len(grad_norms2)))

# %%
if T2:
    plt.figure(figsize=(20,5))
    #plt.ylim((0,100))
    plt.plot([initial_train_acc2]+test_errors2,'o')
    plt.ylim(bottom=0)
    plt.grid()

# %%
plt.figure(figsize=(20,5))
if T2:
    plt.plot(mb_losses2, label='ali min')
plt.plot(mb_losses1,label='ali max')

plt.yscale('log')

plt.legend()
#plt.ylim((1e-8,1.1))
#plt.xlim((80,100))
plt.show()

# %% [markdown]
# ## Third training

# %%
# build model
if _type=='fwd':
    model_classical = feed_forward(dim_in, dim_out,**kwargs_net_classical)
if _type=='res2':
    model_classical = two_weight_resnet(dim_in, dim_out,**kwargs_net_classical)
if _type=='res1':
    model_classical = one_weight_resnet(dim_in, dim_out,**kwargs_net_classical)

torch.nn.utils.vector_to_parameters(param_init_class,model_classical.parameters())

# %%
print('test error: ',check_testerror(test_dataloader, model_classical))
print('train error: ',check_testerror(train_dataloader, model_classical))
initial_train_acc_class = check_testerror(train_dataloader, model_classical)
# Out:
# test error:  92.01
# train error:  92.055

# %%
# build optimizer
if optimizer_type == 'SGD':
    optimizer_classical = torch.optim.SGD(model_classical.parameters(), lr_init_classical)
if optimizer_type == 'Adam':
    optimizer_classical = torch.optim.Adam(model_classical.parameters(), lr_init_classical)

# build lr scheduler
if lrscheduler_type == 'StepLR':
    step_size = lrscheduler_args_classical['step_size']
    gamma = lrscheduler_args_classical['gamma']
    lrscheduler_classical = torch.optim.lr_scheduler.StepLR(
            optimizer_classical, step_size=step_size, gamma=gamma)

# %%
if T3:
    print('training classically on model', model_classical)
    mblosses_classical, lr_end, test_error_classical, exit_flag_classical, grad_norms_classical = train(model_classical,
                                                             train_dataloader=train_dataloader,
                                                             epochs=epochs_classical,
                                                             optimizer=optimizer_classical,
                                                             scheduler=lrscheduler_classical,
                                                             wanted_testerror=wanted_testerror,
                                                             start_with_backtracking=None,
                                                             check_testerror_between=interval_testerror,
                                                             test_dataloader=test_dataloader,
                                                             print_param_flag=False,
                                                             save_grad_norms=save_grad_norms
                                                             )

# %% [markdown]
# plot results:

# %%
if T3:
    print('test error: ',check_testerror(test_dataloader, model_classical))
    print('train error: ',check_testerror(train_dataloader, model_classical))

# %%
if T3:
    plt.figure(figsize=(20,5))
    plt.plot(mblosses_classical,'o')
    plt.yscale('log')
    
    #plt.xlim((-10,3000))
    #plt.ylim((0.68,0.8))

# %%
if T3:
    plt.figure(figsize=(20,5))
    plt.plot(grad_norms_classical,'o')
    plt.yscale('log')

# %%
if T3:
    plt.figure(figsize=(20,5))
    plt.plot([initial_train_acc_class]+test_error_classical,'o')
    plt.ylim(bottom=0,top=10)
    plt.grid()

# %% [markdown]
# ## Comparison of the trainings as plot:

# %%
import matplotlib

# %%
matplotlib.rc('ytick', labelsize=16)
plt.figure(figsize=(20,5))
plt.vlines(50,0,3,linestyles='dotted',colors='lightgray')

#if T2:
#    plt.plot(np.zeros(max(len(mb_losses1),len(mb_losses2))))#,len(mblosses_classical))))
if T3:
    plt.plot(mblosses_classical, label='original net')
plt.plot(mb_losses1,label='Layer insertion')
if T2:
    plt.plot(mb_losses2, '--',label='Alternative')


plt.yscale('log')
plt.xlabel('iterations', fontsize=20)
plt.ylabel('loss', fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)


plt.legend(fontsize=20)
#plt.ylim((1e-8,1.1))
#plt.xlim((80,100))
plt.show()

# %%
from utils import ema2

# %%
smooth_factor = 0.99
s1= ema2(mb_losses1, smooth_factor,no_of_steps_back=1000)
if T2:
    s2= ema2(mb_losses2, smooth_factor, no_of_steps_back=1000)
if T3:
    s3 = ema2(mblosses_classical, smooth_factor, no_of_steps_back=1000)

# %%
plt.figure(figsize=(20,5))
if T2:
    plt.plot(np.zeros(max(len(s1),len(s2))))#,len(s3))))

if T2:
    plt.plot(s2, label='ali min')
plt.plot(s1,label='ali max')
if T3:
    plt.plot(s3, label='classical coarse')
plt.yscale('log')

plt.legend()
#plt.ylim((1e-8,1.1))
#plt.xlim((99800,102000))
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.plot(test_errors1,'o',label='absmax')
if T2:
    plt.plot(test_errors2,'o', label='absmin')
if T3:
    plt.plot(test_error_classical,'o',label='comparison')
plt.grid()
plt.ylim(bottom=0)
plt.legend()
