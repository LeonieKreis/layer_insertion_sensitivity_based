# %% [markdown]
# ## Notebook for running single training and compare them

# %% [markdown]
# Imports and set seed optionally:

# %%
import torch
import random
import copy
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import tikzplotlib
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor


from layer_insertion_loop import layer_insertion_loop
from train_and_test_ import train, check_testerror
from nets import feed_forward, two_weight_resnet, one_weight_resnet
from utils import ema


h=72
random.seed(h)
np.random.seed(h)
torch.manual_seed(h)

torch.set_num_threads(8)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# Define and list hyperparameters:

# %%
no_hidden_layers_start = 2
fix_width = [100,50]
no_iters = 1
lr_decrease_after_li =0.8
epochs = [70,70]
wanted_testerror = 2.
_type = 'fwd'
act_fun = nn.ReLU
interval_testerror = 1

batch_size = 60000 #1000 #20 #200 # 60000 for full batch
save_grad_norms = True

lr_init = 1e-0
optimizer_type = 'SGD'
lrscheduler_type = 'StepLR'
lrscheduler_args = {'step_size': 40,
                    'gamma': 0.1}


# for classical 
epochs_classical = sum(epochs)
lr_init_classical = lr_init
lrscheduler_args_classical = {'step_size': 40,
                    'gamma': 0.1}

# %% [markdown]
# Load dataset:

# %%
MNIST = True
FMNIST = False
CIFAR10 = False

# %%
if MNIST:    
    # Download training data from open datasets.
    training_data = datasets.MNIST(
        root="data",
        train=True,
        download=True,
        transform=ToTensor(),
    )

    # Download test data from open datasets.
    test_data = datasets.MNIST(
        root="data",
        train=False,
        download=True,
        transform=ToTensor(),
    )

    tr_split_len = 60000#10000
    te_split_len = 10000#int(0.33*tr_split_len)
    training_data = torch.utils.data.random_split(training_data, [tr_split_len, len(training_data)-tr_split_len])[0]
    test_data = torch.utils.data.random_split(test_data, [te_split_len, len(test_data)-te_split_len])[0]

if FMNIST:
    # Download training data from open datasets.
    training_data = datasets.FashionMNIST(
        root="data",
        train=True,
        download=True,
        transform=ToTensor(),
    )

    # Download test data from open datasets.
    test_data = datasets.FashionMNIST(
        root="data",
        train=False,
        download=True,
        transform=ToTensor(),
    )

if CIFAR10:
    # Download training data from open datasets.
    training_data = datasets.CIFAR10(
        root="data",
        train=True,
        download=True,
        transform=ToTensor(),
    )

    # Download test data from open datasets.
    test_data = datasets.CIFAR10(
        root="data",
        train=False,
        download=True,
        transform=ToTensor(),
    )

# %%
print('no of iterations in one epoch:',int(len(training_data)/batch_size))
print(len(training_data))
print(len(test_data))
# Out:
# no of iterations in one epoch: 1
# 60000
# 10000

# %% [markdown]
# Create dataloader:

# %%
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=10000)

# %% [markdown]
# Build models:

# %%
kwargs_net ={
        'hidden_layers': no_hidden_layers_start,
        'dim_hidden_layers': fix_width,
        'act_fun': act_fun,
        'type': _type
}

dim_in = 28*28 #32*32 
dim_out = 10

# %%
# classical net
kwargs_net_classical = {
    'hidden_layers': 2,
    'dim_hidden_layers': [100,50],#fix_width,
    'act_fun': act_fun,
    'type': _type
}

# %% [markdown]
# Determine which trainings are run:

# %%
T1 = True
T2 = True
T3 = False

# %% [markdown]
# ## Training with layer insertion:

# %%
# build model
if _type=='fwd':
    model_init = feed_forward(dim_in, dim_out,**kwargs_net)
if _type=='res2':
    model_init = two_weight_resnet(dim_in, dim_out,**kwargs_net)
if _type=='res1':
    model_init = one_weight_resnet(dim_in, dim_out,**kwargs_net)

param_init = torch.nn.utils.parameters_to_vector(model_init.parameters())
param_init = copy.deepcopy(param_init.data)
param_init_class = copy.deepcopy(param_init.data)

# %% [markdown]
# Check initial test error of the model

# %%
print(check_testerror(test_dataloader,model_init))
initial_train_acc = check_testerror(train_dataloader,model_init)
print(check_testerror(train_dataloader,model_init))
# Out:
# 92.03999999999999
# 92.06

# %%
# train ali 1
if T1:
    model1, mb_losses1, test_errors_short1, test_errors1, exit_flag1, grad_norms1 = layer_insertion_loop(
        iters=no_iters,
        epochs=epochs,
        model= model_init,
        kwargs_net=kwargs_net,
        dim_in=dim_in,
        dim_out=dim_out,
        train_dataloader=train_dataloader,
        test_dataloader=test_dataloader,
        lr_init=lr_init,
        wanted_test_error=wanted_testerror,
        mode='abs max',
        optimizer_type=optimizer_type,
        lrschedule_type=lrscheduler_type,
        lrscheduler_args=lrscheduler_args,
        check_testerror_between=interval_testerror,
        decrease_after_li=lr_decrease_after_li,
        print_param_flag=False,
        start_with_backtracking=None,
        v2=False,
        save_grad_norms=save_grad_norms
    )
# Out:
# starting on 1. net !
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=100, out_features=50, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=50, out_features=10, bias=True)
# )
# mbloss:  2.310239791870117
# (dataset)error at epoch 0 is 88.36
# mbloss:  2.286231279373169
# (dataset)error at epoch 1 is 78.89
# mbloss:  2.2575409412384033
# (dataset)error at epoch 2 is 61.65
# mbloss:  2.2136995792388916
# (dataset)error at epoch 3 is 52.589999999999996
# mbloss:  2.1464104652404785
# (dataset)error at epoch 4 is 47.89
# mbloss:  2.0420567989349365
# (dataset)error at epoch 5 is 52.27
# mbloss:  1.8884682655334473
# (dataset)error at epoch 6 is 51.85
# mbloss:  1.7583837509155273
# (dataset)error at epoch 7 is 89.91
# mbloss:  3.2710301876068115
# (dataset)error at epoch 8 is 76.93
# mbloss:  2.3834948539733887
# (dataset)error at epoch 9 is 89.69
# mbloss:  2.5311691761016846
# (dataset)error at epoch 10 is 75.47
# mbloss:  2.2686386108398438
# (dataset)error at epoch 11 is 61.61
# mbloss:  2.1797707080841064
# (dataset)error at epoch 12 is 58.72
# mbloss:  2.056166648864746
# (dataset)error at epoch 13 is 64.4
# mbloss:  1.9078656435012817
# (dataset)error at epoch 14 is 67.3
# mbloss:  1.900823950767517
# (dataset)error at epoch 15 is 76.53999999999999
# mbloss:  2.3594586849212646
# (dataset)error at epoch 16 is 64.9
# mbloss:  2.097815752029419
# (dataset)error at epoch 17 is 73.75
# mbloss:  2.030564785003662
# (dataset)error at epoch 18 is 82.12
# mbloss:  2.5471487045288086
# (dataset)error at epoch 19 is 86.67999999999999
# mbloss:  2.2278363704681396
# (dataset)error at epoch 20 is 77.31
# mbloss:  2.090102195739746
# (dataset)error at epoch 21 is 65.22
# mbloss:  1.967987298965454
# (dataset)error at epoch 22 is 51.36
# mbloss:  1.7178375720977783
# (dataset)error at epoch 23 is 43.379999999999995
# mbloss:  1.52414071559906
# (dataset)error at epoch 24 is 45.440000000000005
# mbloss:  1.4264487028121948
# (dataset)error at epoch 25 is 85.5
# mbloss:  2.606261968612671
# (dataset)error at epoch 26 is 61.67
# mbloss:  2.1081182956695557
# (dataset)error at epoch 27 is 69.53
# mbloss:  3.9420926570892334
# (dataset)error at epoch 28 is 75.55
# mbloss:  1.9991905689239502
# (dataset)error at epoch 29 is 62.480000000000004
# mbloss:  1.747277855873108
# (dataset)error at epoch 30 is 55.559999999999995
# mbloss:  1.6694529056549072
# (dataset)error at epoch 31 is 64.47999999999999
# mbloss:  1.763587474822998
# (dataset)error at epoch 32 is 65.94999999999999
# mbloss:  1.850826382637024
# (dataset)error at epoch 33 is 59.97
# mbloss:  1.78602933883667
# (dataset)error at epoch 34 is 46.309999999999995
# mbloss:  1.496312141418457
# (dataset)error at epoch 35 is 41.839999999999996
# mbloss:  1.3989381790161133
# (dataset)error at epoch 36 is 42.2
# mbloss:  1.2676674127578735
# (dataset)error at epoch 37 is 53.46
# mbloss:  1.7488794326782227
# (dataset)error at epoch 38 is 67.81
# mbloss:  2.4692132472991943
# (dataset)error at epoch 39 is 63.62
# mbloss:  1.8920358419418335
# (dataset)error at epoch 40 is 60.63
# mbloss:  1.7240312099456787
# (dataset)error at epoch 41 is 58.62
# mbloss:  1.6558853387832642
# (dataset)error at epoch 42 is 57.129999999999995
# mbloss:  1.6115226745605469
# (dataset)error at epoch 43 is 55.730000000000004
# mbloss:  1.5778026580810547
# (dataset)error at epoch 44 is 54.67
# mbloss:  1.550008773803711
# (dataset)error at epoch 45 is 53.69
# mbloss:  1.526035189628601
# (dataset)error at epoch 46 is 52.82
# mbloss:  1.5047543048858643
# (dataset)error at epoch 47 is 52.07
# mbloss:  1.4855152368545532
# (dataset)error at epoch 48 is 51.26
# mbloss:  1.4679988622665405
# (dataset)error at epoch 49 is 50.7
# mbloss:  1.451973795890808
# (dataset)error at epoch 50 is 50.22
# mbloss:  1.4372590780258179
# (dataset)error at epoch 51 is 49.63999999999999
# mbloss:  1.4236431121826172
# (dataset)error at epoch 52 is 49.41
# mbloss:  1.4109177589416504
# (dataset)error at epoch 53 is 49.03999999999999
# mbloss:  1.3989206552505493
# (dataset)error at epoch 54 is 48.79
# mbloss:  1.3875164985656738
# (dataset)error at epoch 55 is 48.45
# mbloss:  1.3765779733657837
# (dataset)error at epoch 56 is 48.199999999999996
# mbloss:  1.3660087585449219
# (dataset)error at epoch 57 is 47.69
# mbloss:  1.3557045459747314
# (dataset)error at epoch 58 is 47.370000000000005
# mbloss:  1.3455843925476074
# (dataset)error at epoch 59 is 47.08
# mbloss:  1.335586428642273
# (dataset)error at epoch 60 is 46.58
# mbloss:  1.325641393661499
# (dataset)error at epoch 61 is 46.19
# mbloss:  1.3156960010528564
# (dataset)error at epoch 62 is 45.76
# mbloss:  1.3057154417037964
# (dataset)error at epoch 63 is 45.26
# mbloss:  1.2956459522247314
# (dataset)error at epoch 64 is 44.830000000000005
# mbloss:  1.2854655981063843
# (dataset)error at epoch 65 is 44.52
# mbloss:  1.2751230001449585
# (dataset)error at epoch 66 is 44.11000000000001
# mbloss:  1.2645988464355469
# (dataset)error at epoch 67 is 43.61000000000001
# mbloss:  1.2538896799087524
# (dataset)error at epoch 68 is 43.2
# mbloss:  1.2429614067077637
# (dataset)error at epoch 69 is 42.76
# Test error after first step of loop 1 is 42.76!
# the averaged shadow prices  of all available positions: [tensor(1.1963e-06), tensor(4.7418e-06)]
# Insert layer at position 1 !
# starting on 2. net!
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=100, out_features=50, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=50, out_features=50, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=50, out_features=10, bias=True)
# )
# mbloss:  1.2318172454833984
# (dataset)error at epoch 0 is 42.300000000000004
# mbloss:  1.2220088243484497
# (dataset)error at epoch 1 is 41.23
# mbloss:  1.2085742950439453
# (dataset)error at epoch 2 is 40.5
# mbloss:  1.195094347000122
# (dataset)error at epoch 3 is 39.72
# mbloss:  1.1816933155059814
# (dataset)error at epoch 4 is 38.85999999999999
# mbloss:  1.1683874130249023
# (dataset)error at epoch 5 is 38.36000000000001
# mbloss:  1.1550532579421997
# (dataset)error at epoch 6 is 37.59
# mbloss:  1.1418027877807617
# (dataset)error at epoch 7 is 36.919999999999995
# mbloss:  1.1286581754684448
# (dataset)error at epoch 8 is 36.309999999999995
# mbloss:  1.1156785488128662
# (dataset)error at epoch 9 is 35.91
# mbloss:  1.102738380432129
# (dataset)error at epoch 10 is 35.540000000000006
# mbloss:  1.0900167226791382
# (dataset)error at epoch 11 is 35.22
# mbloss:  1.0774799585342407
# (dataset)error at epoch 12 is 34.95
# mbloss:  1.0649800300598145
# (dataset)error at epoch 13 is 34.64
# mbloss:  1.052725076675415
# (dataset)error at epoch 14 is 34.28999999999999
# mbloss:  1.0406250953674316
# (dataset)error at epoch 15 is 34.05
# mbloss:  1.0285810232162476
# (dataset)error at epoch 16 is 33.81
# mbloss:  1.0167458057403564
# (dataset)error at epoch 17 is 33.39999999999999
# mbloss:  1.0050603151321411
# (dataset)error at epoch 18 is 33.120000000000005
# mbloss:  0.9935198426246643
# (dataset)error at epoch 19 is 32.66
# mbloss:  0.9821382761001587
# (dataset)error at epoch 20 is 32.42
# mbloss:  0.9708925485610962
# (dataset)error at epoch 21 is 31.939999999999998
# mbloss:  0.9598530530929565
# (dataset)error at epoch 22 is 31.349999999999994
# mbloss:  0.9489923715591431
# (dataset)error at epoch 23 is 30.510000000000005
# mbloss:  0.9383555054664612
# (dataset)error at epoch 24 is 29.950000000000003
# mbloss:  0.9279401898384094
# (dataset)error at epoch 25 is 29.269999999999996
# mbloss:  0.9177811145782471
# (dataset)error at epoch 26 is 28.549999999999997
# mbloss:  0.9078834056854248
# (dataset)error at epoch 27 is 27.810000000000002
# mbloss:  0.8982539176940918
# (dataset)error at epoch 28 is 27.14
# mbloss:  0.888884425163269
# (dataset)error at epoch 29 is 26.539999999999992
# mbloss:  0.8797480463981628
# (dataset)error at epoch 30 is 26.129999999999995
# mbloss:  0.8708443641662598
# (dataset)error at epoch 31 is 25.700000000000003
# mbloss:  0.8621740341186523
# (dataset)error at epoch 32 is 25.290000000000006
# mbloss:  0.8537110090255737
# (dataset)error at epoch 33 is 24.939999999999998
# mbloss:  0.845441997051239
# (dataset)error at epoch 34 is 24.620000000000005
# mbloss:  0.8373503088951111
# (dataset)error at epoch 35 is 24.290000000000006
# mbloss:  0.829433023929596
# (dataset)error at epoch 36 is 24.05000000000001
# mbloss:  0.821681559085846
# (dataset)error at epoch 37 is 23.769999999999996
# mbloss:  0.8140916228294373
# (dataset)error at epoch 38 is 23.5
# mbloss:  0.8066558837890625
# (dataset)error at epoch 39 is 23.189999999999998
# mbloss:  0.7993740439414978
# (dataset)error at epoch 40 is 23.189999999999998
# mbloss:  0.7986571788787842
# (dataset)error at epoch 41 is 23.150000000000006
# mbloss:  0.7979416847229004
# (dataset)error at epoch 42 is 23.150000000000006
# mbloss:  0.7972273826599121
# (dataset)error at epoch 43 is 23.11999999999999
# mbloss:  0.7965144515037537
# (dataset)error at epoch 44 is 23.099999999999994
# mbloss:  0.795802891254425
# (dataset)error at epoch 45 is 23.08
# mbloss:  0.7950925230979919
# (dataset)error at epoch 46 is 23.08
# mbloss:  0.794383704662323
# (dataset)error at epoch 47 is 23.019999999999996
# mbloss:  0.793676495552063
# (dataset)error at epoch 48 is 23.019999999999996
# mbloss:  0.7929708957672119
# (dataset)error at epoch 49 is 23.0
# mbloss:  0.7922667264938354
# (dataset)error at epoch 50 is 22.97
# mbloss:  0.7915637493133545
# (dataset)error at epoch 51 is 22.960000000000008
# mbloss:  0.7908620238304138
# (dataset)error at epoch 52 is 22.92
# mbloss:  0.7901617288589478
# (dataset)error at epoch 53 is 22.870000000000005
# mbloss:  0.7894628047943115
# (dataset)error at epoch 54 is 22.870000000000005
# mbloss:  0.7887648344039917
# (dataset)error at epoch 55 is 22.840000000000003
# mbloss:  0.7880678176879883
# (dataset)error at epoch 56 is 22.83
# mbloss:  0.7873721122741699
# (dataset)error at epoch 57 is 22.83
# mbloss:  0.7866777181625366
# (dataset)error at epoch 58 is 22.810000000000002
# mbloss:  0.7859847545623779
# (dataset)error at epoch 59 is 22.75
# mbloss:  0.7852928638458252
# (dataset)error at epoch 60 is 22.72
# mbloss:  0.7846019268035889
# (dataset)error at epoch 61 is 22.700000000000003
# mbloss:  0.7839126586914062
# (dataset)error at epoch 62 is 22.709999999999994
# mbloss:  0.78322434425354
# (dataset)error at epoch 63 is 22.689999999999998
# mbloss:  0.7825374603271484
# (dataset)error at epoch 64 is 22.650000000000006
# mbloss:  0.7818520069122314
# (dataset)error at epoch 65 is 22.629999999999995
# mbloss:  0.78116774559021
# (dataset)error at epoch 66 is 22.61999999999999
# mbloss:  0.7804850339889526
# (dataset)error at epoch 67 is 22.590000000000003
# mbloss:  0.7798037528991699
# (dataset)error at epoch 68 is 22.560000000000002
# mbloss:  0.7791240811347961
# (dataset)error at epoch 69 is 22.549999999999997
# Test error of loop 2 is 22.549999999999997!
# The final model has the architecture: Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=100, out_features=50, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=50, out_features=50, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=50, out_features=10, bias=True)
# )

# %%
print('test error: ',check_testerror(test_dataloader, model1))
train_acc = check_testerror(train_dataloader, model1)
print('train error: ',train_acc)
# Out:
# test error:  22.549999999999997
# train error:  23.16333333333334

# %% [markdown]
# plot results:

# %%
end_list=[]
for i,e in enumerate(epochs):
    end_list.append(int(e*len(training_data)/batch_size))
    end_list.append(1) 
end_list.pop() # removes last 1 which was too much

# todo plot
if T1:
    plt.figure(figsize=(20,5))
    plt.grid(which='major', axis='x', zorder=-1.0)
    xfull = range(1,len(mb_losses1)+1)
    yfull = mb_losses1
    begin=0
    end=0
    for i in range(len(end_list)):
        end=end+end_list[i]
        x_curr= xfull[begin:end]
        y_curr= yfull[begin:end]
        begin=end
        plt.plot(x_curr,y_curr,'o')
    plt.xlabel('minibatch iterations')
    plt.ylabel('minibatch loss')

    plt.yscale('log')
    #plt.ylim((0.4,.6))
    #plt.xlim((99300,99800))
    
    plt.grid()
    plt.plot(np.zeros(len(mb_losses1)))

# %%
# todo plot
if T1:
    plt.figure(figsize=(20,5))
    plt.grid(which='major', axis='x', zorder=-1.0)
    xfull = range(1,len(grad_norms1)+1)
    yfull = grad_norms1
    begin=0
    end=0
    for i in range(len(end_list)):
        end=end+end_list[i]
        x_curr= xfull[begin:end]
        y_curr= yfull[begin:end]
        begin=end
        plt.plot(x_curr,y_curr,'o')
    plt.xlabel('minibatch iterations')
    plt.ylabel('squared grad norm')

    plt.yscale('log')
    #plt.ylim((0.4,.6))
    #plt.xlim((99300,99800))
    
    plt.grid()
    plt.plot(np.zeros(len(grad_norms1)))

# %%
plt.figure(figsize=(20,5))
plt.plot([initial_train_acc]+test_errors1)#,'o')
plt.ylim(top=100,bottom=0)
plt.grid()
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# ## Second training

# %%
# build net
if _type=='fwd':
    model_init2 = feed_forward(dim_in, dim_out,**kwargs_net)
if _type=='res2':
    model_init2 = two_weight_resnet(dim_in, dim_out,**kwargs_net)
if _type=='res1':
    model_init2 = one_weight_resnet(dim_in, dim_out,**kwargs_net)

torch.nn.utils.vector_to_parameters(param_init, model_init2.parameters())

# %%
print(check_testerror(test_dataloader,model_init2))
initial_train_acc2 = check_testerror(train_dataloader,model_init2)
print(check_testerror(train_dataloader,model_init2))
# Out:
# 92.03999999999999
# 92.06

# %%
if T2:
    model2, mb_losses2, test_errors_short2, test_errors2, exit_flag2, grad_norms2 = layer_insertion_loop(
        iters=no_iters,
        epochs=epochs,
        model= model_init2,
        kwargs_net=kwargs_net,
        dim_in=dim_in,
        dim_out=dim_out,
        train_dataloader=train_dataloader,
        test_dataloader=test_dataloader,
        lr_init=lr_init,
        wanted_test_error=wanted_testerror,
        mode='abs min',#'threshold',
        optimizer_type=optimizer_type,
        lrschedule_type=lrscheduler_type,
        lrscheduler_args=lrscheduler_args,
        check_testerror_between=interval_testerror,
        decrease_after_li=lr_decrease_after_li,
        print_param_flag=False,
        start_with_backtracking=None,
        v2=False,
        save_grad_norms=save_grad_norms
    )
# Out:
# starting on 1. net !
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=100, out_features=50, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=50, out_features=10, bias=True)
# )
# mbloss:  2.310239791870117
# (dataset)error at epoch 0 is 88.36
# mbloss:  2.286231279373169
# (dataset)error at epoch 1 is 78.89
# mbloss:  2.2575409412384033
# (dataset)error at epoch 2 is 61.65
# mbloss:  2.2136995792388916
# (dataset)error at epoch 3 is 52.589999999999996
# mbloss:  2.1464104652404785
# (dataset)error at epoch 4 is 47.89
# mbloss:  2.0420567989349365
# (dataset)error at epoch 5 is 52.27
# mbloss:  1.8884682655334473
# (dataset)error at epoch 6 is 51.85
# mbloss:  1.7583837509155273
# (dataset)error at epoch 7 is 89.91
# mbloss:  3.2710301876068115
# (dataset)error at epoch 8 is 76.93
# mbloss:  2.3834948539733887
# (dataset)error at epoch 9 is 89.69
# mbloss:  2.5311691761016846
# (dataset)error at epoch 10 is 75.47
# mbloss:  2.2686386108398438
# (dataset)error at epoch 11 is 61.61
# mbloss:  2.1797707080841064
# (dataset)error at epoch 12 is 58.72
# mbloss:  2.056166648864746
# (dataset)error at epoch 13 is 64.4
# mbloss:  1.9078656435012817
# (dataset)error at epoch 14 is 67.3
# mbloss:  1.900823950767517
# (dataset)error at epoch 15 is 76.53999999999999
# mbloss:  2.3594586849212646
# (dataset)error at epoch 16 is 64.9
# mbloss:  2.097815752029419
# (dataset)error at epoch 17 is 73.75
# mbloss:  2.030564785003662
# (dataset)error at epoch 18 is 82.12
# mbloss:  2.5471487045288086
# (dataset)error at epoch 19 is 86.67999999999999
# mbloss:  2.2278363704681396
# (dataset)error at epoch 20 is 77.31
# mbloss:  2.090102195739746
# (dataset)error at epoch 21 is 65.22
# mbloss:  1.967987298965454
# (dataset)error at epoch 22 is 51.36
# mbloss:  1.7178375720977783
# (dataset)error at epoch 23 is 43.379999999999995
# mbloss:  1.52414071559906
# (dataset)error at epoch 24 is 45.440000000000005
# mbloss:  1.4264487028121948
# (dataset)error at epoch 25 is 85.5
# mbloss:  2.606261968612671
# (dataset)error at epoch 26 is 61.67
# mbloss:  2.1081182956695557
# (dataset)error at epoch 27 is 69.53
# mbloss:  3.9420926570892334
# (dataset)error at epoch 28 is 75.55
# mbloss:  1.9991905689239502
# (dataset)error at epoch 29 is 62.480000000000004
# mbloss:  1.747277855873108
# (dataset)error at epoch 30 is 55.559999999999995
# mbloss:  1.6694529056549072
# (dataset)error at epoch 31 is 64.47999999999999
# mbloss:  1.763587474822998
# (dataset)error at epoch 32 is 65.94999999999999
# mbloss:  1.850826382637024
# (dataset)error at epoch 33 is 59.97
# mbloss:  1.78602933883667
# (dataset)error at epoch 34 is 46.309999999999995
# mbloss:  1.496312141418457
# (dataset)error at epoch 35 is 41.839999999999996
# mbloss:  1.3989381790161133
# (dataset)error at epoch 36 is 42.2
# mbloss:  1.2676674127578735
# (dataset)error at epoch 37 is 53.46
# mbloss:  1.7488794326782227
# (dataset)error at epoch 38 is 67.81
# mbloss:  2.4692132472991943
# (dataset)error at epoch 39 is 63.62
# mbloss:  1.8920358419418335
# (dataset)error at epoch 40 is 60.63
# mbloss:  1.7240312099456787
# (dataset)error at epoch 41 is 58.62
# mbloss:  1.6558853387832642
# (dataset)error at epoch 42 is 57.129999999999995
# mbloss:  1.6115226745605469
# (dataset)error at epoch 43 is 55.730000000000004
# mbloss:  1.5778026580810547
# (dataset)error at epoch 44 is 54.67
# mbloss:  1.550008773803711
# (dataset)error at epoch 45 is 53.69
# mbloss:  1.526035189628601
# (dataset)error at epoch 46 is 52.82
# mbloss:  1.5047543048858643
# (dataset)error at epoch 47 is 52.07
# mbloss:  1.4855152368545532
# (dataset)error at epoch 48 is 51.26
# mbloss:  1.4679988622665405
# (dataset)error at epoch 49 is 50.7
# mbloss:  1.451973795890808
# (dataset)error at epoch 50 is 50.22
# mbloss:  1.4372590780258179
# (dataset)error at epoch 51 is 49.63999999999999
# mbloss:  1.4236431121826172
# (dataset)error at epoch 52 is 49.41
# mbloss:  1.4109177589416504
# (dataset)error at epoch 53 is 49.03999999999999
# mbloss:  1.3989206552505493
# (dataset)error at epoch 54 is 48.79
# mbloss:  1.3875164985656738
# (dataset)error at epoch 55 is 48.45
# mbloss:  1.3765779733657837
# (dataset)error at epoch 56 is 48.199999999999996
# mbloss:  1.3660087585449219
# (dataset)error at epoch 57 is 47.69
# mbloss:  1.3557045459747314
# (dataset)error at epoch 58 is 47.370000000000005
# mbloss:  1.3455843925476074
# (dataset)error at epoch 59 is 47.08
# mbloss:  1.335586428642273
# (dataset)error at epoch 60 is 46.58
# mbloss:  1.325641393661499
# (dataset)error at epoch 61 is 46.19
# mbloss:  1.3156960010528564
# (dataset)error at epoch 62 is 45.76
# mbloss:  1.3057154417037964
# (dataset)error at epoch 63 is 45.26
# mbloss:  1.2956459522247314
# (dataset)error at epoch 64 is 44.830000000000005
# mbloss:  1.2854655981063843
# (dataset)error at epoch 65 is 44.52
# mbloss:  1.2751230001449585
# (dataset)error at epoch 66 is 44.11000000000001
# mbloss:  1.2645988464355469
# (dataset)error at epoch 67 is 43.61000000000001
# mbloss:  1.2538896799087524
# (dataset)error at epoch 68 is 43.2
# mbloss:  1.2429614067077637
# (dataset)error at epoch 69 is 42.76
# Test error after first step of loop 1 is 42.76!
# the averaged shadow prices  of all available positions: [tensor(1.1963e-06), tensor(4.7418e-06)]
# Insert layer at position 0 !
# starting on 2. net!
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=100, out_features=100, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=100, out_features=50, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=50, out_features=10, bias=True)
# )
# mbloss:  1.2318172454833984
# (dataset)error at epoch 0 is 42.32
# mbloss:  1.2220532894134521
# (dataset)error at epoch 1 is 41.65
# mbloss:  1.2116963863372803
# (dataset)error at epoch 2 is 41.190000000000005
# mbloss:  1.2012760639190674
# (dataset)error at epoch 3 is 40.800000000000004
# mbloss:  1.1907485723495483
# (dataset)error at epoch 4 is 40.25
# mbloss:  1.1800751686096191
# (dataset)error at epoch 5 is 39.629999999999995
# mbloss:  1.1692981719970703
# (dataset)error at epoch 6 is 39.27
# mbloss:  1.1584287881851196
# (dataset)error at epoch 7 is 38.79
# mbloss:  1.1474535465240479
# (dataset)error at epoch 8 is 38.29
# mbloss:  1.1364389657974243
# (dataset)error at epoch 9 is 37.870000000000005
# mbloss:  1.12535560131073
# (dataset)error at epoch 10 is 37.31
# mbloss:  1.1142650842666626
# (dataset)error at epoch 11 is 36.99
# mbloss:  1.1031278371810913
# (dataset)error at epoch 12 is 36.550000000000004
# mbloss:  1.0920132398605347
# (dataset)error at epoch 13 is 36.260000000000005
# mbloss:  1.0808755159378052
# (dataset)error at epoch 14 is 36.12
# mbloss:  1.0697643756866455
# (dataset)error at epoch 15 is 35.78
# mbloss:  1.0586574077606201
# (dataset)error at epoch 16 is 35.519999999999996
# mbloss:  1.0475730895996094
# (dataset)error at epoch 17 is 35.22
# mbloss:  1.0365166664123535
# (dataset)error at epoch 18 is 34.94
# mbloss:  1.0254881381988525
# (dataset)error at epoch 19 is 34.67
# mbloss:  1.0144976377487183
# (dataset)error at epoch 20 is 34.39999999999999
# mbloss:  1.0035500526428223
# (dataset)error at epoch 21 is 34.14
# mbloss:  0.992664635181427
# (dataset)error at epoch 22 is 33.8
# mbloss:  0.9818512201309204
# (dataset)error at epoch 23 is 33.45
# mbloss:  0.9711379408836365
# (dataset)error at epoch 24 is 32.959999999999994
# mbloss:  0.9605527520179749
# (dataset)error at epoch 25 is 32.66
# mbloss:  0.9501193165779114
# (dataset)error at epoch 26 is 32.24000000000001
# mbloss:  0.9398391842842102
# (dataset)error at epoch 27 is 31.679999999999993
# mbloss:  0.9297409057617188
# (dataset)error at epoch 28 is 30.939999999999998
# mbloss:  0.9198184609413147
# (dataset)error at epoch 29 is 30.320000000000007
# mbloss:  0.9100882411003113
# (dataset)error at epoch 30 is 29.60000000000001
# mbloss:  0.9005737900733948
# (dataset)error at epoch 31 is 28.97999999999999
# mbloss:  0.8912627100944519
# (dataset)error at epoch 32 is 28.180000000000007
# mbloss:  0.8821613192558289
# (dataset)error at epoch 33 is 27.42
# mbloss:  0.8732907176017761
# (dataset)error at epoch 34 is 26.849999999999994
# mbloss:  0.864630401134491
# (dataset)error at epoch 35 is 26.409999999999997
# mbloss:  0.8561736941337585
# (dataset)error at epoch 36 is 26.039999999999992
# mbloss:  0.8479154109954834
# (dataset)error at epoch 37 is 25.519999999999996
# mbloss:  0.8398420214653015
# (dataset)error at epoch 38 is 24.980000000000004
# mbloss:  0.8319358229637146
# (dataset)error at epoch 39 is 24.739999999999995
# mbloss:  0.8241904377937317
# (dataset)error at epoch 40 is 24.67
# mbloss:  0.8234264850616455
# (dataset)error at epoch 41 is 24.650000000000006
# mbloss:  0.8226635456085205
# (dataset)error at epoch 42 is 24.58
# mbloss:  0.821901798248291
# (dataset)error at epoch 43 is 24.55000000000001
# mbloss:  0.8211414813995361
# (dataset)error at epoch 44 is 24.510000000000005
# mbloss:  0.8203825354576111
# (dataset)error at epoch 45 is 24.460000000000008
# mbloss:  0.8196251392364502
# (dataset)error at epoch 46 is 24.460000000000008
# mbloss:  0.8188689351081848
# (dataset)error at epoch 47 is 24.439999999999998
# mbloss:  0.8181140422821045
# (dataset)error at epoch 48 is 24.42
# mbloss:  0.8173606991767883
# (dataset)error at epoch 49 is 24.39
# mbloss:  0.8166083097457886
# (dataset)error at epoch 50 is 24.33999999999999
# mbloss:  0.8158573508262634
# (dataset)error at epoch 51 is 24.28
# mbloss:  0.8151074647903442
# (dataset)error at epoch 52 is 24.239999999999995
# mbloss:  0.8143585920333862
# (dataset)error at epoch 53 is 24.239999999999995
# mbloss:  0.8136107921600342
# (dataset)error at epoch 54 is 24.239999999999995
# mbloss:  0.8128637075424194
# (dataset)error at epoch 55 is 24.239999999999995
# mbloss:  0.8121182322502136
# (dataset)error at epoch 56 is 24.22
# mbloss:  0.8113734126091003
# (dataset)error at epoch 57 is 24.189999999999998
# mbloss:  0.8106297254562378
# (dataset)error at epoch 58 is 24.159999999999997
# mbloss:  0.8098875284194946
# (dataset)error at epoch 59 is 24.14
# mbloss:  0.8091464638710022
# (dataset)error at epoch 60 is 24.129999999999995
# mbloss:  0.8084068298339844
# (dataset)error at epoch 61 is 24.060000000000002
# mbloss:  0.8076685070991516
# (dataset)error at epoch 62 is 24.039999999999992
# mbloss:  0.8069314956665039
# (dataset)error at epoch 63 is 24.0
# mbloss:  0.8061962127685547
# (dataset)error at epoch 64 is 23.97
# mbloss:  0.8054620027542114
# (dataset)error at epoch 65 is 23.929999999999993
# mbloss:  0.8047289848327637
# (dataset)error at epoch 66 is 23.879999999999995
# mbloss:  0.8039969801902771
# (dataset)error at epoch 67 is 23.810000000000002
# mbloss:  0.8032659888267517
# (dataset)error at epoch 68 is 23.78
# mbloss:  0.8025364875793457
# (dataset)error at epoch 69 is 23.790000000000006
# Test error of loop 2 is 23.790000000000006!
# The final model has the architecture: Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=100, out_features=100, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=100, out_features=50, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=50, out_features=10, bias=True)
# )

# %%
if T2:
    print('test error: ',check_testerror(test_dataloader, model2))
    print('train error: ',check_testerror(train_dataloader, model2))
# Out:
# test error:  23.790000000000006
# train error:  24.25833333333334

# %% [markdown]
# plot results:

# %%
# todo plot
if T2:
    plt.figure(figsize=(20,5))
    plt.grid(which='major', axis='x', zorder=-1.0)
    xfull = range(1,len(mb_losses2)+1)
    yfull = mb_losses2
    begin=0
    end=0
    for i in range(len(end_list)):
        end=end+end_list[i]
        x_curr= xfull[begin:end]
        y_curr= yfull[begin:end]
        begin=end
        plt.plot(x_curr,y_curr,'o')
    plt.xlabel('minibatch iterations')
    plt.ylabel('minibatch loss')

    plt.yscale('log')
    #plt.ylim((0.4,.6))
    #plt.xlim((99300,99800))
    
    plt.grid()
    plt.plot(np.zeros(len(mb_losses2)))

# %%
# todo plot
if T2:
    plt.figure(figsize=(20,5))
    plt.grid(which='major', axis='x', zorder=-1.0)
    xfull = range(1,len(grad_norms2)+1)
    yfull = grad_norms2
    begin=0
    end=0
    for i in range(len(end_list)):
        end=end+end_list[i]
        x_curr= xfull[begin:end]
        y_curr= yfull[begin:end]
        begin=end
        plt.plot(x_curr,y_curr,'o')
    plt.xlabel('minibatch iterations')
    plt.ylabel('squared grad norm')

    plt.yscale('log')
    #plt.ylim((0.4,.6))
    #plt.xlim((99300,99800))
    
    plt.grid()
    plt.plot(np.zeros(len(grad_norms2)))

# %%
if T2:
    plt.figure(figsize=(20,5))
    #plt.ylim((0,100))
    plt.plot([initial_train_acc2]+test_errors2,'o')
    plt.ylim(bottom=0)
    plt.grid()

# %%
plt.figure(figsize=(20,5))
if T2:
    plt.plot(mb_losses2, label='ali min')
plt.plot(mb_losses1,label='ali max')

plt.yscale('log')

plt.legend()
#plt.ylim((1e-8,1.1))
#plt.xlim((80,100))
plt.show()

# %% [markdown]
# ## Third training

# %%
# build model
if _type=='fwd':
    model_classical = feed_forward(dim_in, dim_out,**kwargs_net_classical)
if _type=='res2':
    model_classical = two_weight_resnet(dim_in, dim_out,**kwargs_net_classical)
if _type=='res1':
    model_classical = one_weight_resnet(dim_in, dim_out,**kwargs_net_classical)

torch.nn.utils.vector_to_parameters(param_init_class,model_classical.parameters())

# %%
print('test error: ',check_testerror(test_dataloader, model_classical))
print('train error: ',check_testerror(train_dataloader, model_classical))
initial_train_acc_class = check_testerror(train_dataloader, model_classical)
# Out:
# test error:  92.03999999999999
# train error:  92.06

# %%
# build optimizer
if optimizer_type == 'SGD':
    optimizer_classical = torch.optim.SGD(model_classical.parameters(), lr_init_classical)
if optimizer_type == 'Adam':
    optimizer_classical = torch.optim.Adam(model_classical.parameters(), lr_init_classical)

# build lr scheduler
if lrscheduler_type == 'StepLR':
    step_size = lrscheduler_args_classical['step_size']
    gamma = lrscheduler_args_classical['gamma']
    lrscheduler_classical = torch.optim.lr_scheduler.StepLR(
            optimizer_classical, step_size=step_size, gamma=gamma)

# %%
if T3:
    print('training classically on model', model_classical)
    mblosses_classical, lr_end, test_error_classical, exit_flag_classical, grad_norms_classical = train(model_classical,
                                                             train_dataloader=train_dataloader,
                                                             epochs=epochs_classical,
                                                             optimizer=optimizer_classical,
                                                             scheduler=lrscheduler_classical,
                                                             wanted_testerror=wanted_testerror,
                                                             start_with_backtracking=None,
                                                             check_testerror_between=interval_testerror,
                                                             test_dataloader=test_dataloader,
                                                             print_param_flag=False,
                                                             save_grad_norms=save_grad_norms
                                                             )

# %% [markdown]
# plot results:

# %%
if T3:
    print('test error: ',check_testerror(test_dataloader, model_classical))
    print('train error: ',check_testerror(train_dataloader, model_classical))

# %%
if T3:
    plt.figure(figsize=(20,5))
    plt.plot(mblosses_classical,'o')
    plt.yscale('log')
    
    #plt.xlim((-10,3000))
    #plt.ylim((0.68,0.8))

# %%
if T3:
    plt.figure(figsize=(20,5))
    plt.plot(grad_norms_classical,'o')
    plt.yscale('log')

# %%
if T3:
    plt.figure(figsize=(20,5))
    plt.plot([initial_train_acc_class]+test_error_classical,'o')
    plt.ylim(bottom=0,top=10)
    plt.grid()

# %% [markdown]
# ## Comparison of the trainings as plot:

# %%
# save data in sep json file
# todo

# %%
matplotlib.rc('ytick', labelsize=16)
plt.figure(figsize=(12,4))

#if T2:
#    plt.plot(np.zeros(max(len(mb_losses1),len(mb_losses2))))#,len(mblosses_classical))))
if T3:
    plt.plot(mblosses_classical, label='original net')
plt.plot(mb_losses1,label='Layer insertion')
if T2:
    plt.plot(mb_losses2, '--',label='Alternative')

plt.vlines(70,0.8,4,linestyles='dotted',colors='gray')

plt.yscale('log')
plt.xlabel('iterations', fontsize=20)
plt.ylabel('loss', fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)


plt.legend(fontsize=20)
tikzplotlib.save('tikzpicture_plots/fig4a.tex', axis_height='4cm', axis_width='12cm')

# %%
plt.figure(figsize=(20,5))

#if T2:
#    plt.plot(np.zeros(max(len(mb_losses1),len(mb_losses2))))#,len(mblosses_classical))))
if T3:
    plt.plot(mblosses_classical, label='original net')
if T2:
    plt.plot(mb_losses2, label='abs min')
plt.plot(mb_losses1,label='abs max')

plt.yscale('log')

plt.legend()
#plt.ylim((1e-8,1.1))
#plt.xlim((80,100))
plt.show()

# %%
from utils import ema2

# %%
smooth_factor = 0.99
s1= ema2(mb_losses1, smooth_factor,no_of_steps_back=1000)
if T2:
    s2= ema2(mb_losses2, smooth_factor, no_of_steps_back=1000)
if T3:
    s3 = ema2(mblosses_classical, smooth_factor, no_of_steps_back=1000)

# %%
plt.figure(figsize=(20,5))
if T2:
    plt.plot(np.zeros(max(len(s1),len(s2))))#,len(s3))))

if T2:
    plt.plot(s2, label='ali min')
plt.plot(s1,label='ali max')
if T3:
    plt.plot(s3, label='classical coarse')
plt.yscale('log')

plt.legend()
#plt.ylim((1e-8,1.1))
#plt.xlim((99800,102000))
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.plot(test_errors1,'o',label='absmax')
if T2:
    plt.plot(test_errors2,'o', label='absmin')
if T3:
    plt.plot(test_error_classical,'o',label='comparison')
plt.grid()
plt.ylim(bottom=0)
plt.legend()
