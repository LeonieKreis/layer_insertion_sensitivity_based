# %% [markdown]
# ## Notebook for running single training and compare them

# %% [markdown]
# Imports and set seed optionally:

# %%
import torch
import random
import copy
import numpy as np
import matplotlib.pyplot as plt
from torch import nn
from torch.utils.data import DataLoader
from spirals_data_new import plot_decision_boundary, gen_spiral_dataset
from torchvision.transforms import ToTensor


from layer_insertion_loop import layer_insertion_loop
from train_and_test_ import train, check_testerror
from nets import feed_forward, two_weight_resnet, one_weight_resnet
from utils import ema

h=random.randint(0,100)
print(h)
random.seed(h)
np.random.seed(h)
torch.manual_seed(h)

torch.set_num_threads(8)
# Out:
# Running on CPU!
# Current working directory:  /home/leonie/codes/layer_insertion_sensitivity_based
# Removed previously created data directory & contents
# New data directory created
# ['li_experiments_spirals.ipynb', 'utils.py', 'Plot_comp_spirals.py', 'Plot_LI_spirals.py', 'plot_numerical_experiments_spirals.py', 'TODO.md', 'experiment_py_files', 'tikzpicture_plots', 'exp11_5.ipynb', 'data', 'save_to_json.py', 'li_experiments.ipynb', 'Plot_minmax_spirals _closeup.py', '20_absmax.txt', 'figs', 'Plot_comp_spirals_one_figure _mod_xaxis.py', 'model_selection.py', 'exp9_5.ipynb', '21_absmin.txt', '20_absmin.txt', '.git', 'spirals_data_new.py', 'plot_LI_spirals.py', 'exp7_5.ipynb', 'exp9_55.ipynb', 'Plot_minmax_spirals.py', '.gitignore', 'plot_helper.py', 'activation_functions.py', 'nets.py', 'Plot_comp_spirals_iterations.py', 'Plot_comp_spirals_one_figure.py', 'README.md', 'model_utils.py', '__pycache__', 'plot_numerical_experiments_ab16.py', 'train_and_test_.py', 'Plot_comp_spirals_einzeln.py', '.pytest_cache', 'results_data_spirals', 'combine_plots.py', 'plot_numerical_experiments.py', 'calculate_shadow_prices.py', 'Plot_LI_spirals _onefigure.py', 'li_experiments_spirals_5.ipynb', '21_absmax.txt', 'playground.py', 'LICENSE', 'layer_insertion_loop.py', 'backtracking.py', 'jsonfile_builder.py']
# Training   set:  600
# Validation set:  200
# 46

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
batchsize = 450
no_per_class = 300
r0=0.5
circles = 1

# %%
td, vd, data_X, data_y = gen_spiral_dataset(batchsize,no_per_class,r0,circles)
# Out:
# Running on CPU!
# Current working directory:  /home/leonie/codes/layer_insertion_sensitivity_based
# Removed previously created data directory & contents
# New data directory created
# ['li_experiments_spirals.ipynb', 'utils.py', 'Plot_comp_spirals.py', 'Plot_LI_spirals.py', 'plot_numerical_experiments_spirals.py', 'TODO.md', 'experiment_py_files', 'tikzpicture_plots', 'exp11_5.ipynb', 'data', 'save_to_json.py', 'li_experiments.ipynb', 'Plot_minmax_spirals _closeup.py', '20_absmax.txt', 'figs', 'Plot_comp_spirals_one_figure _mod_xaxis.py', 'model_selection.py', 'exp9_5.ipynb', '21_absmin.txt', '20_absmin.txt', '.git', 'spirals_data_new.py', 'plot_LI_spirals.py', 'exp7_5.ipynb', 'exp9_55.ipynb', 'Plot_minmax_spirals.py', '.gitignore', 'plot_helper.py', 'activation_functions.py', 'nets.py', 'Plot_comp_spirals_iterations.py', 'Plot_comp_spirals_one_figure.py', 'README.md', 'model_utils.py', '__pycache__', 'plot_numerical_experiments_ab16.py', 'train_and_test_.py', 'Plot_comp_spirals_einzeln.py', '.pytest_cache', 'results_data_spirals', 'combine_plots.py', 'plot_numerical_experiments.py', 'calculate_shadow_prices.py', 'Plot_LI_spirals _onefigure.py', 'li_experiments_spirals_5.ipynb', '21_absmax.txt', 'playground.py', 'LICENSE', 'layer_insertion_loop.py', 'backtracking.py', 'jsonfile_builder.py']
# Training   set:  450
# Validation set:  150

# %% [markdown]
# Define and list hyperparameters:

# %%
no_hidden_layers_start = 2
fix_width = [3,3]
no_iters = 1
lr_decrease_after_li =0.5 #1.0#0.8
epochs = [50,150]
wanted_testerror = 0.
_type = 'res2'
act_fun = nn.ReLU
interval_testerror = 1

save_grad_norms = True

lr_init = 2e-1
optimizer_type = 'SGD'
lrscheduler_type = 'StepLR'
lrscheduler_args = {'step_size': 4000,
                    'gamma': 0.1}


# for classical 
epochs_classical = sum(epochs)
lr_init_classical = lr_init
lrscheduler_args_classical = {'step_size': 4000,
                    'gamma': 0.1}

# %% [markdown]
# Build models:

# %%
kwargs_net ={
        'hidden_layers': no_hidden_layers_start,
        'dim_hidden_layers': fix_width,
        'act_fun': act_fun,
        'type': _type,
    'flatten': True
}

dim_in = 2 
dim_out = 2

# %%
# classical net
kwargs_net_classical = {
    'hidden_layers': 2,
    'dim_hidden_layers': fix_width,
    'act_fun': act_fun,
    'type': _type,
    'flatten': True
}

# %% [markdown]
# Determine which trainings are run:

# %%
T1 = True
T2 = True
T3 = True

# %% [markdown]
# ## Training with layer insertion:

# %%
# build model
if _type=='fwd':
    model_init = feed_forward(dim_in, dim_out,**kwargs_net)
if _type=='res2':
    model_init = two_weight_resnet(dim_in, dim_out,**kwargs_net)
if _type=='res1':
    model_init = one_weight_resnet(dim_in, dim_out,**kwargs_net)

param_init = torch.nn.utils.parameters_to_vector(model_init.parameters())
param_init = copy.deepcopy(param_init.data)
param_init_class = copy.deepcopy(param_init.data)

# %% [markdown]
# Check initial test error of the model

# %%
print(check_testerror(vd,model_init))
initial_train_acc = check_testerror(td,model_init)
print(check_testerror(td,model_init))
# Out:
# 48.0
# 46.44444444444444

# %%
for X,y in vd:
    print(X.shape)
    print(y.shape)
    #print(y)
# Out:
# torch.Size([150, 2])
# torch.Size([150])

# %%
plot_decision_boundary(model_init, data_X, data_y)

# %%
# train ali 1
if T1:
    model1, mb_losses1, test_errors_short1, test_errors1, exit_flag1, grad_norms1, times1 = layer_insertion_loop(
        iters=no_iters,
        epochs=epochs,
        model= model_init,
        kwargs_net=kwargs_net,
        dim_in=dim_in,
        dim_out=dim_out,
        train_dataloader=td,
        test_dataloader=vd,
        lr_init=lr_init,
        wanted_test_error=wanted_testerror,
        mode='abs max',
        optimizer_type=optimizer_type,
        lrschedule_type=lrscheduler_type,
        lrscheduler_args=lrscheduler_args,
        check_testerror_between=interval_testerror,
        decrease_after_li=lr_decrease_after_li,
        print_param_flag=False,
        start_with_backtracking=None,
        v2=False,
        save_grad_norms=save_grad_norms
    )
# Out:
# starting on 1. net !
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=2, out_features=3, bias=False)
#   (2): ReLU()
#   (3): ResBlock1(
#     (af1): ReLU()
#     (l1): Linear(in_features=3, out_features=3, bias=True)
#     (shortcut): Sequential()
#     (l2): Linear(in_features=3, out_features=3, bias=False)
#   )
#   (4): Linear(in_features=3, out_features=2, bias=False)
# )
# mbloss:  0.6812914609909058
# (dataset)error at epoch 0 is 48.0
# mbloss:  0.6809448003768921
# (dataset)error at epoch 1 is 49.33333333333333
# mbloss:  0.6806014776229858
# (dataset)error at epoch 2 is 50.0
# mbloss:  0.6802606582641602
# (dataset)error at epoch 3 is 49.33333333333333
# mbloss:  0.679933488368988
# (dataset)error at epoch 4 is 49.33333333333333
# mbloss:  0.6796111464500427
# (dataset)error at epoch 5 is 49.33333333333333
# mbloss:  0.6792930364608765
# (dataset)error at epoch 6 is 49.33333333333333
# mbloss:  0.6789785027503967
# (dataset)error at epoch 7 is 49.33333333333333
# mbloss:  0.6786664724349976
# (dataset)error at epoch 8 is 49.33333333333333
# mbloss:  0.6783586144447327
# (dataset)error at epoch 9 is 48.66666666666667
# mbloss:  0.6780557036399841
# (dataset)error at epoch 10 is 48.66666666666667
# mbloss:  0.6777569651603699
# (dataset)error at epoch 11 is 50.0
# mbloss:  0.6774618625640869
# (dataset)error at epoch 12 is 50.0
# mbloss:  0.6771703362464905
# (dataset)error at epoch 13 is 50.0
# mbloss:  0.6768832802772522
# (dataset)error at epoch 14 is 50.0
# mbloss:  0.676600456237793
# (dataset)error at epoch 15 is 50.0
# mbloss:  0.6763217449188232
# (dataset)error at epoch 16 is 50.0
# mbloss:  0.6760468482971191
# (dataset)error at epoch 17 is 50.0
# mbloss:  0.6757757067680359
# (dataset)error at epoch 18 is 50.0
# mbloss:  0.6755099892616272
# (dataset)error at epoch 19 is 50.0
# mbloss:  0.6752497553825378
# (dataset)error at epoch 20 is 50.0
# mbloss:  0.6749962568283081
# (dataset)error at epoch 21 is 50.666666666666664
# mbloss:  0.6747470498085022
# (dataset)error at epoch 22 is 50.666666666666664
# mbloss:  0.6745008826255798
# (dataset)error at epoch 23 is 50.666666666666664
# mbloss:  0.674258291721344
# (dataset)error at epoch 24 is 50.666666666666664
# mbloss:  0.6740186810493469
# (dataset)error at epoch 25 is 50.666666666666664
# mbloss:  0.6737834811210632
# (dataset)error at epoch 26 is 50.666666666666664
# mbloss:  0.6735514998435974
# (dataset)error at epoch 27 is 51.33333333333333
# mbloss:  0.6733241677284241
# (dataset)error at epoch 28 is 51.33333333333333
# mbloss:  0.6731002330780029
# (dataset)error at epoch 29 is 51.33333333333333
# mbloss:  0.6728763580322266
# (dataset)error at epoch 30 is 52.0
# mbloss:  0.6726546287536621
# (dataset)error at epoch 31 is 52.0
# mbloss:  0.672435998916626
# (dataset)error at epoch 32 is 52.0
# mbloss:  0.6722186803817749
# (dataset)error at epoch 33 is 52.0
# mbloss:  0.6720050573348999
# (dataset)error at epoch 34 is 52.0
# mbloss:  0.67179274559021
# (dataset)error at epoch 35 is 52.0
# mbloss:  0.6715803742408752
# (dataset)error at epoch 36 is 52.0
# mbloss:  0.6713688969612122
# (dataset)error at epoch 37 is 52.0
# mbloss:  0.6711567044258118
# (dataset)error at epoch 38 is 52.0
# mbloss:  0.6709425449371338
# (dataset)error at epoch 39 is 52.666666666666664
# mbloss:  0.670717716217041
# (dataset)error at epoch 40 is 52.0
# mbloss:  0.6704820394515991
# (dataset)error at epoch 41 is 52.0
# mbloss:  0.6702431440353394
# (dataset)error at epoch 42 is 51.33333333333333
# mbloss:  0.6700035929679871
# (dataset)error at epoch 43 is 51.33333333333333
# mbloss:  0.6697594523429871
# (dataset)error at epoch 44 is 51.33333333333333
# mbloss:  0.6695136427879333
# (dataset)error at epoch 45 is 51.33333333333333
# mbloss:  0.6692604422569275
# (dataset)error at epoch 46 is 51.33333333333333
# mbloss:  0.6689901351928711
# (dataset)error at epoch 47 is 51.33333333333333
# mbloss:  0.6687139868736267
# (dataset)error at epoch 48 is 51.33333333333333
# mbloss:  0.668437659740448
# (dataset)error at epoch 49 is 51.33333333333333
# mbloss:  0.6681627035140991
# (dataset)error at epoch 50 is 50.666666666666664
# mbloss:  0.6678860783576965
# (dataset)error at epoch 51 is 50.666666666666664
# mbloss:  0.6676080822944641
# (dataset)error at epoch 52 is 51.33333333333333
# mbloss:  0.6673297882080078
# (dataset)error at epoch 53 is 51.33333333333333
# mbloss:  0.6670527458190918
# (dataset)error at epoch 54 is 51.33333333333333
# mbloss:  0.666779637336731
# (dataset)error at epoch 55 is 51.33333333333333
# mbloss:  0.6665370464324951
# (dataset)error at epoch 56 is 51.33333333333333
# mbloss:  0.666316032409668
# (dataset)error at epoch 57 is 51.33333333333333
# mbloss:  0.6661087870597839
# (dataset)error at epoch 58 is 51.33333333333333
# mbloss:  0.6659088730812073
# (dataset)error at epoch 59 is 51.33333333333333
# mbloss:  0.6657177209854126
# (dataset)error at epoch 60 is 50.666666666666664
# mbloss:  0.6655365824699402
# (dataset)error at epoch 61 is 51.33333333333333
# mbloss:  0.6653650403022766
# (dataset)error at epoch 62 is 51.33333333333333
# mbloss:  0.6652003526687622
# (dataset)error at epoch 63 is 52.0
# mbloss:  0.665042519569397
# (dataset)error at epoch 64 is 52.0
# mbloss:  0.6648908853530884
# (dataset)error at epoch 65 is 52.666666666666664
# mbloss:  0.6647430658340454
# (dataset)error at epoch 66 is 52.666666666666664
# mbloss:  0.66459721326828
# (dataset)error at epoch 67 is 50.666666666666664
# mbloss:  0.6644572019577026
# (dataset)error at epoch 68 is 50.666666666666664
# mbloss:  0.664322555065155
# (dataset)error at epoch 69 is 50.666666666666664
# mbloss:  0.6641941070556641
# (dataset)error at epoch 70 is 50.666666666666664
# mbloss:  0.664070725440979
# (dataset)error at epoch 71 is 50.666666666666664
# mbloss:  0.6639523506164551
# (dataset)error at epoch 72 is 50.666666666666664
# mbloss:  0.6638365387916565
# (dataset)error at epoch 73 is 50.666666666666664
# mbloss:  0.6637253761291504
# (dataset)error at epoch 74 is 50.666666666666664
# mbloss:  0.6636163592338562
# (dataset)error at epoch 75 is 50.666666666666664
# mbloss:  0.663510262966156
# (dataset)error at epoch 76 is 50.666666666666664
# mbloss:  0.6634098887443542
# (dataset)error at epoch 77 is 50.666666666666664
# mbloss:  0.6633115410804749
# (dataset)error at epoch 78 is 50.666666666666664
# mbloss:  0.6632151007652283
# (dataset)error at epoch 79 is 50.666666666666664
# mbloss:  0.6631226539611816
# (dataset)error at epoch 80 is 50.666666666666664
# mbloss:  0.6630330681800842
# (dataset)error at epoch 81 is 50.666666666666664
# mbloss:  0.6629466414451599
# (dataset)error at epoch 82 is 50.666666666666664
# mbloss:  0.6628618240356445
# (dataset)error at epoch 83 is 50.666666666666664
# mbloss:  0.6627793908119202
# (dataset)error at epoch 84 is 50.666666666666664
# mbloss:  0.6626997590065002
# (dataset)error at epoch 85 is 50.666666666666664
# mbloss:  0.6626210808753967
# (dataset)error at epoch 86 is 50.666666666666664
# mbloss:  0.6625439524650574
# (dataset)error at epoch 87 is 50.666666666666664
# mbloss:  0.6624693870544434
# (dataset)error at epoch 88 is 50.666666666666664
# mbloss:  0.6623977422714233
# (dataset)error at epoch 89 is 50.666666666666664
# mbloss:  0.6623287200927734
# (dataset)error at epoch 90 is 50.666666666666664
# mbloss:  0.6622604131698608
# (dataset)error at epoch 91 is 50.666666666666664
# mbloss:  0.6621893048286438
# (dataset)error at epoch 92 is 50.666666666666664
# mbloss:  0.6621197462081909
# (dataset)error at epoch 93 is 50.666666666666664
# mbloss:  0.6620516777038574
# (dataset)error at epoch 94 is 50.666666666666664
# mbloss:  0.661984920501709
# (dataset)error at epoch 95 is 50.666666666666664
# mbloss:  0.6619188189506531
# (dataset)error at epoch 96 is 50.666666666666664
# mbloss:  0.6618532538414001
# (dataset)error at epoch 97 is 50.666666666666664
# mbloss:  0.6617885828018188
# (dataset)error at epoch 98 is 50.666666666666664
# mbloss:  0.661727249622345
# (dataset)error at epoch 99 is 50.666666666666664
# mbloss:  0.6616677045822144
# (dataset)error at epoch 100 is 50.666666666666664
# mbloss:  0.6616091728210449
# (dataset)error at epoch 101 is 50.666666666666664
# mbloss:  0.6615511775016785
# (dataset)error at epoch 102 is 50.666666666666664
# mbloss:  0.6614940762519836
# (dataset)error at epoch 103 is 50.666666666666664
# mbloss:  0.661437451839447
# (dataset)error at epoch 104 is 50.666666666666664
# mbloss:  0.6613817811012268
# (dataset)error at epoch 105 is 50.666666666666664
# mbloss:  0.6613259315490723
# (dataset)error at epoch 106 is 50.666666666666664
# mbloss:  0.6612706184387207
# (dataset)error at epoch 107 is 50.666666666666664
# mbloss:  0.6612154841423035
# (dataset)error at epoch 108 is 50.666666666666664
# mbloss:  0.6611610054969788
# (dataset)error at epoch 109 is 50.666666666666664
# mbloss:  0.6611078381538391
# (dataset)error at epoch 110 is 50.666666666666664
# mbloss:  0.6610549688339233
# (dataset)error at epoch 111 is 50.666666666666664
# mbloss:  0.6610023379325867
# (dataset)error at epoch 112 is 50.666666666666664
# mbloss:  0.6609498262405396
# (dataset)error at epoch 113 is 50.666666666666664
# mbloss:  0.6608975529670715
# (dataset)error at epoch 114 is 50.666666666666664
# mbloss:  0.6608452796936035
# (dataset)error at epoch 115 is 50.666666666666664
# mbloss:  0.6607940196990967
# (dataset)error at epoch 116 is 50.666666666666664
# mbloss:  0.6607433557510376
# (dataset)error at epoch 117 is 50.666666666666664
# mbloss:  0.66069096326828
# (dataset)error at epoch 118 is 50.666666666666664
# mbloss:  0.6606312990188599
# (dataset)error at epoch 119 is 50.666666666666664
# mbloss:  0.6605718731880188
# (dataset)error at epoch 120 is 50.666666666666664
# mbloss:  0.6605126261711121
# (dataset)error at epoch 121 is 50.666666666666664
# mbloss:  0.6604532599449158
# (dataset)error at epoch 122 is 50.666666666666664
# mbloss:  0.660394012928009
# (dataset)error at epoch 123 is 50.666666666666664
# mbloss:  0.6603354215621948
# (dataset)error at epoch 124 is 50.666666666666664
# mbloss:  0.6602777242660522
# (dataset)error at epoch 125 is 50.666666666666664
# mbloss:  0.6602202653884888
# (dataset)error at epoch 126 is 50.666666666666664
# mbloss:  0.6601630449295044
# (dataset)error at epoch 127 is 50.666666666666664
# mbloss:  0.6601091027259827
# (dataset)error at epoch 128 is 50.666666666666664
# mbloss:  0.660057783126831
# (dataset)error at epoch 129 is 50.666666666666664
# mbloss:  0.6600061058998108
# (dataset)error at epoch 130 is 50.666666666666664
# mbloss:  0.6599542498588562
# (dataset)error at epoch 131 is 50.666666666666664
# mbloss:  0.6599017977714539
# (dataset)error at epoch 132 is 50.666666666666664
# mbloss:  0.6598491668701172
# (dataset)error at epoch 133 is 50.666666666666664
# mbloss:  0.6597961187362671
# (dataset)error at epoch 134 is 50.666666666666664
# mbloss:  0.6597425937652588
# (dataset)error at epoch 135 is 50.666666666666664
# mbloss:  0.6596889495849609
# (dataset)error at epoch 136 is 50.666666666666664
# mbloss:  0.6596354246139526
# (dataset)error at epoch 137 is 50.666666666666664
# mbloss:  0.6595813632011414
# (dataset)error at epoch 138 is 50.666666666666664
# mbloss:  0.6595271229743958
# (dataset)error at epoch 139 is 50.666666666666664
# mbloss:  0.6594724655151367
# (dataset)error at epoch 140 is 50.666666666666664
# mbloss:  0.6594170928001404
# (dataset)error at epoch 141 is 50.666666666666664
# mbloss:  0.6593614816665649
# (dataset)error at epoch 142 is 50.666666666666664
# mbloss:  0.6593055129051208
# (dataset)error at epoch 143 is 50.666666666666664
# mbloss:  0.6592490077018738
# (dataset)error at epoch 144 is 50.666666666666664
# mbloss:  0.6591918468475342
# (dataset)error at epoch 145 is 50.666666666666664
# mbloss:  0.6591343283653259
# (dataset)error at epoch 146 is 50.666666666666664
# mbloss:  0.6590763330459595
# (dataset)error at epoch 147 is 50.666666666666664
# mbloss:  0.65901780128479
# (dataset)error at epoch 148 is 50.666666666666664
# mbloss:  0.6589586734771729
# (dataset)error at epoch 149 is 50.666666666666664
# mbloss:  0.6588991284370422
# (dataset)error at epoch 150 is 50.666666666666664
# mbloss:  0.6588389873504639
# (dataset)error at epoch 151 is 50.666666666666664
# mbloss:  0.6587784886360168
# (dataset)error at epoch 152 is 50.666666666666664
# mbloss:  0.6587178111076355
# (dataset)error at epoch 153 is 50.666666666666664
# mbloss:  0.6586561799049377
# (dataset)error at epoch 154 is 50.666666666666664
# mbloss:  0.658594012260437
# (dataset)error at epoch 155 is 50.666666666666664
# mbloss:  0.6585313081741333
# (dataset)error at epoch 156 is 50.666666666666664
# mbloss:  0.6584679484367371
# (dataset)error at epoch 157 is 50.666666666666664
# mbloss:  0.6584039330482483
# (dataset)error at epoch 158 is 50.666666666666664
# mbloss:  0.6583393216133118
# (dataset)error at epoch 159 is 50.666666666666664
# mbloss:  0.6582731604576111
# (dataset)error at epoch 160 is 50.666666666666664
# mbloss:  0.658206582069397
# (dataset)error at epoch 161 is 50.666666666666664
# mbloss:  0.6581393480300903
# (dataset)error at epoch 162 is 50.666666666666664
# mbloss:  0.658072292804718
# (dataset)error at epoch 163 is 50.666666666666664
# mbloss:  0.6580045819282532
# (dataset)error at epoch 164 is 50.666666666666664
# mbloss:  0.6579362750053406
# (dataset)error at epoch 165 is 50.666666666666664
# mbloss:  0.6578673720359802
# (dataset)error at epoch 166 is 50.666666666666664
# mbloss:  0.6577975749969482
# (dataset)error at epoch 167 is 50.666666666666664
# mbloss:  0.6577277183532715
# (dataset)error at epoch 168 is 50.666666666666664
# mbloss:  0.657657265663147
# (dataset)error at epoch 169 is 50.666666666666664
# mbloss:  0.6575860977172852
# (dataset)error at epoch 170 is 50.666666666666664
# mbloss:  0.6575143337249756
# (dataset)error at epoch 171 is 50.666666666666664
# mbloss:  0.6574417948722839
# (dataset)error at epoch 172 is 50.666666666666664
# mbloss:  0.6573684811592102
# (dataset)error at epoch 173 is 50.666666666666664
# mbloss:  0.6572944521903992
# (dataset)error at epoch 174 is 50.666666666666664
# mbloss:  0.6572197675704956
# (dataset)error at epoch 175 is 50.666666666666664
# mbloss:  0.6571444869041443
# (dataset)error at epoch 176 is 50.666666666666664
# mbloss:  0.6570687294006348
# (dataset)error at epoch 177 is 50.666666666666664
# mbloss:  0.6569921374320984
# (dataset)error at epoch 178 is 50.666666666666664
# mbloss:  0.6569148898124695
# (dataset)error at epoch 179 is 50.666666666666664
# mbloss:  0.6568368077278137
# (dataset)error at epoch 180 is 50.666666666666664
# mbloss:  0.6567578315734863
# (dataset)error at epoch 181 is 50.666666666666664
# mbloss:  0.6566782593727112
# (dataset)error at epoch 182 is 50.666666666666664
# mbloss:  0.6565976142883301
# (dataset)error at epoch 183 is 50.666666666666664
# mbloss:  0.6565163731575012
# (dataset)error at epoch 184 is 50.666666666666664
# mbloss:  0.6564342379570007
# (dataset)error at epoch 185 is 50.666666666666664
# mbloss:  0.6563512086868286
# (dataset)error at epoch 186 is 50.666666666666664
# mbloss:  0.6562674045562744
# (dataset)error at epoch 187 is 50.666666666666664
# mbloss:  0.6561825275421143
# (dataset)error at epoch 188 is 50.666666666666664
# mbloss:  0.6560968160629272
# (dataset)error at epoch 189 is 50.666666666666664
# mbloss:  0.6560101509094238
# (dataset)error at epoch 190 is 50.666666666666664
# mbloss:  0.6559223532676697
# (dataset)error at epoch 191 is 50.666666666666664
# mbloss:  0.6558332443237305
# (dataset)error at epoch 192 is 50.666666666666664
# mbloss:  0.6557433605194092
# (dataset)error at epoch 193 is 50.666666666666664
# mbloss:  0.6556527614593506
# (dataset)error at epoch 194 is 50.666666666666664
# mbloss:  0.6555610299110413
# (dataset)error at epoch 195 is 50.0
# mbloss:  0.6554685235023499
# (dataset)error at epoch 196 is 50.0
# mbloss:  0.6553750038146973
# (dataset)error at epoch 197 is 50.0
# mbloss:  0.6552805304527283
# (dataset)error at epoch 198 is 50.0
# mbloss:  0.6551849842071533
# (dataset)error at epoch 199 is 50.0
# mbloss:  0.6550885438919067
# (dataset)error at epoch 200 is 50.0
# mbloss:  0.6549913287162781
# (dataset)error at epoch 201 is 50.0
# mbloss:  0.6548928022384644
# (dataset)error at epoch 202 is 50.0
# mbloss:  0.654793381690979
# (dataset)error at epoch 203 is 50.0
# mbloss:  0.6546927690505981
# (dataset)error at epoch 204 is 50.0
# mbloss:  0.6545912027359009
# (dataset)error at epoch 205 is 50.0
# mbloss:  0.6544883847236633
# (dataset)error at epoch 206 is 50.0
# mbloss:  0.654384434223175
# (dataset)error at epoch 207 is 50.0
# mbloss:  0.6542795300483704
# (dataset)error at epoch 208 is 50.0
# mbloss:  0.6541733145713806
# (dataset)error at epoch 209 is 50.0
# mbloss:  0.654065728187561
# (dataset)error at epoch 210 is 50.0
# mbloss:  0.6539570689201355
# (dataset)error at epoch 211 is 50.0
# mbloss:  0.6538470983505249
# (dataset)error at epoch 212 is 50.0
# mbloss:  0.6537360548973083
# (dataset)error at epoch 213 is 50.0
# mbloss:  0.6536235213279724
# (dataset)error at epoch 214 is 50.0
# mbloss:  0.6535097360610962
# (dataset)error at epoch 215 is 50.0
# mbloss:  0.6533945202827454
# (dataset)error at epoch 216 is 50.0
# mbloss:  0.6532779335975647
# (dataset)error at epoch 217 is 50.0
# mbloss:  0.6531597375869751
# (dataset)error at epoch 218 is 50.0
# mbloss:  0.6530393958091736
# (dataset)error at epoch 219 is 50.0
# mbloss:  0.6529176831245422
# (dataset)error at epoch 220 is 50.0
# mbloss:  0.6527947187423706
# (dataset)error at epoch 221 is 50.0
# mbloss:  0.6526704430580139
# (dataset)error at epoch 222 is 50.0
# mbloss:  0.6525446176528931
# (dataset)error at epoch 223 is 50.0
# mbloss:  0.6524173021316528
# (dataset)error at epoch 224 is 50.0
# mbloss:  0.6522884964942932
# (dataset)error at epoch 225 is 50.0
# mbloss:  0.6521581411361694
# (dataset)error at epoch 226 is 50.0
# mbloss:  0.6520261168479919
# (dataset)error at epoch 227 is 50.0
# mbloss:  0.6518925428390503
# (dataset)error at epoch 228 is 50.0
# mbloss:  0.6517574191093445
# (dataset)error at epoch 229 is 50.0
# mbloss:  0.6516203880310059
# (dataset)error at epoch 230 is 50.0
# mbloss:  0.6514819264411926
# (dataset)error at epoch 231 is 50.0
# mbloss:  0.6513416171073914
# (dataset)error at epoch 232 is 49.33333333333333
# mbloss:  0.651199460029602
# (dataset)error at epoch 233 is 49.33333333333333
# mbloss:  0.6510555148124695
# (dataset)error at epoch 234 is 49.33333333333333
# mbloss:  0.6509098410606384
# (dataset)error at epoch 235 is 49.33333333333333
# mbloss:  0.6507622003555298
# (dataset)error at epoch 236 is 49.33333333333333
# mbloss:  0.6506125926971436
# (dataset)error at epoch 237 is 49.33333333333333
# mbloss:  0.6504611968994141
# (dataset)error at epoch 238 is 49.33333333333333
# mbloss:  0.6503082513809204
# (dataset)error at epoch 239 is 49.33333333333333
# mbloss:  0.6501538753509521
# (dataset)error at epoch 240 is 49.33333333333333
# mbloss:  0.649996817111969
# (dataset)error at epoch 241 is 49.33333333333333
# mbloss:  0.649834394454956
# (dataset)error at epoch 242 is 49.33333333333333
# mbloss:  0.6496701240539551
# (dataset)error at epoch 243 is 49.33333333333333
# mbloss:  0.6495044827461243
# (dataset)error at epoch 244 is 49.33333333333333
# mbloss:  0.6493367552757263
# (dataset)error at epoch 245 is 49.33333333333333
# mbloss:  0.6491672992706299
# (dataset)error at epoch 246 is 49.33333333333333
# mbloss:  0.6489959955215454
# (dataset)error at epoch 247 is 49.33333333333333
# mbloss:  0.6488227844238281
# (dataset)error at epoch 248 is 49.33333333333333
# mbloss:  0.6486474871635437
# (dataset)error at epoch 249 is 49.33333333333333
# mbloss:  0.6484701037406921
# (dataset)error at epoch 250 is 48.66666666666667
# mbloss:  0.648290753364563
# (dataset)error at epoch 251 is 48.66666666666667
# mbloss:  0.6481092572212219
# (dataset)error at epoch 252 is 48.66666666666667
# mbloss:  0.6479255557060242
# (dataset)error at epoch 253 is 48.66666666666667
# mbloss:  0.6477387547492981
# (dataset)error at epoch 254 is 48.66666666666667
# mbloss:  0.6475450396537781
# (dataset)error at epoch 255 is 48.66666666666667
# mbloss:  0.6473492383956909
# (dataset)error at epoch 256 is 48.66666666666667
# mbloss:  0.6471512913703918
# (dataset)error at epoch 257 is 48.66666666666667
# mbloss:  0.6469513177871704
# (dataset)error at epoch 258 is 48.0
# mbloss:  0.6467501521110535
# (dataset)error at epoch 259 is 48.0
# mbloss:  0.6465485692024231
# (dataset)error at epoch 260 is 48.0
# mbloss:  0.6463449001312256
# (dataset)error at epoch 261 is 48.0
# mbloss:  0.6461388468742371
# (dataset)error at epoch 262 is 48.0
# mbloss:  0.6459304690361023
# (dataset)error at epoch 263 is 48.0
# mbloss:  0.6457194685935974
# (dataset)error at epoch 264 is 48.0
# mbloss:  0.6455023884773254
# (dataset)error at epoch 265 is 48.0
# mbloss:  0.6452755928039551
# (dataset)error at epoch 266 is 48.0
# mbloss:  0.6450488567352295
# (dataset)error at epoch 267 is 48.0
# mbloss:  0.6448202729225159
# (dataset)error at epoch 268 is 48.0
# mbloss:  0.6445897817611694
# (dataset)error at epoch 269 is 48.0
# mbloss:  0.6443572044372559
# (dataset)error at epoch 270 is 48.0
# mbloss:  0.6441223621368408
# (dataset)error at epoch 271 is 47.333333333333336
# mbloss:  0.643884003162384
# (dataset)error at epoch 272 is 47.333333333333336
# mbloss:  0.6436296105384827
# (dataset)error at epoch 273 is 47.333333333333336
# mbloss:  0.6433739066123962
# (dataset)error at epoch 274 is 47.333333333333336
# mbloss:  0.6431165337562561
# (dataset)error at epoch 275 is 47.333333333333336
# mbloss:  0.642855703830719
# (dataset)error at epoch 276 is 47.333333333333336
# mbloss:  0.6425929069519043
# (dataset)error at epoch 277 is 47.333333333333336
# mbloss:  0.6423268914222717
# (dataset)error at epoch 278 is 46.666666666666664
# mbloss:  0.6420446634292603
# (dataset)error at epoch 279 is 46.666666666666664
# mbloss:  0.6417615413665771
# (dataset)error at epoch 280 is 46.666666666666664
# mbloss:  0.641477108001709
# (dataset)error at epoch 281 is 46.666666666666664
# mbloss:  0.6411903500556946
# (dataset)error at epoch 282 is 46.666666666666664
# mbloss:  0.6409032940864563
# (dataset)error at epoch 283 is 46.666666666666664
# mbloss:  0.6406236886978149
# (dataset)error at epoch 284 is 46.666666666666664
# mbloss:  0.6403421759605408
# (dataset)error at epoch 285 is 46.666666666666664
# mbloss:  0.6400575041770935
# (dataset)error at epoch 286 is 46.666666666666664
# mbloss:  0.6397696733474731
# (dataset)error at epoch 287 is 46.666666666666664
# mbloss:  0.6394785642623901
# (dataset)error at epoch 288 is 46.666666666666664
# mbloss:  0.6391841769218445
# (dataset)error at epoch 289 is 46.666666666666664
# mbloss:  0.6388862729072571
# (dataset)error at epoch 290 is 46.666666666666664
# mbloss:  0.6385846734046936
# (dataset)error at epoch 291 is 46.0
# mbloss:  0.6382794976234436
# (dataset)error at epoch 292 is 46.0
# mbloss:  0.6379705667495728
# (dataset)error at epoch 293 is 46.0
# mbloss:  0.6376549601554871
# (dataset)error at epoch 294 is 46.0
# mbloss:  0.6373167037963867
# (dataset)error at epoch 295 is 46.0
# mbloss:  0.6369768381118774
# (dataset)error at epoch 296 is 46.0
# mbloss:  0.6366347074508667
# (dataset)error at epoch 297 is 45.333333333333336
# mbloss:  0.6362901926040649
# (dataset)error at epoch 298 is 43.99999999999999
# mbloss:  0.6359426975250244
# (dataset)error at epoch 299 is 42.666666666666664
# mbloss:  0.6355905532836914
# (dataset)error at epoch 300 is 42.666666666666664
# mbloss:  0.6352325677871704
# (dataset)error at epoch 301 is 42.666666666666664
# mbloss:  0.6348714828491211
# (dataset)error at epoch 302 is 42.666666666666664
# mbloss:  0.6345070004463196
# (dataset)error at epoch 303 is 42.666666666666664
# mbloss:  0.6341390609741211
# (dataset)error at epoch 304 is 42.00000000000001
# mbloss:  0.633766233921051
# (dataset)error at epoch 305 is 42.00000000000001
# mbloss:  0.6333848834037781
# (dataset)error at epoch 306 is 42.00000000000001
# mbloss:  0.6330053210258484
# (dataset)error at epoch 307 is 42.00000000000001
# mbloss:  0.6326200366020203
# (dataset)error at epoch 308 is 42.00000000000001
# mbloss:  0.6322285532951355
# (dataset)error at epoch 309 is 42.00000000000001
# mbloss:  0.6318323612213135
# (dataset)error at epoch 310 is 42.00000000000001
# mbloss:  0.6314337253570557
# (dataset)error at epoch 311 is 42.00000000000001
# mbloss:  0.6310335397720337
# (dataset)error at epoch 312 is 42.00000000000001
# mbloss:  0.6306286454200745
# (dataset)error at epoch 313 is 42.666666666666664
# mbloss:  0.6302193403244019
# (dataset)error at epoch 314 is 42.666666666666664
# mbloss:  0.6298051476478577
# (dataset)error at epoch 315 is 42.666666666666664
# mbloss:  0.6293860673904419
# (dataset)error at epoch 316 is 42.666666666666664
# mbloss:  0.6289615035057068
# (dataset)error at epoch 317 is 42.666666666666664
# mbloss:  0.6285130977630615
# (dataset)error at epoch 318 is 42.00000000000001
# mbloss:  0.6280649304389954
# (dataset)error at epoch 319 is 42.00000000000001
# mbloss:  0.6276146173477173
# (dataset)error at epoch 320 is 41.333333333333336
# mbloss:  0.6271617412567139
# (dataset)error at epoch 321 is 40.666666666666664
# mbloss:  0.6267059445381165
# (dataset)error at epoch 322 is 40.666666666666664
# mbloss:  0.6262518167495728
# (dataset)error at epoch 323 is 40.666666666666664
# mbloss:  0.62579345703125
# (dataset)error at epoch 324 is 40.666666666666664
# mbloss:  0.6253347992897034
# (dataset)error at epoch 325 is 40.666666666666664
# mbloss:  0.6248719096183777
# (dataset)error at epoch 326 is 40.666666666666664
# mbloss:  0.6244044899940491
# (dataset)error at epoch 327 is 40.666666666666664
# mbloss:  0.6239323616027832
# (dataset)error at epoch 328 is 40.666666666666664
# mbloss:  0.6234548687934875
# (dataset)error at epoch 329 is 40.666666666666664
# mbloss:  0.6229700446128845
# (dataset)error at epoch 330 is 40.666666666666664
# mbloss:  0.6224783062934875
# (dataset)error at epoch 331 is 40.666666666666664
# mbloss:  0.6219761371612549
# (dataset)error at epoch 332 is 40.666666666666664
# mbloss:  0.6214760541915894
# (dataset)error at epoch 333 is 40.0
# mbloss:  0.6209707856178284
# (dataset)error at epoch 334 is 40.0
# mbloss:  0.6204596757888794
# (dataset)error at epoch 335 is 40.0
# mbloss:  0.6199434399604797
# (dataset)error at epoch 336 is 40.0
# mbloss:  0.6194220781326294
# (dataset)error at epoch 337 is 40.0
# mbloss:  0.6188955307006836
# (dataset)error at epoch 338 is 40.0
# mbloss:  0.6183638572692871
# (dataset)error at epoch 339 is 40.0
# mbloss:  0.6178286671638489
# (dataset)error at epoch 340 is 40.0
# mbloss:  0.6172918081283569
# (dataset)error at epoch 341 is 40.0
# mbloss:  0.6167503595352173
# (dataset)error at epoch 342 is 40.0
# mbloss:  0.6162039637565613
# (dataset)error at epoch 343 is 40.0
# mbloss:  0.6156529188156128
# (dataset)error at epoch 344 is 40.0
# mbloss:  0.6150975823402405
# (dataset)error at epoch 345 is 40.0
# mbloss:  0.6145372986793518
# (dataset)error at epoch 346 is 40.0
# mbloss:  0.6139721870422363
# (dataset)error at epoch 347 is 40.0
# mbloss:  0.6134021282196045
# (dataset)error at epoch 348 is 39.33333333333333
# mbloss:  0.6128273010253906
# (dataset)error at epoch 349 is 39.33333333333333
# mbloss:  0.61224764585495
# (dataset)error at epoch 350 is 39.33333333333333
# mbloss:  0.6116635203361511
# (dataset)error at epoch 351 is 38.66666666666667
# mbloss:  0.6110749840736389
# (dataset)error at epoch 352 is 38.66666666666667
# mbloss:  0.6104826927185059
# (dataset)error at epoch 353 is 38.66666666666667
# mbloss:  0.6098862290382385
# (dataset)error at epoch 354 is 38.66666666666667
# mbloss:  0.6092849969863892
# (dataset)error at epoch 355 is 38.66666666666667
# mbloss:  0.6086798310279846
# (dataset)error at epoch 356 is 38.66666666666667
# mbloss:  0.6080706119537354
# (dataset)error at epoch 357 is 38.66666666666667
# mbloss:  0.6074602007865906
# (dataset)error at epoch 358 is 38.66666666666667
# mbloss:  0.6068523526191711
# (dataset)error at epoch 359 is 38.66666666666667
# mbloss:  0.6062416434288025
# (dataset)error at epoch 360 is 37.33333333333333
# mbloss:  0.605627179145813
# (dataset)error at epoch 361 is 37.33333333333333
# mbloss:  0.6050095558166504
# (dataset)error at epoch 362 is 37.33333333333333
# mbloss:  0.6043887734413147
# (dataset)error at epoch 363 is 37.33333333333333
# mbloss:  0.6037653088569641
# (dataset)error at epoch 364 is 37.33333333333333
# mbloss:  0.6031392812728882
# (dataset)error at epoch 365 is 37.33333333333333
# mbloss:  0.6025101542472839
# (dataset)error at epoch 366 is 37.33333333333333
# mbloss:  0.6018780469894409
# (dataset)error at epoch 367 is 37.33333333333333
# mbloss:  0.6012428998947144
# (dataset)error at epoch 368 is 36.66666666666667
# mbloss:  0.6006047129631042
# (dataset)error at epoch 369 is 36.66666666666667
# mbloss:  0.5999637246131897
# (dataset)error at epoch 370 is 36.66666666666667
# mbloss:  0.5993200540542603
# (dataset)error at epoch 371 is 36.66666666666667
# mbloss:  0.5986737608909607
# (dataset)error at epoch 372 is 37.33333333333333
# mbloss:  0.5980252027511597
# (dataset)error at epoch 373 is 37.33333333333333
# mbloss:  0.5973741412162781
# (dataset)error at epoch 374 is 36.66666666666667
# mbloss:  0.5967209339141846
# (dataset)error at epoch 375 is 36.66666666666667
# mbloss:  0.5960657596588135
# (dataset)error at epoch 376 is 36.66666666666667
# mbloss:  0.5954086780548096
# (dataset)error at epoch 377 is 36.66666666666667
# mbloss:  0.5947498679161072
# (dataset)error at epoch 378 is 36.66666666666667
# mbloss:  0.5940895676612854
# (dataset)error at epoch 379 is 36.66666666666667
# mbloss:  0.5934277176856995
# (dataset)error at epoch 380 is 36.0
# mbloss:  0.5927658677101135
# (dataset)error at epoch 381 is 36.0
# mbloss:  0.5921028256416321
# (dataset)error at epoch 382 is 36.0
# mbloss:  0.5914389491081238
# (dataset)error at epoch 383 is 36.0
# mbloss:  0.5907741785049438
# (dataset)error at epoch 384 is 36.0
# mbloss:  0.5901089906692505
# (dataset)error at epoch 385 is 36.66666666666667
# mbloss:  0.5894432663917542
# (dataset)error at epoch 386 is 36.66666666666667
# mbloss:  0.5887787938117981
# (dataset)error at epoch 387 is 36.66666666666667
# mbloss:  0.5881139039993286
# (dataset)error at epoch 388 is 36.66666666666667
# mbloss:  0.5874492526054382
# (dataset)error at epoch 389 is 36.66666666666667
# mbloss:  0.5867852568626404
# (dataset)error at epoch 390 is 36.66666666666667
# mbloss:  0.5861215591430664
# (dataset)error at epoch 391 is 36.66666666666667
# mbloss:  0.5854576230049133
# (dataset)error at epoch 392 is 36.66666666666667
# mbloss:  0.5847901105880737
# (dataset)error at epoch 393 is 36.66666666666667
# mbloss:  0.5841253399848938
# (dataset)error at epoch 394 is 36.66666666666667
# mbloss:  0.583463191986084
# (dataset)error at epoch 395 is 36.0
# mbloss:  0.5828009247779846
# (dataset)error at epoch 396 is 36.0
# mbloss:  0.5821410417556763
# (dataset)error at epoch 397 is 36.0
# mbloss:  0.5814835429191589
# (dataset)error at epoch 398 is 36.0
# mbloss:  0.5808268189430237
# (dataset)error at epoch 399 is 36.0
# mbloss:  0.5801729559898376
# (dataset)error at epoch 400 is 36.0
# mbloss:  0.5795210003852844
# (dataset)error at epoch 401 is 36.0
# mbloss:  0.5788707733154297
# (dataset)error at epoch 402 is 36.0
# mbloss:  0.5782238245010376
# (dataset)error at epoch 403 is 36.0
# mbloss:  0.5775783061981201
# (dataset)error at epoch 404 is 36.0
# mbloss:  0.5769369006156921
# (dataset)error at epoch 405 is 36.0
# mbloss:  0.5762972235679626
# (dataset)error at epoch 406 is 36.0
# mbloss:  0.5756616592407227
# (dataset)error at epoch 407 is 36.0
# mbloss:  0.5750287771224976
# (dataset)error at epoch 408 is 36.0
# mbloss:  0.5743994116783142
# (dataset)error at epoch 409 is 36.0
# mbloss:  0.5737740993499756
# (dataset)error at epoch 410 is 36.66666666666667
# mbloss:  0.5731545090675354
# (dataset)error at epoch 411 is 36.0
# mbloss:  0.5725356936454773
# (dataset)error at epoch 412 is 36.66666666666667
# mbloss:  0.57192462682724
# (dataset)error at epoch 413 is 36.0
# mbloss:  0.5713158249855042
# (dataset)error at epoch 414 is 36.66666666666667
# mbloss:  0.5707122683525085
# (dataset)error at epoch 415 is 36.0
# mbloss:  0.5701135993003845
# (dataset)error at epoch 416 is 36.66666666666667
# mbloss:  0.5695194602012634
# (dataset)error at epoch 417 is 36.66666666666667
# mbloss:  0.5689297318458557
# (dataset)error at epoch 418 is 36.66666666666667
# mbloss:  0.5683466792106628
# (dataset)error at epoch 419 is 36.66666666666667
# mbloss:  0.5677686333656311
# (dataset)error at epoch 420 is 36.66666666666667
# mbloss:  0.5671957731246948
# (dataset)error at epoch 421 is 36.66666666666667
# mbloss:  0.5666282773017883
# (dataset)error at epoch 422 is 36.0
# mbloss:  0.566067099571228
# (dataset)error at epoch 423 is 36.0
# mbloss:  0.5655117034912109
# (dataset)error at epoch 424 is 35.33333333333334
# mbloss:  0.5649622678756714
# (dataset)error at epoch 425 is 35.33333333333334
# mbloss:  0.564418613910675
# (dataset)error at epoch 426 is 34.66666666666667
# mbloss:  0.5638808608055115
# (dataset)error at epoch 427 is 34.0
# mbloss:  0.5633490085601807
# (dataset)error at epoch 428 is 34.0
# mbloss:  0.5628232359886169
# (dataset)error at epoch 429 is 34.0
# mbloss:  0.5623033046722412
# (dataset)error at epoch 430 is 34.0
# mbloss:  0.5617893934249878
# (dataset)error at epoch 431 is 34.0
# mbloss:  0.5612816214561462
# (dataset)error at epoch 432 is 34.0
# mbloss:  0.5607798099517822
# (dataset)error at epoch 433 is 34.0
# mbloss:  0.5602842569351196
# (dataset)error at epoch 434 is 34.0
# mbloss:  0.5597948431968689
# (dataset)error at epoch 435 is 34.0
# mbloss:  0.5593115091323853
# (dataset)error at epoch 436 is 34.0
# mbloss:  0.5588343739509583
# (dataset)error at epoch 437 is 34.0
# mbloss:  0.5583633184432983
# (dataset)error at epoch 438 is 34.0
# mbloss:  0.5578986406326294
# (dataset)error at epoch 439 is 34.0
# mbloss:  0.5574400424957275
# (dataset)error at epoch 440 is 34.0
# mbloss:  0.5569875240325928
# (dataset)error at epoch 441 is 34.0
# mbloss:  0.5565412640571594
# (dataset)error at epoch 442 is 34.0
# mbloss:  0.5561012029647827
# (dataset)error at epoch 443 is 34.0
# mbloss:  0.5556672215461731
# (dataset)error at epoch 444 is 34.0
# mbloss:  0.5552393794059753
# (dataset)error at epoch 445 is 34.0
# mbloss:  0.5548177361488342
# (dataset)error at epoch 446 is 34.0
# mbloss:  0.5544021129608154
# (dataset)error at epoch 447 is 34.0
# mbloss:  0.5539926290512085
# (dataset)error at epoch 448 is 34.0
# mbloss:  0.5535890460014343
# (dataset)error at epoch 449 is 34.0
# mbloss:  0.5531915426254272
# (dataset)error at epoch 450 is 34.0
# mbloss:  0.5528000593185425
# (dataset)error at epoch 451 is 34.0
# mbloss:  0.5524144172668457
# (dataset)error at epoch 452 is 34.0
# mbloss:  0.5520346760749817
# (dataset)error at epoch 453 is 34.0
# mbloss:  0.5516608953475952
# (dataset)error at epoch 454 is 33.33333333333334
# mbloss:  0.5512928366661072
# (dataset)error at epoch 455 is 33.33333333333334
# mbloss:  0.5509305000305176
# (dataset)error at epoch 456 is 33.33333333333334
# mbloss:  0.5505738854408264
# (dataset)error at epoch 457 is 33.33333333333334
# mbloss:  0.5502229332923889
# (dataset)error at epoch 458 is 33.33333333333334
# mbloss:  0.5498776435852051
# (dataset)error at epoch 459 is 33.33333333333334
# mbloss:  0.5495378375053406
# (dataset)error at epoch 460 is 33.33333333333334
# mbloss:  0.5492035746574402
# (dataset)error at epoch 461 is 33.33333333333334
# mbloss:  0.5488747358322144
# (dataset)error at epoch 462 is 33.33333333333334
# mbloss:  0.5485513210296631
# (dataset)error at epoch 463 is 33.33333333333334
# mbloss:  0.5482355356216431
# (dataset)error at epoch 464 is 33.33333333333334
# mbloss:  0.5479278564453125
# (dataset)error at epoch 465 is 33.33333333333334
# mbloss:  0.5476260185241699
# (dataset)error at epoch 466 is 33.33333333333334
# mbloss:  0.5473296642303467
# (dataset)error at epoch 467 is 33.33333333333334
# mbloss:  0.5470386147499084
# (dataset)error at epoch 468 is 33.33333333333334
# mbloss:  0.5467527508735657
# (dataset)error at epoch 469 is 33.33333333333334
# mbloss:  0.5464720726013184
# (dataset)error at epoch 470 is 33.33333333333334
# mbloss:  0.5461966395378113
# (dataset)error at epoch 471 is 33.33333333333334
# mbloss:  0.5459263324737549
# (dataset)error at epoch 472 is 33.33333333333334
# mbloss:  0.5456611514091492
# (dataset)error at epoch 473 is 33.33333333333334
# mbloss:  0.5454011559486389
# (dataset)error at epoch 474 is 33.33333333333334
# mbloss:  0.5451481342315674
# (dataset)error at epoch 475 is 33.33333333333334
# mbloss:  0.5449005365371704
# (dataset)error at epoch 476 is 33.33333333333334
# mbloss:  0.5446625351905823
# (dataset)error at epoch 477 is 33.33333333333334
# mbloss:  0.5444343686103821
# (dataset)error at epoch 478 is 33.33333333333334
# mbloss:  0.5442208647727966
# (dataset)error at epoch 479 is 32.0
# mbloss:  0.5440296530723572
# (dataset)error at epoch 480 is 34.0
# mbloss:  0.5438724160194397
# (dataset)error at epoch 481 is 32.0
# mbloss:  0.5437765717506409
# (dataset)error at epoch 482 is 34.66666666666667
# mbloss:  0.5437802672386169
# (dataset)error at epoch 483 is 30.666666666666657
# mbloss:  0.5439674854278564
# (dataset)error at epoch 484 is 36.0
# mbloss:  0.5444918274879456
# (dataset)error at epoch 485 is 31.33333333333333
# mbloss:  0.5456053018569946
# (dataset)error at epoch 486 is 37.33333333333333
# mbloss:  0.5479244589805603
# (dataset)error at epoch 487 is 31.33333333333333
# mbloss:  0.5521267056465149
# (dataset)error at epoch 488 is 40.0
# mbloss:  0.5607527494430542
# (dataset)error at epoch 489 is 23.33333333333333
# mbloss:  0.5744078755378723
# (dataset)error at epoch 490 is 44.666666666666664
# mbloss:  0.6015772223472595
# (dataset)error at epoch 491 is 29.33333333333333
# mbloss:  0.6312670707702637
# (dataset)error at epoch 492 is 44.666666666666664
# mbloss:  0.6825718283653259
# (dataset)error at epoch 493 is 35.33333333333334
# mbloss:  0.691024661064148
# (dataset)error at epoch 494 is 46.0
# mbloss:  0.7207265496253967
# (dataset)error at epoch 495 is 31.33333333333333
# mbloss:  0.6777361631393433
# (dataset)error at epoch 496 is 44.666666666666664
# mbloss:  0.6751574277877808
# (dataset)error at epoch 497 is 28.666666666666657
# mbloss:  0.6328950524330139
# (dataset)error at epoch 498 is 45.333333333333336
# mbloss:  0.6243513822555542
# (dataset)error at epoch 499 is 28.0
# Test error after first step of loop 1 is 28.0!
# the averaged shadow prices  of all available positions: [tensor(0.0109), tensor(0.0014)]
# Insert layer at position 0 !
# [tensor(1.8254)]
# [tensor(1.8254), tensor(1.7321)]
# [tensor(1.8254), tensor(1.7321), tensor(0.)]
# [tensor(1.8254), tensor(1.7321), tensor(0.), tensor(0.)]
# [tensor(1.8254), tensor(1.7321), tensor(0.), tensor(0.), tensor(1.7476)]
# [tensor(1.8254), tensor(1.7321), tensor(0.), tensor(0.), tensor(1.7476), tensor(1.5964)]
# [tensor(1.8254), tensor(1.7321), tensor(0.), tensor(0.), tensor(1.7476), tensor(1.5964), tensor(2.1571)]
# [tensor(1.8254), tensor(1.7321), tensor(0.), tensor(0.), tensor(1.7476), tensor(1.5964), tensor(2.1571), tensor(2.2407)]
# starting on 2. net!
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=2, out_features=3, bias=False)
#   (2): ReLU()
#   (3): ResBlock1(
#     (af1): ReLU()
#     (l1): Linear(in_features=3, out_features=3, bias=True)
#     (shortcut): Sequential()
#     (l2): Linear(in_features=3, out_features=3, bias=False)
#   )
#   (4): ResBlock1(
#     (af1): ReLU()
#     (l1): Linear(in_features=3, out_features=3, bias=True)
#     (shortcut): Sequential()
#     (l2): Linear(in_features=3, out_features=3, bias=False)
#   )
#   (5): Linear(in_features=3, out_features=2, bias=False)
# )
# mbloss:  0.6003491282463074
# (dataset)error at epoch 0 is 34.0
# mbloss:  0.5471756458282471
# (dataset)error at epoch 1 is 34.0
# mbloss:  0.5465531349182129
# (dataset)error at epoch 2 is 33.33333333333334
# mbloss:  0.5463080406188965
# (dataset)error at epoch 3 is 33.33333333333334
# mbloss:  0.5460826754570007
# (dataset)error at epoch 4 is 33.33333333333334
# mbloss:  0.545870840549469
# (dataset)error at epoch 5 is 33.33333333333334
# mbloss:  0.5456691384315491
# (dataset)error at epoch 6 is 33.33333333333334
# mbloss:  0.5454747080802917
# (dataset)error at epoch 7 is 33.33333333333334
# mbloss:  0.5452868938446045
# (dataset)error at epoch 8 is 33.33333333333334
# mbloss:  0.5451057553291321
# (dataset)error at epoch 9 is 33.33333333333334
# mbloss:  0.5449299216270447
# (dataset)error at epoch 10 is 33.33333333333334
# mbloss:  0.5447593331336975
# (dataset)error at epoch 11 is 33.33333333333334
# mbloss:  0.5445926785469055
# (dataset)error at epoch 12 is 33.33333333333334
# mbloss:  0.5444305539131165
# (dataset)error at epoch 13 is 33.33333333333334
# mbloss:  0.544272780418396
# (dataset)error at epoch 14 is 33.33333333333334
# mbloss:  0.5441187024116516
# (dataset)error at epoch 15 is 33.33333333333334
# mbloss:  0.5439679026603699
# (dataset)error at epoch 16 is 33.33333333333334
# mbloss:  0.5438191294670105
# (dataset)error at epoch 17 is 33.33333333333334
# mbloss:  0.5436720848083496
# (dataset)error at epoch 18 is 33.33333333333334
# mbloss:  0.5435279011726379
# (dataset)error at epoch 19 is 33.33333333333334
# mbloss:  0.5433864593505859
# (dataset)error at epoch 20 is 33.33333333333334
# mbloss:  0.5432471632957458
# (dataset)error at epoch 21 is 33.33333333333334
# mbloss:  0.5431092977523804
# (dataset)error at epoch 22 is 33.33333333333334
# mbloss:  0.5429736375808716
# (dataset)error at epoch 23 is 33.33333333333334
# mbloss:  0.5428395867347717
# (dataset)error at epoch 24 is 33.33333333333334
# mbloss:  0.5427083373069763
# (dataset)error at epoch 25 is 33.33333333333334
# mbloss:  0.5425769090652466
# (dataset)error at epoch 26 is 33.33333333333334
# mbloss:  0.542447566986084
# (dataset)error at epoch 27 is 33.33333333333334
# mbloss:  0.5423194169998169
# (dataset)error at epoch 28 is 33.33333333333334
# mbloss:  0.5421934127807617
# (dataset)error at epoch 29 is 33.33333333333334
# mbloss:  0.5420708656311035
# (dataset)error at epoch 30 is 33.33333333333334
# mbloss:  0.541947603225708
# (dataset)error at epoch 31 is 33.33333333333334
# mbloss:  0.5418265461921692
# (dataset)error at epoch 32 is 33.33333333333334
# mbloss:  0.541706383228302
# (dataset)error at epoch 33 is 33.33333333333334
# mbloss:  0.5415872931480408
# (dataset)error at epoch 34 is 33.33333333333334
# mbloss:  0.5414702892303467
# (dataset)error at epoch 35 is 33.33333333333334
# mbloss:  0.5413521528244019
# (dataset)error at epoch 36 is 33.33333333333334
# mbloss:  0.5412362217903137
# (dataset)error at epoch 37 is 33.33333333333334
# mbloss:  0.5411233901977539
# (dataset)error at epoch 38 is 33.33333333333334
# mbloss:  0.5410082936286926
# (dataset)error at epoch 39 is 33.33333333333334
# mbloss:  0.5408941507339478
# (dataset)error at epoch 40 is 33.33333333333334
# mbloss:  0.5407829880714417
# (dataset)error at epoch 41 is 33.33333333333334
# mbloss:  0.5406724810600281
# (dataset)error at epoch 42 is 33.33333333333334
# mbloss:  0.5405606031417847
# (dataset)error at epoch 43 is 33.33333333333334
# mbloss:  0.5404518246650696
# (dataset)error at epoch 44 is 33.33333333333334
# mbloss:  0.540344774723053
# (dataset)error at epoch 45 is 33.33333333333334
# mbloss:  0.5402351021766663
# (dataset)error at epoch 46 is 33.33333333333334
# mbloss:  0.540127694606781
# (dataset)error at epoch 47 is 33.33333333333334
# mbloss:  0.5400223731994629
# (dataset)error at epoch 48 is 33.33333333333334
# mbloss:  0.5399195551872253
# (dataset)error at epoch 49 is 33.33333333333334
# mbloss:  0.5398129224777222
# (dataset)error at epoch 50 is 33.33333333333334
# mbloss:  0.5397061109542847
# (dataset)error at epoch 51 is 33.33333333333334
# mbloss:  0.5395922064781189
# (dataset)error at epoch 52 is 33.33333333333334
# mbloss:  0.539482593536377
# (dataset)error at epoch 53 is 33.33333333333334
# mbloss:  0.5393682718276978
# (dataset)error at epoch 54 is 32.66666666666667
# mbloss:  0.5392565727233887
# (dataset)error at epoch 55 is 32.66666666666667
# mbloss:  0.539147675037384
# (dataset)error at epoch 56 is 32.66666666666667
# mbloss:  0.5390434265136719
# (dataset)error at epoch 57 is 32.66666666666667
# mbloss:  0.5389334559440613
# (dataset)error at epoch 58 is 32.66666666666667
# mbloss:  0.5388264060020447
# (dataset)error at epoch 59 is 32.66666666666667
# mbloss:  0.5387212634086609
# (dataset)error at epoch 60 is 32.66666666666667
# mbloss:  0.5386180281639099
# (dataset)error at epoch 61 is 32.66666666666667
# mbloss:  0.5385141968727112
# (dataset)error at epoch 62 is 32.66666666666667
# mbloss:  0.5384126901626587
# (dataset)error at epoch 63 is 32.66666666666667
# mbloss:  0.5383102297782898
# (dataset)error at epoch 64 is 32.66666666666667
# mbloss:  0.538210391998291
# (dataset)error at epoch 65 is 32.66666666666667
# mbloss:  0.5381093621253967
# (dataset)error at epoch 66 is 32.66666666666667
# mbloss:  0.5380105972290039
# (dataset)error at epoch 67 is 32.66666666666667
# mbloss:  0.5379113554954529
# (dataset)error at epoch 68 is 32.66666666666667
# mbloss:  0.5378141403198242
# (dataset)error at epoch 69 is 32.66666666666667
# mbloss:  0.5377157330513
# (dataset)error at epoch 70 is 32.66666666666667
# mbloss:  0.537619411945343
# (dataset)error at epoch 71 is 32.66666666666667
# mbloss:  0.5375229716300964
# (dataset)error at epoch 72 is 32.66666666666667
# mbloss:  0.5374289751052856
# (dataset)error at epoch 73 is 32.66666666666667
# mbloss:  0.5373319387435913
# (dataset)error at epoch 74 is 32.66666666666667
# mbloss:  0.5372375249862671
# (dataset)error at epoch 75 is 32.66666666666667
# mbloss:  0.5371449589729309
# (dataset)error at epoch 76 is 32.66666666666667
# mbloss:  0.5370493531227112
# (dataset)error at epoch 77 is 32.66666666666667
# mbloss:  0.5369563698768616
# (dataset)error at epoch 78 is 32.66666666666667
# mbloss:  0.5368639826774597
# (dataset)error at epoch 79 is 32.66666666666667
# mbloss:  0.5367716550827026
# (dataset)error at epoch 80 is 32.66666666666667
# mbloss:  0.5366805195808411
# (dataset)error at epoch 81 is 32.66666666666667
# mbloss:  0.5365872979164124
# (dataset)error at epoch 82 is 32.0
# mbloss:  0.5364964604377747
# (dataset)error at epoch 83 is 32.0
# mbloss:  0.5364058613777161
# (dataset)error at epoch 84 is 32.0
# mbloss:  0.5363174676895142
# (dataset)error at epoch 85 is 32.0
# mbloss:  0.5362247824668884
# (dataset)error at epoch 86 is 32.0
# mbloss:  0.5361353158950806
# (dataset)error at epoch 87 is 32.0
# mbloss:  0.5360473990440369
# (dataset)error at epoch 88 is 32.0
# mbloss:  0.5359550714492798
# (dataset)error at epoch 89 is 32.0
# mbloss:  0.5358431935310364
# (dataset)error at epoch 90 is 32.0
# mbloss:  0.5357329845428467
# (dataset)error at epoch 91 is 32.0
# mbloss:  0.5356242060661316
# (dataset)error at epoch 92 is 32.0
# mbloss:  0.5355173349380493
# (dataset)error at epoch 93 is 32.0
# mbloss:  0.5354106426239014
# (dataset)error at epoch 94 is 32.0
# mbloss:  0.535305917263031
# (dataset)error at epoch 95 is 32.0
# mbloss:  0.5351994633674622
# (dataset)error at epoch 96 is 32.0
# mbloss:  0.5350958108901978
# (dataset)error at epoch 97 is 32.0
# mbloss:  0.5349910259246826
# (dataset)error at epoch 98 is 32.0
# mbloss:  0.5348882675170898
# (dataset)error at epoch 99 is 32.0
# mbloss:  0.5347836017608643
# (dataset)error at epoch 100 is 32.0
# mbloss:  0.5346817374229431
# (dataset)error at epoch 101 is 32.0
# mbloss:  0.5345777273178101
# (dataset)error at epoch 102 is 32.0
# mbloss:  0.5344765782356262
# (dataset)error at epoch 103 is 32.0
# mbloss:  0.5343726873397827
# (dataset)error at epoch 104 is 31.33333333333333
# mbloss:  0.5342709422111511
# (dataset)error at epoch 105 is 31.33333333333333
# mbloss:  0.5341694355010986
# (dataset)error at epoch 106 is 31.33333333333333
# mbloss:  0.5340692400932312
# (dataset)error at epoch 107 is 31.33333333333333
# mbloss:  0.5339661240577698
# (dataset)error at epoch 108 is 31.33333333333333
# mbloss:  0.5338651537895203
# (dataset)error at epoch 109 is 31.33333333333333
# mbloss:  0.5337641835212708
# (dataset)error at epoch 110 is 31.33333333333333
# mbloss:  0.5336646437644958
# (dataset)error at epoch 111 is 31.33333333333333
# mbloss:  0.5335617065429688
# (dataset)error at epoch 112 is 31.33333333333333
# mbloss:  0.5334596633911133
# (dataset)error at epoch 113 is 31.33333333333333
# mbloss:  0.5333366394042969
# (dataset)error at epoch 114 is 31.33333333333333
# mbloss:  0.5332157015800476
# (dataset)error at epoch 115 is 31.33333333333333
# mbloss:  0.533093273639679
# (dataset)error at epoch 116 is 31.33333333333333
# mbloss:  0.5329760909080505
# (dataset)error at epoch 117 is 30.666666666666657
# mbloss:  0.5328536629676819
# (dataset)error at epoch 118 is 30.666666666666657
# mbloss:  0.5327344536781311
# (dataset)error at epoch 119 is 30.666666666666657
# mbloss:  0.5326157808303833
# (dataset)error at epoch 120 is 30.666666666666657
# mbloss:  0.5324974060058594
# (dataset)error at epoch 121 is 30.666666666666657
# mbloss:  0.5323792099952698
# (dataset)error at epoch 122 is 30.666666666666657
# mbloss:  0.5322611927986145
# (dataset)error at epoch 123 is 30.0
# mbloss:  0.5321432948112488
# (dataset)error at epoch 124 is 30.0
# mbloss:  0.5320254564285278
# (dataset)error at epoch 125 is 30.0
# mbloss:  0.5319074392318726
# (dataset)error at epoch 126 is 30.0
# mbloss:  0.5317893624305725
# (dataset)error at epoch 127 is 30.0
# mbloss:  0.5316712856292725
# (dataset)error at epoch 128 is 30.0
# mbloss:  0.5315531492233276
# (dataset)error at epoch 129 is 30.0
# mbloss:  0.5314348936080933
# (dataset)error at epoch 130 is 30.0
# mbloss:  0.5313158631324768
# (dataset)error at epoch 131 is 30.0
# mbloss:  0.5311967134475708
# (dataset)error at epoch 132 is 30.0
# mbloss:  0.5310764908790588
# (dataset)error at epoch 133 is 30.0
# mbloss:  0.5309523940086365
# (dataset)error at epoch 134 is 30.0
# ...
# (dataset)error at epoch 1163 is 2.0
# mbloss:  0.031151870265603065
# (dataset)error at epoch 1164 is 2.0
# mbloss:  0.03102809563279152
# (dataset)error at epoch 1165 is 2.0
# mbloss:  0.030904648825526237
# (dataset)error at epoch 1166 is 2.0
# mbloss:  0.03078162483870983
# (dataset)error at epoch 1167 is 2.0
# mbloss:  0.030658721923828125
# (dataset)error at epoch 1168 is 2.0
# mbloss:  0.030536016449332237
# (dataset)error at epoch 1169 is 2.0
# mbloss:  0.030413499101996422
# (dataset)error at epoch 1170 is 2.0
# mbloss:  0.030291106551885605
# (dataset)error at epoch 1171 is 2.0
# mbloss:  0.030168922618031502
# (dataset)error at epoch 1172 is 2.0
# mbloss:  0.030046895146369934
# (dataset)error at epoch 1173 is 2.0
# mbloss:  0.029923059046268463
# (dataset)error at epoch 1174 is 2.0
# mbloss:  0.029799748212099075
# (dataset)error at epoch 1175 is 2.0
# mbloss:  0.02967670187354088
# (dataset)error at epoch 1176 is 2.0
# mbloss:  0.02955397590994835
# (dataset)error at epoch 1177 is 2.0
# mbloss:  0.02943146415054798
# (dataset)error at epoch 1178 is 2.0
# mbloss:  0.02930924855172634
# (dataset)error at epoch 1179 is 2.0
# mbloss:  0.029187211766839027
# (dataset)error at epoch 1180 is 2.0
# mbloss:  0.029065292328596115
# (dataset)error at epoch 1181 is 2.0
# mbloss:  0.028943626210093498
# (dataset)error at epoch 1182 is 2.0
# mbloss:  0.0288222786039114
# (dataset)error at epoch 1183 is 2.0
# mbloss:  0.028701430186629295
# (dataset)error at epoch 1184 is 2.0
# mbloss:  0.02858084812760353
# (dataset)error at epoch 1185 is 2.0
# mbloss:  0.028460558503866196
# (dataset)error at epoch 1186 is 2.0
# mbloss:  0.02832944318652153
# (dataset)error at epoch 1187 is 0.6666666666666714
# mbloss:  0.026530569419264793
# (dataset)error at epoch 1188 is 0.6666666666666714
# mbloss:  0.025954706594347954
# (dataset)error at epoch 1189 is 1.3333333333333286
# mbloss:  0.025941088795661926
# (dataset)error at epoch 1190 is 0.6666666666666714
# mbloss:  0.02562766522169113
# (dataset)error at epoch 1191 is 0.6666666666666714
# mbloss:  0.02555970661342144
# (dataset)error at epoch 1192 is 0.6666666666666714
# mbloss:  0.02531883865594864
# (dataset)error at epoch 1193 is 0.6666666666666714
# mbloss:  0.02525470033288002
# (dataset)error at epoch 1194 is 0.6666666666666714
# mbloss:  0.025042925029993057
# (dataset)error at epoch 1195 is 0.6666666666666714
# mbloss:  0.02497360296547413
# (dataset)error at epoch 1196 is 0.6666666666666714
# mbloss:  0.024784347042441368
# (dataset)error at epoch 1197 is 0.6666666666666714
# mbloss:  0.02471279166638851
# (dataset)error at epoch 1198 is 0.6666666666666714
# mbloss:  0.02454044111073017
# (dataset)error at epoch 1199 is 0.6666666666666714
# mbloss:  0.02446417696774006
# (dataset)error at epoch 1200 is 0.6666666666666714
# mbloss:  0.024308819323778152
# (dataset)error at epoch 1201 is 0.6666666666666714
# mbloss:  0.02422354742884636
# (dataset)error at epoch 1202 is 0.6666666666666714
# mbloss:  0.02408456988632679
# (dataset)error at epoch 1203 is 0.6666666666666714
# mbloss:  0.023988433182239532
# (dataset)error at epoch 1204 is 0.6666666666666714
# mbloss:  0.023867633193731308
# (dataset)error at epoch 1205 is 0.6666666666666714
# mbloss:  0.023756328970193863
# (dataset)error at epoch 1206 is 0.6666666666666714
# mbloss:  0.023655777797102928
# (dataset)error at epoch 1207 is 0.6666666666666714
# mbloss:  0.0235268697142601
# (dataset)error at epoch 1208 is 0.6666666666666714
# mbloss:  0.023446792736649513
# (dataset)error at epoch 1209 is 0.6666666666666714
# mbloss:  0.023297585546970367
# (dataset)error at epoch 1210 is 0.6666666666666714
# mbloss:  0.023238729685544968
# (dataset)error at epoch 1211 is 0.6666666666666714
# mbloss:  0.02307102642953396
# (dataset)error at epoch 1212 is 0.6666666666666714
# mbloss:  0.023034708574414253
# (dataset)error at epoch 1213 is 0.6666666666666714
# mbloss:  0.022846776992082596
# (dataset)error at epoch 1214 is 0.6666666666666714
# mbloss:  0.022834086790680885
# (dataset)error at epoch 1215 is 0.6666666666666714
# mbloss:  0.022625820711255074
# (dataset)error at epoch 1216 is 0.6666666666666714
# mbloss:  0.022635167464613914
# (dataset)error at epoch 1217 is 0.6666666666666714
# mbloss:  0.022409111261367798
# (dataset)error at epoch 1218 is 0.6666666666666714
# mbloss:  0.022440126165747643
# (dataset)error at epoch 1219 is 0.6666666666666714
# mbloss:  0.022216932848095894
# (dataset)error at epoch 1220 is 0.6666666666666714
# mbloss:  0.022207632660865784
# (dataset)error at epoch 1221 is 0.6666666666666714
# mbloss:  0.02209453098475933
# (dataset)error at epoch 1222 is 0.6666666666666714
# mbloss:  0.02193642221391201
# (dataset)error at epoch 1223 is 0.6666666666666714
# mbloss:  0.02193422056734562
# (dataset)error at epoch 1224 is 0.6666666666666714
# mbloss:  0.021734103560447693
# (dataset)error at epoch 1225 is 0.6666666666666714
# mbloss:  0.0217151939868927
# (dataset)error at epoch 1226 is 0.6666666666666714
# mbloss:  0.021619869396090508
# (dataset)error at epoch 1227 is 0.6666666666666714
# mbloss:  0.02144564501941204
# (dataset)error at epoch 1228 is 0.6666666666666714
# mbloss:  0.02146958000957966
# (dataset)error at epoch 1229 is 0.6666666666666714
# mbloss:  0.021279823035001755
# (dataset)error at epoch 1230 is 0.6666666666666714
# mbloss:  0.021224016323685646
# (dataset)error at epoch 1231 is 0.6666666666666714
# mbloss:  0.02116898074746132
# (dataset)error at epoch 1232 is 0.6666666666666714
# mbloss:  0.021000005304813385
# (dataset)error at epoch 1233 is 0.6666666666666714
# mbloss:  0.020959390327334404
# (dataset)error at epoch 1234 is 0.6666666666666714
# mbloss:  0.02088978886604309
# (dataset)error at epoch 1235 is 0.6666666666666714
# mbloss:  0.02072759158909321
# (dataset)error at epoch 1236 is 0.6666666666666714
# mbloss:  0.02067713998258114
# (dataset)error at epoch 1237 is 0.6666666666666714
# mbloss:  0.020619863644242287
# (dataset)error at epoch 1238 is 0.6666666666666714
# mbloss:  0.020462440326809883
# (dataset)error at epoch 1239 is 0.6666666666666714
# mbloss:  0.020392347127199173
# (dataset)error at epoch 1240 is 0.6666666666666714
# mbloss:  0.02036091312766075
# (dataset)error at epoch 1241 is 0.6666666666666714
# mbloss:  0.020205488428473473
# (dataset)error at epoch 1242 is 0.6666666666666714
# mbloss:  0.020111577585339546
# (dataset)error at epoch 1243 is 0.6666666666666714
# mbloss:  0.02010532096028328
# (dataset)error at epoch 1244 is 0.6666666666666714
# mbloss:  0.01995113492012024
# (dataset)error at epoch 1245 is 0.6666666666666714
# mbloss:  0.019841846078634262
# (dataset)error at epoch 1246 is 0.6666666666666714
# mbloss:  0.01979721151292324
# (dataset)error at epoch 1247 is 0.6666666666666714
# mbloss:  0.019746340811252594
# (dataset)error at epoch 1248 is 0.6666666666666714
# mbloss:  0.01960764080286026
# (dataset)error at epoch 1249 is 0.6666666666666714
# mbloss:  0.019503749907016754
# (dataset)error at epoch 1250 is 0.6666666666666714
# mbloss:  0.019446033984422684
# (dataset)error at epoch 1251 is 0.6666666666666714
# mbloss:  0.01940673217177391
# (dataset)error at epoch 1252 is 0.6666666666666714
# mbloss:  0.019275037571787834
# (dataset)error at epoch 1253 is 0.6666666666666714
# mbloss:  0.019176596775650978
# (dataset)error at epoch 1254 is 0.6666666666666714
# mbloss:  0.019087517634034157
# (dataset)error at epoch 1255 is 0.6666666666666714
# mbloss:  0.01908002607524395
# (dataset)error at epoch 1256 is 0.6666666666666714
# mbloss:  0.018949614837765694
# (dataset)error at epoch 1257 is 0.6666666666666714
# mbloss:  0.01885382831096649
# (dataset)error at epoch 1258 is 0.6666666666666714
# mbloss:  0.018766917288303375
# (dataset)error at epoch 1259 is 0.6666666666666714
# mbloss:  0.01869342289865017
# (dataset)error at epoch 1260 is 0.6666666666666714
# mbloss:  0.018671033903956413
# (dataset)error at epoch 1261 is 0.6666666666666714
# mbloss:  0.018548568710684776
# (dataset)error at epoch 1262 is 0.6666666666666714
# mbloss:  0.018454506993293762
# (dataset)error at epoch 1263 is 0.6666666666666714
# mbloss:  0.018368428573012352
# (dataset)error at epoch 1264 is 0.6666666666666714
# mbloss:  0.01828618347644806
# (dataset)error at epoch 1265 is 0.6666666666666714
# mbloss:  0.01821695826947689
# (dataset)error at epoch 1266 is 0.6666666666666714
# mbloss:  0.01818614825606346
# (dataset)error at epoch 1267 is 0.6666666666666714
# mbloss:  0.018073052167892456
# (dataset)error at epoch 1268 is 0.6666666666666714
# mbloss:  0.017985155805945396
# (dataset)error at epoch 1269 is 0.6666666666666714
# mbloss:  0.017904099076986313
# (dataset)error at epoch 1270 is 0.6666666666666714
# mbloss:  0.017826227471232414
# (dataset)error at epoch 1271 is 0.6666666666666714
# mbloss:  0.017750244587659836
# (dataset)error at epoch 1272 is 0.6666666666666714
# mbloss:  0.017677778378129005
# (dataset)error at epoch 1273 is 0.6666666666666714
# mbloss:  0.017655067145824432
# (dataset)error at epoch 1274 is 0.6666666666666714
# mbloss:  0.017548011615872383
# (dataset)error at epoch 1275 is 0.6666666666666714
# mbloss:  0.017465928569436073
# (dataset)error at epoch 1276 is 0.6666666666666714
# mbloss:  0.017390532419085503
# (dataset)error at epoch 1277 is 0.6666666666666714
# mbloss:  0.017316201701760292
# (dataset)error at epoch 1278 is 0.6666666666666714
# mbloss:  0.017244592308998108
# (dataset)error at epoch 1279 is 0.6666666666666714
# mbloss:  0.017174484208226204
# (dataset)error at epoch 1280 is 0.6666666666666714
# mbloss:  0.017103543505072594
# (dataset)error at epoch 1281 is 0.6666666666666714
# mbloss:  0.017034858465194702
# (dataset)error at epoch 1282 is 0.6666666666666714
# mbloss:  0.016966311261057854
# (dataset)error at epoch 1283 is 0.6666666666666714
# mbloss:  0.01689750887453556
# (dataset)error at epoch 1284 is 0.6666666666666714
# mbloss:  0.016830626875162125
# (dataset)error at epoch 1285 is 0.6666666666666714
# mbloss:  0.016762515529990196
# (dataset)error at epoch 1286 is 0.6666666666666714
# mbloss:  0.016696685925126076
# (dataset)error at epoch 1287 is 0.6666666666666714
# mbloss:  0.016629068180918694
# (dataset)error at epoch 1288 is 0.6666666666666714
# mbloss:  0.01656433753669262
# (dataset)error at epoch 1289 is 0.6666666666666714
# mbloss:  0.016497265547513962
# (dataset)error at epoch 1290 is 0.6666666666666714
# mbloss:  0.01643332466483116
# (dataset)error at epoch 1291 is 0.6666666666666714
# mbloss:  0.016367187723517418
# (dataset)error at epoch 1292 is 0.6666666666666714
# mbloss:  0.01630428060889244
# (dataset)error at epoch 1293 is 0.6666666666666714
# mbloss:  0.016238868236541748
# (dataset)error at epoch 1294 is 0.6666666666666714
# mbloss:  0.016175758093595505
# (dataset)error at epoch 1295 is 0.6666666666666714
# mbloss:  0.016112802550196648
# (dataset)error at epoch 1296 is 0.6666666666666714
# mbloss:  0.016049224883317947
# (dataset)error at epoch 1297 is 0.6666666666666714
# mbloss:  0.015987476333975792
# (dataset)error at epoch 1298 is 0.6666666666666714
# mbloss:  0.01592406816780567
# (dataset)error at epoch 1299 is 0.6666666666666714
# mbloss:  0.015863562002778053
# (dataset)error at epoch 1300 is 0.6666666666666714
# mbloss:  0.015799541026353836
# (dataset)error at epoch 1301 is 0.6666666666666714
# mbloss:  0.015736203640699387
# (dataset)error at epoch 1302 is 0.6666666666666714
# mbloss:  0.015672288835048676
# (dataset)error at epoch 1303 is 0.6666666666666714
# mbloss:  0.015609350986778736
# (dataset)error at epoch 1304 is 0.6666666666666714
# mbloss:  0.015546845272183418
# (dataset)error at epoch 1305 is 0.6666666666666714
# mbloss:  0.015484538860619068
# (dataset)error at epoch 1306 is 0.6666666666666714
# mbloss:  0.01542104221880436
# (dataset)error at epoch 1307 is 0.6666666666666714
# mbloss:  0.01535843126475811
# (dataset)error at epoch 1308 is 0.6666666666666714
# mbloss:  0.015296362340450287
# (dataset)error at epoch 1309 is 0.6666666666666714
# mbloss:  0.015234744176268578
# (dataset)error at epoch 1310 is 0.6666666666666714
# mbloss:  0.015173378400504589
# (dataset)error at epoch 1311 is 0.6666666666666714
# mbloss:  0.015112166292965412
# (dataset)error at epoch 1312 is 0.6666666666666714
# mbloss:  0.015049836598336697
# (dataset)error at epoch 1313 is 0.6666666666666714
# mbloss:  0.014988470822572708
# (dataset)error at epoch 1314 is 0.6666666666666714
# mbloss:  0.014927519485354424
# (dataset)error at epoch 1315 is 0.6666666666666714
# mbloss:  0.014866963028907776
# (dataset)error at epoch 1316 is 0.6666666666666714
# mbloss:  0.014807249419391155
# (dataset)error at epoch 1317 is 0.6666666666666714
# mbloss:  0.014748378656804562
# (dataset)error at epoch 1318 is 0.6666666666666714
# mbloss:  0.014688273891806602
# (dataset)error at epoch 1319 is 0.6666666666666714
# mbloss:  0.014629106968641281
# (dataset)error at epoch 1320 is 0.6666666666666714
# mbloss:  0.014570856466889381
# (dataset)error at epoch 1321 is 0.6666666666666714
# mbloss:  0.014513595029711723
# (dataset)error at epoch 1322 is 0.6666666666666714
# mbloss:  0.014454750344157219
# (dataset)error at epoch 1323 is 0.6666666666666714
# mbloss:  0.014397415332496166
# (dataset)error at epoch 1324 is 0.6666666666666714
# mbloss:  0.014341413043439388
# (dataset)error at epoch 1325 is 0.6666666666666714
# mbloss:  0.014283609576523304
# (dataset)error at epoch 1326 is 0.6666666666666714
# mbloss:  0.014227484352886677
# (dataset)error at epoch 1327 is 0.6666666666666714
# mbloss:  0.014172375202178955
# (dataset)error at epoch 1328 is 0.6666666666666714
# mbloss:  0.014115417376160622
# (dataset)error at epoch 1329 is 0.6666666666666714
# mbloss:  0.014060732908546925
# (dataset)error at epoch 1330 is 0.6666666666666714
# mbloss:  0.014006238430738449
# (dataset)error at epoch 1331 is 0.6666666666666714
# mbloss:  0.013950537890195847
# (dataset)error at epoch 1332 is 0.6666666666666714
# mbloss:  0.013897452503442764
# (dataset)error at epoch 1333 is 0.6666666666666714
# mbloss:  0.013842003419995308
# (dataset)error at epoch 1334 is 0.6666666666666714
# mbloss:  0.013788992539048195
# (dataset)error at epoch 1335 is 0.6666666666666714
# mbloss:  0.013735064305365086
# (dataset)error at epoch 1336 is 0.6666666666666714
# mbloss:  0.013680840842425823
# (dataset)error at epoch 1337 is 0.6666666666666714
# mbloss:  0.013628058135509491
# (dataset)error at epoch 1338 is 0.6666666666666714
# mbloss:  0.013574305921792984
# (dataset)error at epoch 1339 is 0.6666666666666714
# mbloss:  0.013522392138838768
# (dataset)error at epoch 1340 is 0.6666666666666714
# mbloss:  0.013469133526086807
# (dataset)error at epoch 1341 is 0.6666666666666714
# mbloss:  0.013417973183095455
# (dataset)error at epoch 1342 is 0.6666666666666714
# mbloss:  0.01336513739079237
# (dataset)error at epoch 1343 is 0.6666666666666714
# mbloss:  0.013314797542989254
# (dataset)error at epoch 1344 is 0.6666666666666714
# mbloss:  0.013262397609651089
# (dataset)error at epoch 1345 is 0.6666666666666714
# mbloss:  0.01321286428719759
# (dataset)error at epoch 1346 is 0.6666666666666714
# mbloss:  0.013160999864339828
# (dataset)error at epoch 1347 is 0.6666666666666714
# mbloss:  0.013112062588334084
# (dataset)error at epoch 1348 is 0.6666666666666714
# mbloss:  0.013060693629086018
# (dataset)error at epoch 1349 is 0.6666666666666714
# mbloss:  0.013012182898819447
# (dataset)error at epoch 1350 is 0.6666666666666714
# mbloss:  0.012960359454154968
# (dataset)error at epoch 1351 is 0.6666666666666714
# mbloss:  0.012911341153085232
# (dataset)error at epoch 1352 is 0.6666666666666714
# mbloss:  0.012860382907092571
# (dataset)error at epoch 1353 is 0.6666666666666714
# mbloss:  0.012811784632503986
# (dataset)error at epoch 1354 is 0.6666666666666714
# mbloss:  0.012761604972183704
# (dataset)error at epoch 1355 is 0.0
# Test error of loop 2 is 0.0!
# The final model has the architecture: Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=2, out_features=3, bias=False)
#   (2): ReLU()
#   (3): ResBlock1(
#     (af1): ReLU()
#     (l1): Linear(in_features=3, out_features=3, bias=True)
#     (shortcut): Sequential()
#     (l2): Linear(in_features=3, out_features=3, bias=False)
#   )
#   (4): ResBlock1(
#     (af1): ReLU()
#     (l1): Linear(in_features=3, out_features=3, bias=True)
#     (shortcut): Sequential()
#     (l2): Linear(in_features=3, out_features=3, bias=False)
#   )
#   (5): Linear(in_features=3, out_features=2, bias=False)
# )
# norm of values of parameters (parameter-wise) at layer insertion: [tensor(1.8254), tensor(1.7321), tensor(0.), tensor(0.), tensor(1.7476), tensor(1.5964), tensor(2.1571), tensor(2.2407)]

# %%
if T1:
    print('test error: ',check_testerror(vd, model1))
    train_acc = check_testerror(td, model1)
    print('train error: ',train_acc)
# Out:
# test error:  0.0
# train error:  0.44444444444444287

# %%
if T1:
    #plot_decision_boundary(model1, X_small,y_small)
    plot_decision_boundary(model1,data_X,data_y)

# %% [markdown]
# plot results:

# %%
end_list=[]
for i,e in enumerate(epochs):
    end_list.append(int(e*len(td)))
    end_list.append(1) 
end_list.pop() # removes last 1 which was too much

# todo plot
if T1:
    plt.figure(figsize=(20,5))
    plt.grid(which='major', axis='x', zorder=-1.0)
    xfull = range(1,len(mb_losses1)+1)
    yfull = mb_losses1
    begin=0
    end=0
    for i in range(len(end_list)):
        end=end+end_list[i]
        x_curr= xfull[begin:end]
        y_curr= yfull[begin:end]
        begin=end
        plt.plot(x_curr,y_curr,'o')
    plt.xlabel('minibatch iterations')
    plt.ylabel('minibatch loss')

    plt.yscale('log')
    #plt.ylim((0.4,.6))
    #plt.xlim((99300,99800))
    
    plt.grid()
    plt.plot(np.zeros(len(mb_losses1)))

# %%
#print(len(grad_norms1[1]))

# %%
if True:
    plt.figure(figsize=(20,5))
    l1 = len(grad_norms1[0])
    l2 = len(grad_norms1[1])
    len_t1 = len(grad_norms1[0][0])
    len_t2 = len(grad_norms1[1][0])
    for i in range(l1):
        plt.plot(grad_norms1[0][i], label=f'0_{i}')
    for j in range(l2):
        #print(list(range(len_t1,len_t2+len_t1)))
        plt.plot(list(range(len_t1,len_t2+len_t1)), grad_norms1[1][j], label=f'1_{j}')
    plt.legend()
    plt.yscale('log')
    plt.xlabel('iterations')
    plt.ylabel('layerwise gradient norms scaled by lr')
    #plt.xlim(900,1100)

# %%
# todo plot
if False:
    plt.figure(figsize=(20,5))
    plt.grid(which='major', axis='x', zorder=-1.0)
    xfull = range(1,len(grad_norms1)+1)
    yfull = grad_norms1
    begin=0
    end=0
    for i in range(len(end_list)):
        end=end+end_list[i]
        x_curr= xfull[begin:end]
        y_curr= yfull[begin:end]
        begin=end
        plt.plot(x_curr,y_curr,'o')
    plt.xlabel('minibatch iterations')
    plt.ylabel('squared grad norm')

    plt.yscale('log')
    #plt.ylim((0.4,.6))
    #plt.xlim((99300,99800))
    
    plt.grid()
    plt.plot(np.zeros(len(grad_norms1)))

# %%
plt.figure(figsize=(20,5))
plt.plot([initial_train_acc]+test_errors1)#,'o')
plt.ylim(top=100,bottom=0)
plt.grid()
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# ## Second training

# %%
# build net
if _type=='fwd':
    model_init2 = feed_forward(dim_in, dim_out,**kwargs_net)
if _type=='res2':
    model_init2 = two_weight_resnet(dim_in, dim_out,**kwargs_net)
if _type=='res1':
    model_init2 = one_weight_resnet(dim_in, dim_out,**kwargs_net)

torch.nn.utils.vector_to_parameters(param_init, model_init2.parameters())

# %%
print(check_testerror(vd,model_init2))
initial_train_acc2 = check_testerror(td,model_init2)
print(check_testerror(td,model_init2))
# Out:
# 48.0
# 46.44444444444444

# %%
if T2:
    model2, mb_losses2, test_errors_short2, test_errors2, exit_flag2, grad_norms2, times2 = layer_insertion_loop(
        iters=no_iters,
        epochs=epochs,
        model= model_init2,
        kwargs_net=kwargs_net,
        dim_in=dim_in,
        dim_out=dim_out,
        train_dataloader=td,
        test_dataloader=vd,
        lr_init=lr_init,
        wanted_test_error=wanted_testerror,
        mode='abs min',#'threshold',
        optimizer_type=optimizer_type,
        lrschedule_type=lrscheduler_type,
        lrscheduler_args=lrscheduler_args,
        check_testerror_between=interval_testerror,
        decrease_after_li=lr_decrease_after_li,
        print_param_flag=False,
        start_with_backtracking=None,
        v2=False,
        save_grad_norms=save_grad_norms
    )
# Out:
# starting on 1. net !
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=2, out_features=3, bias=False)
#   (2): ReLU()
#   (3): ResBlock1(
#     (af1): ReLU()
#     (l1): Linear(in_features=3, out_features=3, bias=True)
#     (shortcut): Sequential()
#     (l2): Linear(in_features=3, out_features=3, bias=False)
#   )
#   (4): Linear(in_features=3, out_features=2, bias=False)
# )
# mbloss:  0.6812914609909058
# (dataset)error at epoch 0 is 48.0
# mbloss:  0.6809449791908264
# (dataset)error at epoch 1 is 49.33333333333333
# mbloss:  0.6806014180183411
# (dataset)error at epoch 2 is 50.0
# mbloss:  0.6802606582641602
# (dataset)error at epoch 3 is 49.33333333333333
# mbloss:  0.6799336075782776
# (dataset)error at epoch 4 is 49.33333333333333
# mbloss:  0.6796112060546875
# (dataset)error at epoch 5 is 49.33333333333333
# mbloss:  0.6792930960655212
# (dataset)error at epoch 6 is 49.33333333333333
# mbloss:  0.6789785027503967
# (dataset)error at epoch 7 is 49.33333333333333
# mbloss:  0.6786664724349976
# (dataset)error at epoch 8 is 49.33333333333333
# mbloss:  0.6783586144447327
# (dataset)error at epoch 9 is 48.66666666666667
# mbloss:  0.6780556440353394
# (dataset)error at epoch 10 is 48.66666666666667
# mbloss:  0.6777569651603699
# (dataset)error at epoch 11 is 50.0
# mbloss:  0.6774619817733765
# (dataset)error at epoch 12 is 50.0
# mbloss:  0.6771703958511353
# (dataset)error at epoch 13 is 50.0
# mbloss:  0.676883339881897
# (dataset)error at epoch 14 is 50.0
# mbloss:  0.6766005158424377
# (dataset)error at epoch 15 is 50.0
# mbloss:  0.6763216853141785
# (dataset)error at epoch 16 is 50.0
# mbloss:  0.6760468482971191
# (dataset)error at epoch 17 is 50.0
# mbloss:  0.6757757663726807
# (dataset)error at epoch 18 is 50.0
# mbloss:  0.6755099892616272
# (dataset)error at epoch 19 is 50.0
# mbloss:  0.6752497553825378
# (dataset)error at epoch 20 is 50.0
# mbloss:  0.6749962568283081
# (dataset)error at epoch 21 is 50.666666666666664
# mbloss:  0.6747470498085022
# (dataset)error at epoch 22 is 50.666666666666664
# mbloss:  0.6745008230209351
# (dataset)error at epoch 23 is 50.666666666666664
# mbloss:  0.6742583513259888
# (dataset)error at epoch 24 is 50.666666666666664
# mbloss:  0.6740186810493469
# (dataset)error at epoch 25 is 50.666666666666664
# mbloss:  0.673783540725708
# (dataset)error at epoch 26 is 50.666666666666664
# mbloss:  0.6735514998435974
# (dataset)error at epoch 27 is 51.33333333333333
# mbloss:  0.6733242869377136
# (dataset)error at epoch 28 is 51.33333333333333
# mbloss:  0.6731002926826477
# (dataset)error at epoch 29 is 51.33333333333333
# mbloss:  0.672876238822937
# (dataset)error at epoch 30 is 52.0
# mbloss:  0.6726546883583069
# (dataset)error at epoch 31 is 52.0
# mbloss:  0.672435998916626
# (dataset)error at epoch 32 is 52.0
# mbloss:  0.6722186207771301
# (dataset)error at epoch 33 is 52.0
# mbloss:  0.6720051169395447
# (dataset)error at epoch 34 is 52.0
# mbloss:  0.6717926859855652
# (dataset)error at epoch 35 is 52.0
# mbloss:  0.6715804934501648
# (dataset)error at epoch 36 is 52.0
# mbloss:  0.6713688373565674
# (dataset)error at epoch 37 is 52.0
# mbloss:  0.6711567640304565
# (dataset)error at epoch 38 is 52.0
# mbloss:  0.6709426045417786
# (dataset)error at epoch 39 is 52.666666666666664
# mbloss:  0.6707176566123962
# (dataset)error at epoch 40 is 52.0
# mbloss:  0.6704819798469543
# (dataset)error at epoch 41 is 52.0
# mbloss:  0.6702431440353394
# (dataset)error at epoch 42 is 51.33333333333333
# mbloss:  0.6700035333633423
# (dataset)error at epoch 43 is 51.33333333333333
# mbloss:  0.6697593927383423
# (dataset)error at epoch 44 is 51.33333333333333
# mbloss:  0.6695136427879333
# (dataset)error at epoch 45 is 51.33333333333333
# mbloss:  0.6692604422569275
# (dataset)error at epoch 46 is 51.33333333333333
# mbloss:  0.6689901947975159
# (dataset)error at epoch 47 is 51.33333333333333
# mbloss:  0.6687140464782715
# (dataset)error at epoch 48 is 51.33333333333333
# mbloss:  0.668437659740448
# (dataset)error at epoch 49 is 51.33333333333333
# mbloss:  0.6681627631187439
# (dataset)error at epoch 50 is 50.666666666666664
# mbloss:  0.6678860187530518
# (dataset)error at epoch 51 is 50.666666666666664
# mbloss:  0.6676080822944641
# (dataset)error at epoch 52 is 51.33333333333333
# mbloss:  0.6673297882080078
# (dataset)error at epoch 53 is 51.33333333333333
# mbloss:  0.6670528054237366
# (dataset)error at epoch 54 is 51.33333333333333
# mbloss:  0.666779637336731
# (dataset)error at epoch 55 is 51.33333333333333
# mbloss:  0.6665369868278503
# (dataset)error at epoch 56 is 51.33333333333333
# mbloss:  0.6663160920143127
# (dataset)error at epoch 57 is 51.33333333333333
# mbloss:  0.6661087870597839
# (dataset)error at epoch 58 is 51.33333333333333
# mbloss:  0.6659088134765625
# (dataset)error at epoch 59 is 51.33333333333333
# mbloss:  0.6657176613807678
# (dataset)error at epoch 60 is 50.666666666666664
# mbloss:  0.6655365824699402
# (dataset)error at epoch 61 is 51.33333333333333
# mbloss:  0.6653650999069214
# (dataset)error at epoch 62 is 51.33333333333333
# mbloss:  0.6652003526687622
# (dataset)error at epoch 63 is 52.0
# mbloss:  0.6650424599647522
# (dataset)error at epoch 64 is 52.0
# mbloss:  0.6648908853530884
# (dataset)error at epoch 65 is 52.666666666666664
# mbloss:  0.6647430658340454
# (dataset)error at epoch 66 is 52.666666666666664
# mbloss:  0.6645971536636353
# (dataset)error at epoch 67 is 50.666666666666664
# mbloss:  0.6644572019577026
# (dataset)error at epoch 68 is 50.666666666666664
# mbloss:  0.6643226742744446
# (dataset)error at epoch 69 is 50.666666666666664
# mbloss:  0.6641941070556641
# (dataset)error at epoch 70 is 50.666666666666664
# mbloss:  0.6640707850456238
# (dataset)error at epoch 71 is 50.666666666666664
# mbloss:  0.6639522910118103
# (dataset)error at epoch 72 is 50.666666666666664
# mbloss:  0.6638365387916565
# (dataset)error at epoch 73 is 50.666666666666664
# mbloss:  0.6637253165245056
# (dataset)error at epoch 74 is 50.666666666666664
# mbloss:  0.6636163592338562
# (dataset)error at epoch 75 is 50.666666666666664
# mbloss:  0.6635102033615112
# (dataset)error at epoch 76 is 50.666666666666664
# mbloss:  0.6634098887443542
# (dataset)error at epoch 77 is 50.666666666666664
# mbloss:  0.6633114814758301
# (dataset)error at epoch 78 is 50.666666666666664
# mbloss:  0.6632151007652283
# (dataset)error at epoch 79 is 50.666666666666664
# mbloss:  0.6631227731704712
# (dataset)error at epoch 80 is 50.666666666666664
# mbloss:  0.6630330681800842
# (dataset)error at epoch 81 is 50.666666666666664
# mbloss:  0.6629466414451599
# (dataset)error at epoch 82 is 50.666666666666664
# mbloss:  0.6628617644309998
# (dataset)error at epoch 83 is 50.666666666666664
# mbloss:  0.6627793312072754
# (dataset)error at epoch 84 is 50.666666666666664
# mbloss:  0.6626997590065002
# (dataset)error at epoch 85 is 50.666666666666664
# mbloss:  0.6626211404800415
# (dataset)error at epoch 86 is 50.666666666666664
# mbloss:  0.6625438928604126
# (dataset)error at epoch 87 is 50.666666666666664
# mbloss:  0.6624693274497986
# (dataset)error at epoch 88 is 50.666666666666664
# mbloss:  0.6623978018760681
# (dataset)error at epoch 89 is 50.666666666666664
# mbloss:  0.6623286008834839
# (dataset)error at epoch 90 is 50.666666666666664
# mbloss:  0.6622602939605713
# (dataset)error at epoch 91 is 50.666666666666664
# mbloss:  0.6621894240379333
# (dataset)error at epoch 92 is 50.666666666666664
# mbloss:  0.6621197462081909
# (dataset)error at epoch 93 is 50.666666666666664
# mbloss:  0.6620516777038574
# (dataset)error at epoch 94 is 50.666666666666664
# mbloss:  0.6619848608970642
# (dataset)error at epoch 95 is 50.666666666666664
# mbloss:  0.6619188785552979
# (dataset)error at epoch 96 is 50.666666666666664
# mbloss:  0.6618533134460449
# (dataset)error at epoch 97 is 50.666666666666664
# mbloss:  0.6617885828018188
# (dataset)error at epoch 98 is 50.666666666666664
# mbloss:  0.6617271304130554
# (dataset)error at epoch 99 is 50.666666666666664
# mbloss:  0.6616677045822144
# (dataset)error at epoch 100 is 50.666666666666664
# mbloss:  0.6616091132164001
# (dataset)error at epoch 101 is 50.666666666666664
# mbloss:  0.6615512371063232
# (dataset)error at epoch 102 is 50.666666666666664
# mbloss:  0.6614940762519836
# (dataset)error at epoch 103 is 50.666666666666664
# mbloss:  0.661437451839447
# (dataset)error at epoch 104 is 50.666666666666664
# mbloss:  0.6613817811012268
# (dataset)error at epoch 105 is 50.666666666666664
# mbloss:  0.6613259315490723
# (dataset)error at epoch 106 is 50.666666666666664
# mbloss:  0.6612705588340759
# (dataset)error at epoch 107 is 50.666666666666664
# mbloss:  0.6612155437469482
# (dataset)error at epoch 108 is 50.666666666666664
# mbloss:  0.6611608862876892
# (dataset)error at epoch 109 is 50.666666666666664
# mbloss:  0.6611078381538391
# (dataset)error at epoch 110 is 50.666666666666664
# mbloss:  0.6610550284385681
# (dataset)error at epoch 111 is 50.666666666666664
# mbloss:  0.6610022783279419
# (dataset)error at epoch 112 is 50.666666666666664
# mbloss:  0.6609498262405396
# (dataset)error at epoch 113 is 50.666666666666664
# mbloss:  0.6608975529670715
# (dataset)error at epoch 114 is 50.666666666666664
# mbloss:  0.6608452796936035
# (dataset)error at epoch 115 is 50.666666666666664
# mbloss:  0.6607940196990967
# (dataset)error at epoch 116 is 50.666666666666664
# mbloss:  0.6607433557510376
# (dataset)error at epoch 117 is 50.666666666666664
# mbloss:  0.6606910824775696
# (dataset)error at epoch 118 is 50.666666666666664
# mbloss:  0.6606312990188599
# (dataset)error at epoch 119 is 50.666666666666664
# mbloss:  0.660571813583374
# (dataset)error at epoch 120 is 50.666666666666664
# mbloss:  0.6605126261711121
# (dataset)error at epoch 121 is 50.666666666666664
# mbloss:  0.6604532599449158
# (dataset)error at epoch 122 is 50.666666666666664
# mbloss:  0.6603940725326538
# (dataset)error at epoch 123 is 50.666666666666664
# mbloss:  0.6603354215621948
# (dataset)error at epoch 124 is 50.666666666666664
# mbloss:  0.6602776646614075
# (dataset)error at epoch 125 is 50.666666666666664
# mbloss:  0.6602203249931335
# (dataset)error at epoch 126 is 50.666666666666664
# mbloss:  0.6601631045341492
# (dataset)error at epoch 127 is 50.666666666666664
# mbloss:  0.6601089835166931
# (dataset)error at epoch 128 is 50.666666666666664
# mbloss:  0.6600577235221863
# (dataset)error at epoch 129 is 50.666666666666664
# mbloss:  0.6600061655044556
# (dataset)error at epoch 130 is 50.666666666666664
# mbloss:  0.6599541306495667
# (dataset)error at epoch 131 is 50.666666666666664
# mbloss:  0.6599017977714539
# (dataset)error at epoch 132 is 50.666666666666664
# mbloss:  0.6598491072654724
# (dataset)error at epoch 133 is 50.666666666666664
# mbloss:  0.6597961187362671
# (dataset)error at epoch 134 is 50.666666666666664
# mbloss:  0.6597426533699036
# (dataset)error at epoch 135 is 50.666666666666664
# mbloss:  0.6596889495849609
# (dataset)error at epoch 136 is 50.666666666666664
# mbloss:  0.6596354246139526
# (dataset)error at epoch 137 is 50.666666666666664
# mbloss:  0.6595814228057861
# (dataset)error at epoch 138 is 50.666666666666664
# mbloss:  0.6595271229743958
# (dataset)error at epoch 139 is 50.666666666666664
# mbloss:  0.6594723463058472
# (dataset)error at epoch 140 is 50.666666666666664
# mbloss:  0.6594171524047852
# (dataset)error at epoch 141 is 50.666666666666664
# mbloss:  0.6593616008758545
# (dataset)error at epoch 142 is 50.666666666666664
# mbloss:  0.6593053936958313
# (dataset)error at epoch 143 is 50.666666666666664
# mbloss:  0.6592488884925842
# (dataset)error at epoch 144 is 50.666666666666664
# mbloss:  0.659191906452179
# (dataset)error at epoch 145 is 50.666666666666664
# mbloss:  0.6591343283653259
# (dataset)error at epoch 146 is 50.666666666666664
# mbloss:  0.6590763926506042
# (dataset)error at epoch 147 is 50.666666666666664
# mbloss:  0.65901780128479
# (dataset)error at epoch 148 is 50.666666666666664
# mbloss:  0.6589587330818176
# (dataset)error at epoch 149 is 50.666666666666664
# mbloss:  0.658899188041687
# (dataset)error at epoch 150 is 50.666666666666664
# mbloss:  0.6588389873504639
# (dataset)error at epoch 151 is 50.666666666666664
# mbloss:  0.6587784886360168
# (dataset)error at epoch 152 is 50.666666666666664
# mbloss:  0.658717691898346
# (dataset)error at epoch 153 is 50.666666666666664
# mbloss:  0.658656120300293
# (dataset)error at epoch 154 is 50.666666666666664
# mbloss:  0.6585939526557922
# (dataset)error at epoch 155 is 50.666666666666664
# mbloss:  0.6585313081741333
# (dataset)error at epoch 156 is 50.666666666666664
# mbloss:  0.6584679484367371
# (dataset)error at epoch 157 is 50.666666666666664
# mbloss:  0.6584040522575378
# (dataset)error at epoch 158 is 50.666666666666664
# mbloss:  0.658339262008667
# (dataset)error at epoch 159 is 50.666666666666664
# mbloss:  0.6582731604576111
# (dataset)error at epoch 160 is 50.666666666666664
# mbloss:  0.6582065224647522
# (dataset)error at epoch 161 is 50.666666666666664
# mbloss:  0.6581392884254456
# (dataset)error at epoch 162 is 50.666666666666664
# mbloss:  0.6580722332000732
# (dataset)error at epoch 163 is 50.666666666666664
# mbloss:  0.6580045819282532
# (dataset)error at epoch 164 is 50.666666666666664
# mbloss:  0.6579362750053406
# (dataset)error at epoch 165 is 50.666666666666664
# mbloss:  0.6578673124313354
# (dataset)error at epoch 166 is 50.666666666666664
# mbloss:  0.657797634601593
# (dataset)error at epoch 167 is 50.666666666666664
# mbloss:  0.6577276587486267
# (dataset)error at epoch 168 is 50.666666666666664
# mbloss:  0.6576573252677917
# (dataset)error at epoch 169 is 50.666666666666664
# mbloss:  0.6575860977172852
# (dataset)error at epoch 170 is 50.666666666666664
# mbloss:  0.6575143337249756
# (dataset)error at epoch 171 is 50.666666666666664
# mbloss:  0.6574417352676392
# (dataset)error at epoch 172 is 50.666666666666664
# mbloss:  0.6573684811592102
# (dataset)error at epoch 173 is 50.666666666666664
# mbloss:  0.657294511795044
# (dataset)error at epoch 174 is 50.666666666666664
# mbloss:  0.6572197675704956
# (dataset)error at epoch 175 is 50.666666666666664
# mbloss:  0.6571445465087891
# (dataset)error at epoch 176 is 50.666666666666664
# mbloss:  0.6570688486099243
# (dataset)error at epoch 177 is 50.666666666666664
# mbloss:  0.6569921970367432
# (dataset)error at epoch 178 is 50.666666666666664
# mbloss:  0.6569148302078247
# (dataset)error at epoch 179 is 50.666666666666664
# mbloss:  0.656836748123169
# (dataset)error at epoch 180 is 50.666666666666664
# mbloss:  0.6567578911781311
# (dataset)error at epoch 181 is 50.666666666666664
# mbloss:  0.6566781997680664
# (dataset)error at epoch 182 is 50.666666666666664
# mbloss:  0.6565976738929749
# (dataset)error at epoch 183 is 50.666666666666664
# mbloss:  0.656516432762146
# (dataset)error at epoch 184 is 50.666666666666664
# mbloss:  0.6564342379570007
# (dataset)error at epoch 185 is 50.666666666666664
# mbloss:  0.6563512682914734
# (dataset)error at epoch 186 is 50.666666666666664
# mbloss:  0.6562673449516296
# (dataset)error at epoch 187 is 50.666666666666664
# mbloss:  0.6561825275421143
# (dataset)error at epoch 188 is 50.666666666666664
# mbloss:  0.6560968160629272
# (dataset)error at epoch 189 is 50.666666666666664
# mbloss:  0.6560101509094238
# (dataset)error at epoch 190 is 50.666666666666664
# mbloss:  0.6559222936630249
# (dataset)error at epoch 191 is 50.666666666666664
# mbloss:  0.6558334231376648
# (dataset)error at epoch 192 is 50.666666666666664
# mbloss:  0.6557433009147644
# (dataset)error at epoch 193 is 50.666666666666664
# mbloss:  0.655652642250061
# (dataset)error at epoch 194 is 50.666666666666664
# mbloss:  0.655561089515686
# (dataset)error at epoch 195 is 50.0
# mbloss:  0.6554687023162842
# (dataset)error at epoch 196 is 50.0
# mbloss:  0.6553750038146973
# (dataset)error at epoch 197 is 50.0
# mbloss:  0.6552804708480835
# (dataset)error at epoch 198 is 50.0
# mbloss:  0.6551849842071533
# (dataset)error at epoch 199 is 50.0
# mbloss:  0.6550886631011963
# (dataset)error at epoch 200 is 50.0
# mbloss:  0.6549912691116333
# (dataset)error at epoch 201 is 50.0
# mbloss:  0.6548928022384644
# (dataset)error at epoch 202 is 50.0
# mbloss:  0.654793381690979
# (dataset)error at epoch 203 is 50.0
# mbloss:  0.6546928286552429
# (dataset)error at epoch 204 is 50.0
# mbloss:  0.6545911431312561
# (dataset)error at epoch 205 is 50.0
# mbloss:  0.6544883847236633
# (dataset)error at epoch 206 is 50.0
# mbloss:  0.6543844938278198
# (dataset)error at epoch 207 is 50.0
# mbloss:  0.654279351234436
# (dataset)error at epoch 208 is 50.0
# mbloss:  0.6541732549667358
# (dataset)error at epoch 209 is 50.0
# mbloss:  0.654065728187561
# (dataset)error at epoch 210 is 50.0
# mbloss:  0.6539571285247803
# (dataset)error at epoch 211 is 50.0
# mbloss:  0.6538471579551697
# (dataset)error at epoch 212 is 50.0
# mbloss:  0.6537359356880188
# (dataset)error at epoch 213 is 50.0
# mbloss:  0.6536234617233276
# (dataset)error at epoch 214 is 50.0
# mbloss:  0.6535096764564514
# (dataset)error at epoch 215 is 50.0
# mbloss:  0.6533945202827454
# (dataset)error at epoch 216 is 50.0
# mbloss:  0.6532779335975647
# (dataset)error at epoch 217 is 50.0
# mbloss:  0.6531597971916199
# (dataset)error at epoch 218 is 50.0
# mbloss:  0.6530393958091736
# (dataset)error at epoch 219 is 50.0
# mbloss:  0.6529176831245422
# (dataset)error at epoch 220 is 50.0
# mbloss:  0.6527947783470154
# (dataset)error at epoch 221 is 50.0
# mbloss:  0.6526704430580139
# (dataset)error at epoch 222 is 50.0
# mbloss:  0.6525446176528931
# (dataset)error at epoch 223 is 50.0
# mbloss:  0.6524173021316528
# (dataset)error at epoch 224 is 50.0
# mbloss:  0.6522884964942932
# (dataset)error at epoch 225 is 50.0
# mbloss:  0.6521582007408142
# (dataset)error at epoch 226 is 50.0
# mbloss:  0.6520261764526367
# (dataset)error at epoch 227 is 50.0
# mbloss:  0.6518926620483398
# (dataset)error at epoch 228 is 50.0
# mbloss:  0.6517574787139893
# (dataset)error at epoch 229 is 50.0
# mbloss:  0.6516205668449402
# (dataset)error at epoch 230 is 50.0
# mbloss:  0.6514819264411926
# (dataset)error at epoch 231 is 50.0
# mbloss:  0.6513416171073914
# (dataset)error at epoch 232 is 49.33333333333333
# mbloss:  0.651199460029602
# (dataset)error at epoch 233 is 49.33333333333333
# mbloss:  0.6510555148124695
# (dataset)error at epoch 234 is 49.33333333333333
# mbloss:  0.6509097814559937
# (dataset)error at epoch 235 is 49.33333333333333
# mbloss:  0.650762140750885
# (dataset)error at epoch 236 is 49.33333333333333
# mbloss:  0.6506126523017883
# (dataset)error at epoch 237 is 49.33333333333333
# mbloss:  0.6504611372947693
# (dataset)error at epoch 238 is 49.33333333333333
# mbloss:  0.6503082513809204
# (dataset)error at epoch 239 is 49.33333333333333
# mbloss:  0.6501538753509521
# (dataset)error at epoch 240 is 49.33333333333333
# mbloss:  0.6499967575073242
# (dataset)error at epoch 241 is 49.33333333333333
# mbloss:  0.6498344540596008
# (dataset)error at epoch 242 is 49.33333333333333
# mbloss:  0.6496701240539551
# (dataset)error at epoch 243 is 49.33333333333333
# mbloss:  0.6495044231414795
# (dataset)error at epoch 244 is 49.33333333333333
# mbloss:  0.6493367552757263
# (dataset)error at epoch 245 is 49.33333333333333
# mbloss:  0.6491674184799194
# (dataset)error at epoch 246 is 49.33333333333333
# mbloss:  0.6489960551261902
# (dataset)error at epoch 247 is 49.33333333333333
# mbloss:  0.6488227248191833
# (dataset)error at epoch 248 is 49.33333333333333
# mbloss:  0.6486474871635437
# (dataset)error at epoch 249 is 49.33333333333333
# mbloss:  0.6484701633453369
# (dataset)error at epoch 250 is 48.66666666666667
# mbloss:  0.6482908129692078
# (dataset)error at epoch 251 is 48.66666666666667
# mbloss:  0.6481092572212219
# (dataset)error at epoch 252 is 48.66666666666667
# mbloss:  0.6479254961013794
# (dataset)error at epoch 253 is 48.66666666666667
# mbloss:  0.6477387547492981
# (dataset)error at epoch 254 is 48.66666666666667
# mbloss:  0.6475450396537781
# (dataset)error at epoch 255 is 48.66666666666667
# mbloss:  0.6473492383956909
# (dataset)error at epoch 256 is 48.66666666666667
# mbloss:  0.6471512913703918
# (dataset)error at epoch 257 is 48.66666666666667
# mbloss:  0.6469511389732361
# (dataset)error at epoch 258 is 48.0
# mbloss:  0.6467500925064087
# (dataset)error at epoch 259 is 48.0
# mbloss:  0.6465485692024231
# (dataset)error at epoch 260 is 48.0
# mbloss:  0.6463449597358704
# (dataset)error at epoch 261 is 48.0
# mbloss:  0.6461388468742371
# (dataset)error at epoch 262 is 48.0
# mbloss:  0.645930290222168
# (dataset)error at epoch 263 is 48.0
# mbloss:  0.6457194685935974
# (dataset)error at epoch 264 is 48.0
# mbloss:  0.6455023884773254
# (dataset)error at epoch 265 is 48.0
# mbloss:  0.6452756524085999
# (dataset)error at epoch 266 is 48.0
# mbloss:  0.6450489163398743
# (dataset)error at epoch 267 is 48.0
# mbloss:  0.6448202729225159
# (dataset)error at epoch 268 is 48.0
# mbloss:  0.6445897817611694
# (dataset)error at epoch 269 is 48.0
# mbloss:  0.6443571448326111
# (dataset)error at epoch 270 is 48.0
# mbloss:  0.644122302532196
# (dataset)error at epoch 271 is 47.333333333333336
# mbloss:  0.6438840627670288
# (dataset)error at epoch 272 is 47.333333333333336
# mbloss:  0.6436295509338379
# (dataset)error at epoch 273 is 47.333333333333336
# mbloss:  0.6433738470077515
# (dataset)error at epoch 274 is 47.333333333333336
# mbloss:  0.6431164741516113
# (dataset)error at epoch 275 is 47.333333333333336
# mbloss:  0.6428557634353638
# (dataset)error at epoch 276 is 47.333333333333336
# mbloss:  0.6425929665565491
# (dataset)error at epoch 277 is 47.333333333333336
# mbloss:  0.6423270106315613
# (dataset)error at epoch 278 is 46.666666666666664
# mbloss:  0.6420446038246155
# (dataset)error at epoch 279 is 46.666666666666664
# mbloss:  0.6417616009712219
# (dataset)error at epoch 280 is 46.666666666666664
# mbloss:  0.6414770483970642
# (dataset)error at epoch 281 is 46.666666666666664
# mbloss:  0.6411903500556946
# (dataset)error at epoch 282 is 46.666666666666664
# mbloss:  0.6409032940864563
# (dataset)error at epoch 283 is 46.666666666666664
# mbloss:  0.6406238079071045
# (dataset)error at epoch 284 is 46.666666666666664
# mbloss:  0.6403420567512512
# (dataset)error at epoch 285 is 46.666666666666664
# mbloss:  0.6400575041770935
# (dataset)error at epoch 286 is 46.666666666666664
# mbloss:  0.6397697329521179
# (dataset)error at epoch 287 is 46.666666666666664
# mbloss:  0.6394786238670349
# (dataset)error at epoch 288 is 46.666666666666664
# mbloss:  0.6391841173171997
# (dataset)error at epoch 289 is 46.666666666666664
# mbloss:  0.6388862729072571
# (dataset)error at epoch 290 is 46.666666666666664
# mbloss:  0.6385846734046936
# (dataset)error at epoch 291 is 46.0
# mbloss:  0.6382795572280884
# (dataset)error at epoch 292 is 46.0
# mbloss:  0.6379705667495728
# (dataset)error at epoch 293 is 46.0
# mbloss:  0.6376549005508423
# (dataset)error at epoch 294 is 46.0
# mbloss:  0.6373166441917419
# (dataset)error at epoch 295 is 46.0
# mbloss:  0.6369768381118774
# (dataset)error at epoch 296 is 46.0
# mbloss:  0.636634886264801
# (dataset)error at epoch 297 is 45.333333333333336
# mbloss:  0.6362901926040649
# (dataset)error at epoch 298 is 43.99999999999999
# mbloss:  0.635942816734314
# (dataset)error at epoch 299 is 42.666666666666664
# mbloss:  0.6355906128883362
# (dataset)error at epoch 300 is 42.666666666666664
# mbloss:  0.6352325677871704
# (dataset)error at epoch 301 is 42.666666666666664
# mbloss:  0.6348715424537659
# (dataset)error at epoch 302 is 42.666666666666664
# mbloss:  0.6345070600509644
# (dataset)error at epoch 303 is 42.666666666666664
# mbloss:  0.6341390609741211
# (dataset)error at epoch 304 is 42.00000000000001
# mbloss:  0.633766233921051
# (dataset)error at epoch 305 is 42.00000000000001
# mbloss:  0.6333848834037781
# (dataset)error at epoch 306 is 42.00000000000001
# mbloss:  0.6330053210258484
# (dataset)error at epoch 307 is 42.00000000000001
# mbloss:  0.6326200366020203
# (dataset)error at epoch 308 is 42.00000000000001
# mbloss:  0.6322285532951355
# (dataset)error at epoch 309 is 42.00000000000001
# mbloss:  0.6318323612213135
# (dataset)error at epoch 310 is 42.00000000000001
# mbloss:  0.6314337253570557
# (dataset)error at epoch 311 is 42.00000000000001
# mbloss:  0.6310334801673889
# (dataset)error at epoch 312 is 42.00000000000001
# mbloss:  0.6306286454200745
# (dataset)error at epoch 313 is 42.666666666666664
# mbloss:  0.6302192807197571
# (dataset)error at epoch 314 is 42.666666666666664
# mbloss:  0.6298050880432129
# (dataset)error at epoch 315 is 42.666666666666664
# mbloss:  0.6293860077857971
# (dataset)error at epoch 316 is 42.666666666666664
# mbloss:  0.6289615035057068
# (dataset)error at epoch 317 is 42.666666666666664
# mbloss:  0.6285130977630615
# (dataset)error at epoch 318 is 42.00000000000001
# mbloss:  0.6280649304389954
# (dataset)error at epoch 319 is 42.00000000000001
# mbloss:  0.6276146173477173
# (dataset)error at epoch 320 is 41.333333333333336
# mbloss:  0.6271617412567139
# (dataset)error at epoch 321 is 40.666666666666664
# mbloss:  0.6267060041427612
# (dataset)error at epoch 322 is 40.666666666666664
# mbloss:  0.626251757144928
# (dataset)error at epoch 323 is 40.666666666666664
# mbloss:  0.62579345703125
# (dataset)error at epoch 324 is 40.666666666666664
# mbloss:  0.6253347992897034
# (dataset)error at epoch 325 is 40.666666666666664
# mbloss:  0.6248719096183777
# (dataset)error at epoch 326 is 40.666666666666664
# mbloss:  0.6244044303894043
# (dataset)error at epoch 327 is 40.666666666666664
# mbloss:  0.6239324808120728
# (dataset)error at epoch 328 is 40.666666666666664
# mbloss:  0.6234548687934875
# (dataset)error at epoch 329 is 40.666666666666664
# mbloss:  0.6229701042175293
# (dataset)error at epoch 330 is 40.666666666666664
# mbloss:  0.6224783062934875
# (dataset)error at epoch 331 is 40.666666666666664
# mbloss:  0.6219761371612549
# (dataset)error at epoch 332 is 40.666666666666664
# mbloss:  0.6214761734008789
# (dataset)error at epoch 333 is 40.0
# mbloss:  0.6209707260131836
# (dataset)error at epoch 334 is 40.0
# mbloss:  0.6204596757888794
# (dataset)error at epoch 335 is 40.0
# mbloss:  0.6199434399604797
# (dataset)error at epoch 336 is 40.0
# mbloss:  0.6194220781326294
# (dataset)error at epoch 337 is 40.0
# mbloss:  0.6188955307006836
# (dataset)error at epoch 338 is 40.0
# mbloss:  0.6183639764785767
# (dataset)error at epoch 339 is 40.0
# mbloss:  0.6178286671638489
# (dataset)error at epoch 340 is 40.0
# mbloss:  0.6172918677330017
# (dataset)error at epoch 341 is 40.0
# mbloss:  0.6167503595352173
# (dataset)error at epoch 342 is 40.0
# mbloss:  0.616204023361206
# (dataset)error at epoch 343 is 40.0
# mbloss:  0.6156529188156128
# (dataset)error at epoch 344 is 40.0
# mbloss:  0.6150975227355957
# (dataset)error at epoch 345 is 40.0
# mbloss:  0.6145372986793518
# (dataset)error at epoch 346 is 40.0
# mbloss:  0.6139721870422363
# (dataset)error at epoch 347 is 40.0
# mbloss:  0.6134021878242493
# (dataset)error at epoch 348 is 39.33333333333333
# mbloss:  0.6128273010253906
# (dataset)error at epoch 349 is 39.33333333333333
# mbloss:  0.61224764585495
# (dataset)error at epoch 350 is 39.33333333333333
# mbloss:  0.6116635203361511
# (dataset)error at epoch 351 is 38.66666666666667
# mbloss:  0.6110749840736389
# (dataset)error at epoch 352 is 38.66666666666667
# mbloss:  0.6104828119277954
# (dataset)error at epoch 353 is 38.66666666666667
# mbloss:  0.609886109828949
# (dataset)error at epoch 354 is 38.66666666666667
# mbloss:  0.6092849373817444
# (dataset)error at epoch 355 is 38.66666666666667
# mbloss:  0.6086797714233398
# (dataset)error at epoch 356 is 38.66666666666667
# mbloss:  0.6080706715583801
# (dataset)error at epoch 357 is 38.66666666666667
# mbloss:  0.6074602007865906
# (dataset)error at epoch 358 is 38.66666666666667
# mbloss:  0.6068524122238159
# (dataset)error at epoch 359 is 38.66666666666667
# mbloss:  0.6062416434288025
# (dataset)error at epoch 360 is 37.33333333333333
# mbloss:  0.6056271195411682
# (dataset)error at epoch 361 is 37.33333333333333
# mbloss:  0.6050095558166504
# (dataset)error at epoch 362 is 37.33333333333333
# mbloss:  0.6043887734413147
# (dataset)error at epoch 363 is 37.33333333333333
# mbloss:  0.6037653088569641
# (dataset)error at epoch 364 is 37.33333333333333
# mbloss:  0.6031392812728882
# (dataset)error at epoch 365 is 37.33333333333333
# mbloss:  0.6025102138519287
# (dataset)error at epoch 366 is 37.33333333333333
# mbloss:  0.6018780469894409
# (dataset)error at epoch 367 is 37.33333333333333
# mbloss:  0.6012428998947144
# (dataset)error at epoch 368 is 36.66666666666667
# mbloss:  0.6006047129631042
# (dataset)error at epoch 369 is 36.66666666666667
# mbloss:  0.5999637842178345
# (dataset)error at epoch 370 is 36.66666666666667
# mbloss:  0.5993200540542603
# (dataset)error at epoch 371 is 36.66666666666667
# mbloss:  0.5986738204956055
# (dataset)error at epoch 372 is 37.33333333333333
# mbloss:  0.5980252027511597
# (dataset)error at epoch 373 is 37.33333333333333
# mbloss:  0.5973741412162781
# (dataset)error at epoch 374 is 36.66666666666667
# mbloss:  0.5967210531234741
# (dataset)error at epoch 375 is 36.66666666666667
# mbloss:  0.5960657596588135
# (dataset)error at epoch 376 is 36.66666666666667
# mbloss:  0.5954087972640991
# (dataset)error at epoch 377 is 36.66666666666667
# mbloss:  0.5947498679161072
# (dataset)error at epoch 378 is 36.66666666666667
# mbloss:  0.5940895676612854
# (dataset)error at epoch 379 is 36.66666666666667
# mbloss:  0.5934277176856995
# (dataset)error at epoch 380 is 36.0
# mbloss:  0.5927658677101135
# (dataset)error at epoch 381 is 36.0
# mbloss:  0.5921028852462769
# (dataset)error at epoch 382 is 36.0
# mbloss:  0.5914390087127686
# (dataset)error at epoch 383 is 36.0
# mbloss:  0.5907741785049438
# (dataset)error at epoch 384 is 36.0
# mbloss:  0.5901089906692505
# (dataset)error at epoch 385 is 36.66666666666667
# mbloss:  0.5894433856010437
# (dataset)error at epoch 386 is 36.66666666666667
# mbloss:  0.5887789130210876
# (dataset)error at epoch 387 is 36.66666666666667
# mbloss:  0.5881139636039734
# (dataset)error at epoch 388 is 36.66666666666667
# mbloss:  0.587449312210083
# (dataset)error at epoch 389 is 36.66666666666667
# mbloss:  0.5867851972579956
# (dataset)error at epoch 390 is 36.66666666666667
# mbloss:  0.5861214995384216
# (dataset)error at epoch 391 is 36.66666666666667
# mbloss:  0.5854575634002686
# (dataset)error at epoch 392 is 36.66666666666667
# mbloss:  0.5847901701927185
# (dataset)error at epoch 393 is 36.66666666666667
# mbloss:  0.5841253399848938
# (dataset)error at epoch 394 is 36.66666666666667
# mbloss:  0.5834632515907288
# (dataset)error at epoch 395 is 36.0
# mbloss:  0.5828009247779846
# (dataset)error at epoch 396 is 36.0
# mbloss:  0.582141101360321
# (dataset)error at epoch 397 is 36.0
# mbloss:  0.5814836025238037
# (dataset)error at epoch 398 is 36.0
# mbloss:  0.5808268189430237
# (dataset)error at epoch 399 is 36.0
# mbloss:  0.5801729559898376
# (dataset)error at epoch 400 is 36.0
# mbloss:  0.5795209407806396
# (dataset)error at epoch 401 is 36.0
# mbloss:  0.5788707733154297
# (dataset)error at epoch 402 is 36.0
# mbloss:  0.5782238841056824
# (dataset)error at epoch 403 is 36.0
# mbloss:  0.5775784254074097
# (dataset)error at epoch 404 is 36.0
# mbloss:  0.5769369602203369
# (dataset)error at epoch 405 is 36.0
# mbloss:  0.5762972831726074
# (dataset)error at epoch 406 is 36.0
# mbloss:  0.5756617784500122
# (dataset)error at epoch 407 is 36.0
# mbloss:  0.5750288367271423
# (dataset)error at epoch 408 is 36.0
# mbloss:  0.574399471282959
# (dataset)error at epoch 409 is 36.0
# mbloss:  0.5737740993499756
# (dataset)error at epoch 410 is 36.66666666666667
# mbloss:  0.5731545090675354
# (dataset)error at epoch 411 is 36.0
# mbloss:  0.5725356936454773
# (dataset)error at epoch 412 is 36.66666666666667
# mbloss:  0.57192462682724
# (dataset)error at epoch 413 is 36.0
# mbloss:  0.5713159441947937
# (dataset)error at epoch 414 is 36.66666666666667
# mbloss:  0.5707123279571533
# (dataset)error at epoch 415 is 36.0
# mbloss:  0.5701135993003845
# (dataset)error at epoch 416 is 36.66666666666667
# mbloss:  0.5695194005966187
# (dataset)error at epoch 417 is 36.66666666666667
# mbloss:  0.5689297318458557
# (dataset)error at epoch 418 is 36.66666666666667
# mbloss:  0.5683466792106628
# (dataset)error at epoch 419 is 36.66666666666667
# mbloss:  0.5677686929702759
# (dataset)error at epoch 420 is 36.66666666666667
# mbloss:  0.5671958327293396
# (dataset)error at epoch 421 is 36.66666666666667
# mbloss:  0.5666283369064331
# (dataset)error at epoch 422 is 36.0
# mbloss:  0.5660670399665833
# (dataset)error at epoch 423 is 36.0
# mbloss:  0.5655117630958557
# (dataset)error at epoch 424 is 35.33333333333334
# mbloss:  0.5649622678756714
# (dataset)error at epoch 425 is 35.33333333333334
# mbloss:  0.5644185543060303
# (dataset)error at epoch 426 is 34.66666666666667
# mbloss:  0.5638809204101562
# (dataset)error at epoch 427 is 34.0
# mbloss:  0.5633490681648254
# (dataset)error at epoch 428 is 34.0
# mbloss:  0.5628231763839722
# (dataset)error at epoch 429 is 34.0
# mbloss:  0.5623033046722412
# (dataset)error at epoch 430 is 34.0
# mbloss:  0.5617893934249878
# (dataset)error at epoch 431 is 34.0
# mbloss:  0.5612816214561462
# (dataset)error at epoch 432 is 34.0
# mbloss:  0.5607799291610718
# (dataset)error at epoch 433 is 34.0
# mbloss:  0.5602843761444092
# (dataset)error at epoch 434 is 34.0
# mbloss:  0.5597949028015137
# (dataset)error at epoch 435 is 34.0
# mbloss:  0.5593115091323853
# (dataset)error at epoch 436 is 34.0
# mbloss:  0.5588343739509583
# (dataset)error at epoch 437 is 34.0
# mbloss:  0.5583634376525879
# (dataset)error at epoch 438 is 34.0
# mbloss:  0.5578985810279846
# (dataset)error at epoch 439 is 34.0
# mbloss:  0.5574400424957275
# (dataset)error at epoch 440 is 34.0
# mbloss:  0.5569875240325928
# (dataset)error at epoch 441 is 34.0
# mbloss:  0.5565412640571594
# (dataset)error at epoch 442 is 34.0
# mbloss:  0.5561012029647827
# (dataset)error at epoch 443 is 34.0
# mbloss:  0.5556671619415283
# (dataset)error at epoch 444 is 34.0
# mbloss:  0.5552394390106201
# (dataset)error at epoch 445 is 34.0
# mbloss:  0.5548177361488342
# (dataset)error at epoch 446 is 34.0
# mbloss:  0.5544021129608154
# (dataset)error at epoch 447 is 34.0
# mbloss:  0.5539925694465637
# (dataset)error at epoch 448 is 34.0
# mbloss:  0.5535890460014343
# (dataset)error at epoch 449 is 34.0
# mbloss:  0.5531915426254272
# (dataset)error at epoch 450 is 34.0
# mbloss:  0.5528000593185425
# (dataset)error at epoch 451 is 34.0
# mbloss:  0.5524144768714905
# (dataset)error at epoch 452 is 34.0
# mbloss:  0.5520347356796265
# (dataset)error at epoch 453 is 34.0
# mbloss:  0.5516608953475952
# (dataset)error at epoch 454 is 33.33333333333334
# mbloss:  0.5512927770614624
# (dataset)error at epoch 455 is 33.33333333333334
# mbloss:  0.5509305000305176
# (dataset)error at epoch 456 is 33.33333333333334
# mbloss:  0.5505738854408264
# (dataset)error at epoch 457 is 33.33333333333334
# mbloss:  0.5502229332923889
# (dataset)error at epoch 458 is 33.33333333333334
# mbloss:  0.5498776435852051
# (dataset)error at epoch 459 is 33.33333333333334
# mbloss:  0.5495378375053406
# (dataset)error at epoch 460 is 33.33333333333334
# mbloss:  0.5492035746574402
# (dataset)error at epoch 461 is 33.33333333333334
# mbloss:  0.5488747358322144
# (dataset)error at epoch 462 is 33.33333333333334
# mbloss:  0.5485512614250183
# (dataset)error at epoch 463 is 33.33333333333334
# mbloss:  0.5482355952262878
# (dataset)error at epoch 464 is 33.33333333333334
# mbloss:  0.5479279160499573
# (dataset)error at epoch 465 is 33.33333333333334
# mbloss:  0.5476259589195251
# (dataset)error at epoch 466 is 33.33333333333334
# mbloss:  0.5473296642303467
# (dataset)error at epoch 467 is 33.33333333333334
# mbloss:  0.5470386147499084
# (dataset)error at epoch 468 is 33.33333333333334
# mbloss:  0.5467527508735657
# (dataset)error at epoch 469 is 33.33333333333334
# mbloss:  0.5464720726013184
# (dataset)error at epoch 470 is 33.33333333333334
# mbloss:  0.5461965799331665
# (dataset)error at epoch 471 is 33.33333333333334
# mbloss:  0.5459262728691101
# (dataset)error at epoch 472 is 33.33333333333334
# mbloss:  0.5456610918045044
# (dataset)error at epoch 473 is 33.33333333333334
# mbloss:  0.5454011559486389
# (dataset)error at epoch 474 is 33.33333333333334
# mbloss:  0.5451481342315674
# (dataset)error at epoch 475 is 33.33333333333334
# mbloss:  0.5449005365371704
# (dataset)error at epoch 476 is 33.33333333333334
# mbloss:  0.5446624755859375
# (dataset)error at epoch 477 is 33.33333333333334
# mbloss:  0.5444343686103821
# (dataset)error at epoch 478 is 33.33333333333334
# mbloss:  0.5442208051681519
# (dataset)error at epoch 479 is 32.0
# mbloss:  0.5440295338630676
# (dataset)error at epoch 480 is 34.0
# mbloss:  0.5438722968101501
# (dataset)error at epoch 481 is 32.0
# mbloss:  0.5437763333320618
# (dataset)error at epoch 482 is 34.66666666666667
# mbloss:  0.5437797904014587
# (dataset)error at epoch 483 is 30.666666666666657
# mbloss:  0.5439668297767639
# (dataset)error at epoch 484 is 36.0
# mbloss:  0.5444905161857605
# (dataset)error at epoch 485 is 31.33333333333333
# mbloss:  0.5456030964851379
# (dataset)error at epoch 486 is 37.33333333333333
# mbloss:  0.5479204654693604
# (dataset)error at epoch 487 is 31.33333333333333
# mbloss:  0.552119791507721
# (dataset)error at epoch 488 is 40.0
# mbloss:  0.5607401728630066
# (dataset)error at epoch 489 is 23.33333333333333
# mbloss:  0.5743879675865173
# (dataset)error at epoch 490 is 44.666666666666664
# mbloss:  0.6015443801879883
# (dataset)error at epoch 491 is 29.33333333333333
# mbloss:  0.6312313079833984
# (dataset)error at epoch 492 is 44.666666666666664
# mbloss:  0.6825345754623413
# (dataset)error at epoch 493 is 35.33333333333334
# mbloss:  0.6910162568092346
# (dataset)error at epoch 494 is 46.0
# mbloss:  0.7207415103912354
# (dataset)error at epoch 495 is 31.33333333333333
# mbloss:  0.6777622699737549
# (dataset)error at epoch 496 is 44.666666666666664
# mbloss:  0.6751914620399475
# (dataset)error at epoch 497 is 28.666666666666657
# mbloss:  0.6329177021980286
# (dataset)error at epoch 498 is 45.333333333333336
# mbloss:  0.6243727207183838
# (dataset)error at epoch 499 is 28.0
# Test error after first step of loop 1 is 28.0!
# the averaged shadow prices  of all available positions: [tensor(0.0109), tensor(0.0014)]
# Insert layer at position 1 !
# [tensor(1.8254)]
# [tensor(1.8254), tensor(1.7476)]
# [tensor(1.8254), tensor(1.7476), tensor(1.5964)]
# [tensor(1.8254), tensor(1.7476), tensor(1.5964), tensor(2.1571)]
# [tensor(1.8254), tensor(1.7476), tensor(1.5964), tensor(2.1571), tensor(1.7321)]
# [tensor(1.8254), tensor(1.7476), tensor(1.5964), tensor(2.1571), tensor(1.7321), tensor(0.)]
# [tensor(1.8254), tensor(1.7476), tensor(1.5964), tensor(2.1571), tensor(1.7321), tensor(0.), tensor(0.)]
# [tensor(1.8254), tensor(1.7476), tensor(1.5964), tensor(2.1571), tensor(1.7321), tensor(0.), tensor(0.), tensor(2.2407)]
# starting on 2. net!
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=2, out_features=3, bias=False)
#   (2): ReLU()
#   (3): ResBlock1(
#     (af1): ReLU()
#     (l1): Linear(in_features=3, out_features=3, bias=True)
#     (shortcut): Sequential()
#     (l2): Linear(in_features=3, out_features=3, bias=False)
#   )
#   (4): ResBlock1(
#     (af1): ReLU()
#     (l1): Linear(in_features=3, out_features=3, bias=True)
#     (shortcut): Sequential()
#     (l2): Linear(in_features=3, out_features=3, bias=False)
#   )
#   (5): Linear(in_features=3, out_features=2, bias=False)
# )
# mbloss:  0.6003621816635132
# (dataset)error at epoch 0 is 35.33333333333334
# mbloss:  0.5464715957641602
# (dataset)error at epoch 1 is 33.33333333333334
# mbloss:  0.5458180904388428
# (dataset)error at epoch 2 is 33.33333333333334
# mbloss:  0.5452950596809387
# (dataset)error at epoch 3 is 33.33333333333334
# mbloss:  0.5448307394981384
# (dataset)error at epoch 4 is 33.33333333333334
# mbloss:  0.5443972945213318
# (dataset)error at epoch 5 is 33.33333333333334
# mbloss:  0.5439823865890503
# (dataset)error at epoch 6 is 33.33333333333334
# mbloss:  0.5435792207717896
# (dataset)error at epoch 7 is 33.33333333333334
# mbloss:  0.5431856513023376
# (dataset)error at epoch 8 is 33.33333333333334
# mbloss:  0.542801022529602
# (dataset)error at epoch 9 is 33.33333333333334
# mbloss:  0.5424240231513977
# (dataset)error at epoch 10 is 33.33333333333334
# mbloss:  0.5420539975166321
# (dataset)error at epoch 11 is 33.33333333333334
# mbloss:  0.5416904091835022
# (dataset)error at epoch 12 is 33.33333333333334
# mbloss:  0.541332483291626
# (dataset)error at epoch 13 is 33.33333333333334
# mbloss:  0.5409802794456482
# (dataset)error at epoch 14 is 33.33333333333334
# mbloss:  0.5406333804130554
# (dataset)error at epoch 15 is 33.33333333333334
# mbloss:  0.5402912497520447
# (dataset)error at epoch 16 is 33.33333333333334
# mbloss:  0.5399531126022339
# (dataset)error at epoch 17 is 33.33333333333334
# mbloss:  0.5396170616149902
# (dataset)error at epoch 18 is 33.33333333333334
# mbloss:  0.5392836928367615
# (dataset)error at epoch 19 is 33.33333333333334
# mbloss:  0.5389550924301147
# (dataset)error at epoch 20 is 33.33333333333334
# mbloss:  0.5386319160461426
# (dataset)error at epoch 21 is 33.33333333333334
# mbloss:  0.5383139252662659
# (dataset)error at epoch 22 is 33.33333333333334
# mbloss:  0.5380001664161682
# (dataset)error at epoch 23 is 33.33333333333334
# mbloss:  0.5376908779144287
# (dataset)error at epoch 24 is 33.33333333333334
# mbloss:  0.5373871326446533
# (dataset)error at epoch 25 is 33.33333333333334
# mbloss:  0.5370889902114868
# (dataset)error at epoch 26 is 33.33333333333334
# mbloss:  0.5367951393127441
# (dataset)error at epoch 27 is 33.33333333333334
# mbloss:  0.5365052223205566
# (dataset)error at epoch 28 is 33.33333333333334
# mbloss:  0.5362183451652527
# (dataset)error at epoch 29 is 33.33333333333334
# mbloss:  0.5359364748001099
# (dataset)error at epoch 30 is 33.33333333333334
# mbloss:  0.5356581211090088
# (dataset)error at epoch 31 is 33.33333333333334
# mbloss:  0.5353829264640808
# (dataset)error at epoch 32 is 33.33333333333334
# mbloss:  0.5351108312606812
# (dataset)error at epoch 33 is 33.33333333333334
# mbloss:  0.5348432064056396
# (dataset)error at epoch 34 is 33.33333333333334
# mbloss:  0.5345785617828369
# (dataset)error at epoch 35 is 33.33333333333334
# mbloss:  0.5343172550201416
# (dataset)error at epoch 36 is 33.33333333333334
# mbloss:  0.5340598821640015
# (dataset)error at epoch 37 is 33.33333333333334
# mbloss:  0.5338054299354553
# (dataset)error at epoch 38 is 33.33333333333334
# mbloss:  0.533554196357727
# (dataset)error at epoch 39 is 33.33333333333334
# mbloss:  0.5333069562911987
# (dataset)error at epoch 40 is 33.33333333333334
# mbloss:  0.5330622792243958
# (dataset)error at epoch 41 is 32.66666666666667
# mbloss:  0.5328195691108704
# (dataset)error at epoch 42 is 32.66666666666667
# mbloss:  0.5325810313224792
# (dataset)error at epoch 43 is 32.66666666666667
# mbloss:  0.532345712184906
# (dataset)error at epoch 44 is 32.66666666666667
# mbloss:  0.5321153998374939
# (dataset)error at epoch 45 is 32.66666666666667
# mbloss:  0.5318881273269653
# (dataset)error at epoch 46 is 32.66666666666667
# mbloss:  0.5316649675369263
# (dataset)error at epoch 47 is 32.66666666666667
# mbloss:  0.5314447283744812
# (dataset)error at epoch 48 is 32.66666666666667
# mbloss:  0.5312261581420898
# (dataset)error at epoch 49 is 32.66666666666667
# mbloss:  0.5309991836547852
# (dataset)error at epoch 50 is 32.66666666666667
# mbloss:  0.5307766199111938
# (dataset)error at epoch 51 is 32.66666666666667
# mbloss:  0.5305574536323547
# (dataset)error at epoch 52 is 32.66666666666667
# mbloss:  0.5303418636322021
# (dataset)error at epoch 53 is 32.66666666666667
# mbloss:  0.5301299095153809
# (dataset)error at epoch 54 is 32.0
# mbloss:  0.5299211144447327
# (dataset)error at epoch 55 is 32.0
# mbloss:  0.5297150611877441
# (dataset)error at epoch 56 is 32.0
# mbloss:  0.5295118093490601
# (dataset)error at epoch 57 is 32.0
# mbloss:  0.5293111205101013
# (dataset)error at epoch 58 is 32.0
# mbloss:  0.5291130542755127
# (dataset)error at epoch 59 is 32.0
# mbloss:  0.528917133808136
# (dataset)error at epoch 60 is 32.0
# mbloss:  0.5287231206893921
# (dataset)error at epoch 61 is 32.66666666666667
# mbloss:  0.5285321474075317
# (dataset)error at epoch 62 is 32.0
# mbloss:  0.5283430218696594
# (dataset)error at epoch 63 is 32.66666666666667
# mbloss:  0.5281557440757751
# (dataset)error at epoch 64 is 32.66666666666667
# mbloss:  0.527970552444458
# (dataset)error at epoch 65 is 32.66666666666667
# mbloss:  0.5277876257896423
# (dataset)error at epoch 66 is 32.66666666666667
# mbloss:  0.5276066660881042
# (dataset)error at epoch 67 is 32.66666666666667
# mbloss:  0.5274279713630676
# (dataset)error at epoch 68 is 32.0
# mbloss:  0.5272515416145325
# (dataset)error at epoch 69 is 32.0
# mbloss:  0.5270771384239197
# (dataset)error at epoch 70 is 32.0
# mbloss:  0.5269047021865845
# (dataset)error at epoch 71 is 32.0
# mbloss:  0.5267339944839478
# (dataset)error at epoch 72 is 32.0
# mbloss:  0.5265649557113647
# (dataset)error at epoch 73 is 32.0
# mbloss:  0.5263976454734802
# (dataset)error at epoch 74 is 32.0
# mbloss:  0.5262320041656494
# (dataset)error at epoch 75 is 32.0
# mbloss:  0.5260680913925171
# (dataset)error at epoch 76 is 32.0
# mbloss:  0.5259060263633728
# (dataset)error at epoch 77 is 32.0
# mbloss:  0.5257455706596375
# (dataset)error at epoch 78 is 32.0
# mbloss:  0.5255866646766663
# (dataset)error at epoch 79 is 32.0
# mbloss:  0.5254292488098145
# (dataset)error at epoch 80 is 32.0
# mbloss:  0.5252733826637268
# (dataset)error at epoch 81 is 32.0
# mbloss:  0.5251190662384033
# (dataset)error at epoch 82 is 32.0
# mbloss:  0.5249660611152649
# (dataset)error at epoch 83 is 32.0
# mbloss:  0.5248143076896667
# (dataset)error at epoch 84 is 32.0
# mbloss:  0.5246638655662537
# (dataset)error at epoch 85 is 31.33333333333333
# mbloss:  0.5245145559310913
# (dataset)error at epoch 86 is 31.33333333333333
# mbloss:  0.5243664383888245
# (dataset)error at epoch 87 is 31.33333333333333
# mbloss:  0.5242196321487427
# (dataset)error at epoch 88 is 31.33333333333333
# mbloss:  0.5240738391876221
# (dataset)error at epoch 89 is 31.33333333333333
# mbloss:  0.5239293575286865
# (dataset)error at epoch 90 is 31.33333333333333
# mbloss:  0.5237870812416077
# (dataset)error at epoch 91 is 31.33333333333333
# mbloss:  0.5236453413963318
# (dataset)error at epoch 92 is 31.33333333333333
# mbloss:  0.5235083103179932
# (dataset)error at epoch 93 is 31.33333333333333
# mbloss:  0.5233694911003113
# (dataset)error at epoch 94 is 31.33333333333333
# mbloss:  0.5232326984405518
# (dataset)error at epoch 95 is 31.33333333333333
# mbloss:  0.5230943560600281
# (dataset)error at epoch 96 is 31.33333333333333
# mbloss:  0.5229550004005432
# (dataset)error at epoch 97 is 31.33333333333333
# mbloss:  0.5227973461151123
# (dataset)error at epoch 98 is 31.33333333333333
# mbloss:  0.5226430296897888
# (dataset)error at epoch 99 is 31.33333333333333
# mbloss:  0.5224925875663757
# (dataset)error at epoch 100 is 31.33333333333333
# mbloss:  0.5223425030708313
# (dataset)error at epoch 101 is 31.33333333333333
# mbloss:  0.5221909284591675
# (dataset)error at epoch 102 is 31.33333333333333
# mbloss:  0.5220463275909424
# (dataset)error at epoch 103 is 31.33333333333333
# mbloss:  0.5218981504440308
# (dataset)error at epoch 104 is 31.33333333333333
# mbloss:  0.5217567086219788
# (dataset)error at epoch 105 is 31.33333333333333
# mbloss:  0.5216058492660522
# (dataset)error at epoch 106 is 31.33333333333333
# mbloss:  0.5214621424674988
# (dataset)error at epoch 107 is 31.33333333333333
# mbloss:  0.521317720413208
# (dataset)error at epoch 108 is 31.33333333333333
# mbloss:  0.5211699604988098
# (dataset)error at epoch 109 is 31.33333333333333
# mbloss:  0.520932674407959
# (dataset)error at epoch 110 is 31.33333333333333
# mbloss:  0.5207041501998901
# (dataset)error at epoch 111 is 31.33333333333333
# mbloss:  0.5204863548278809
# (dataset)error at epoch 112 is 31.33333333333333
# mbloss:  0.5202822685241699
# (dataset)error at epoch 113 is 31.33333333333333
# mbloss:  0.520089328289032
# (dataset)error at epoch 114 is 31.33333333333333
# mbloss:  0.5199053883552551
# (dataset)error at epoch 115 is 31.33333333333333
# mbloss:  0.5197141170501709
# (dataset)error at epoch 116 is 31.33333333333333
# mbloss:  0.5195092558860779
# (dataset)error at epoch 117 is 31.33333333333333
# mbloss:  0.5193142294883728
# (dataset)error at epoch 118 is 31.33333333333333
# mbloss:  0.5191279649734497
# (dataset)error at epoch 119 is 30.666666666666657
# mbloss:  0.5189425945281982
# (dataset)error at epoch 120 is 30.666666666666657
# mbloss:  0.5187647342681885
# (dataset)error at epoch 121 is 30.666666666666657
# mbloss:  0.5185953974723816
# (dataset)error at epoch 122 is 30.666666666666657
# mbloss:  0.5184049010276794
# (dataset)error at epoch 123 is 30.0
# mbloss:  0.5180818438529968
# (dataset)error at epoch 124 is 30.0
# mbloss:  0.5177921056747437
# (dataset)error at epoch 125 is 30.666666666666657
# mbloss:  0.5175257325172424
# (dataset)error at epoch 126 is 30.666666666666657
# mbloss:  0.5172794461250305
# (dataset)error at epoch 127 is 30.666666666666657
# mbloss:  0.5170442461967468
# (dataset)error at epoch 128 is 30.666666666666657
# mbloss:  0.5168203115463257
# (dataset)error at epoch 129 is 30.666666666666657
# mbloss:  0.5165951251983643
# (dataset)error at epoch 130 is 30.666666666666657
# mbloss:  0.5163733959197998
# (dataset)error at epoch 131 is 30.666666666666657
# mbloss:  0.5161644816398621
# ...
# (dataset)error at epoch 810 is 0.6666666666666714
# mbloss:  0.05000770464539528
# (dataset)error at epoch 811 is 0.6666666666666714
# mbloss:  0.047224320471286774
# (dataset)error at epoch 812 is 0.6666666666666714
# mbloss:  0.050773948431015015
# (dataset)error at epoch 813 is 0.6666666666666714
# mbloss:  0.04467509314417839
# (dataset)error at epoch 814 is 0.6666666666666714
# mbloss:  0.04595626890659332
# (dataset)error at epoch 815 is 0.6666666666666714
# mbloss:  0.04580630362033844
# (dataset)error at epoch 816 is 0.6666666666666714
# mbloss:  0.04815896600484848
# (dataset)error at epoch 817 is 0.6666666666666714
# mbloss:  0.04524798318743706
# (dataset)error at epoch 818 is 0.6666666666666714
# mbloss:  0.04763535410165787
# (dataset)error at epoch 819 is 0.6666666666666714
# mbloss:  0.04480521380901337
# (dataset)error at epoch 820 is 0.6666666666666714
# mbloss:  0.04726769030094147
# (dataset)error at epoch 821 is 0.6666666666666714
# mbloss:  0.04459983482956886
# (dataset)error at epoch 822 is 0.6666666666666714
# mbloss:  0.047557152807712555
# (dataset)error at epoch 823 is 0.6666666666666714
# mbloss:  0.04439406096935272
# (dataset)error at epoch 824 is 0.6666666666666714
# mbloss:  0.047791674733161926
# (dataset)error at epoch 825 is 0.6666666666666714
# mbloss:  0.041470859199762344
# (dataset)error at epoch 826 is 0.6666666666666714
# mbloss:  0.04206419363617897
# (dataset)error at epoch 827 is 0.6666666666666714
# mbloss:  0.04210064187645912
# (dataset)error at epoch 828 is 0.6666666666666714
# mbloss:  0.044212885200977325
# (dataset)error at epoch 829 is 0.6666666666666714
# mbloss:  0.04225808382034302
# (dataset)error at epoch 830 is 0.6666666666666714
# mbloss:  0.045112837105989456
# (dataset)error at epoch 831 is 0.6666666666666714
# mbloss:  0.04275067523121834
# (dataset)error at epoch 832 is 0.6666666666666714
# mbloss:  0.045620035380125046
# (dataset)error at epoch 833 is 0.6666666666666714
# mbloss:  0.04211672022938728
# (dataset)error at epoch 834 is 0.6666666666666714
# mbloss:  0.04438498616218567
# (dataset)error at epoch 835 is 0.6666666666666714
# mbloss:  0.041227348148822784
# (dataset)error at epoch 836 is 0.6666666666666714
# mbloss:  0.043200865387916565
# (dataset)error at epoch 837 is 0.6666666666666714
# mbloss:  0.040180083364248276
# (dataset)error at epoch 838 is 0.6666666666666714
# mbloss:  0.04156060889363289
# (dataset)error at epoch 839 is 0.6666666666666714
# mbloss:  0.04231509193778038
# (dataset)error at epoch 840 is 0.6666666666666714
# mbloss:  0.046671487390995026
# (dataset)error at epoch 841 is 0.6666666666666714
# mbloss:  0.03875511884689331
# (dataset)error at epoch 842 is 0.6666666666666714
# mbloss:  0.039684753865003586
# (dataset)error at epoch 843 is 0.6666666666666714
# mbloss:  0.03937632963061333
# (dataset)error at epoch 844 is 0.6666666666666714
# mbloss:  0.04181087017059326
# (dataset)error at epoch 845 is 0.6666666666666714
# mbloss:  0.03906429558992386
# (dataset)error at epoch 846 is 0.6666666666666714
# mbloss:  0.042039304971694946
# (dataset)error at epoch 847 is 0.6666666666666714
# mbloss:  0.039393141865730286
# (dataset)error at epoch 848 is 0.6666666666666714
# mbloss:  0.042791664600372314
# (dataset)error at epoch 849 is 0.6666666666666714
# mbloss:  0.03652845323085785
# (dataset)error at epoch 850 is 0.6666666666666714
# mbloss:  0.03682846203446388
# (dataset)error at epoch 851 is 0.6666666666666714
# mbloss:  0.037083521485328674
# (dataset)error at epoch 852 is 0.6666666666666714
# mbloss:  0.038884274661540985
# (dataset)error at epoch 853 is 0.6666666666666714
# mbloss:  0.03875010460615158
# (dataset)error at epoch 854 is 0.6666666666666714
# mbloss:  0.0424351841211319
# (dataset)error at epoch 855 is 0.6666666666666714
# mbloss:  0.035846538841724396
# (dataset)error at epoch 856 is 0.6666666666666714
# mbloss:  0.03676135465502739
# (dataset)error at epoch 857 is 0.6666666666666714
# mbloss:  0.03669941425323486
# (dataset)error at epoch 858 is 0.6666666666666714
# mbloss:  0.03948773443698883
# (dataset)error at epoch 859 is 0.6666666666666714
# mbloss:  0.036831095814704895
# (dataset)error at epoch 860 is 0.6666666666666714
# mbloss:  0.040054935961961746
# (dataset)error at epoch 861 is 0.6666666666666714
# mbloss:  0.0374956876039505
# (dataset)error at epoch 862 is 0.6666666666666714
# mbloss:  0.04177645966410637
# (dataset)error at epoch 863 is 0.6666666666666714
# mbloss:  0.034903138875961304
# (dataset)error at epoch 864 is 0.6666666666666714
# mbloss:  0.036450427025556564
# (dataset)error at epoch 865 is 0.6666666666666714
# mbloss:  0.03644131124019623
# (dataset)error at epoch 866 is 0.6666666666666714
# mbloss:  0.03987831249833107
# (dataset)error at epoch 867 is 0.6666666666666714
# mbloss:  0.03697358816862106
# (dataset)error at epoch 868 is 0.6666666666666714
# mbloss:  0.04161393642425537
# (dataset)error at epoch 869 is 0.6666666666666714
# mbloss:  0.034328311681747437
# (dataset)error at epoch 870 is 0.6666666666666714
# mbloss:  0.03630850091576576
# (dataset)error at epoch 871 is 0.6666666666666714
# mbloss:  0.03399631753563881
# (dataset)error at epoch 872 is 0.6666666666666714
# mbloss:  0.036027807742357254
# (dataset)error at epoch 873 is 0.6666666666666714
# mbloss:  0.033787984400987625
# (dataset)error at epoch 874 is 0.6666666666666714
# mbloss:  0.03595561906695366
# (dataset)error at epoch 875 is 0.6666666666666714
# mbloss:  0.033942487090826035
# (dataset)error at epoch 876 is 0.6666666666666714
# mbloss:  0.036703336983919144
# (dataset)error at epoch 877 is 0.6666666666666714
# mbloss:  0.034222669899463654
# (dataset)error at epoch 878 is 0.6666666666666714
# mbloss:  0.03740795701742172
# (dataset)error at epoch 879 is 0.6666666666666714
# mbloss:  0.034622181206941605
# (dataset)error at epoch 880 is 0.6666666666666714
# mbloss:  0.03913591429591179
# (dataset)error at epoch 881 is 0.6666666666666714
# mbloss:  0.032637327909469604
# (dataset)error at epoch 882 is 0.6666666666666714
# mbloss:  0.034680940210819244
# (dataset)error at epoch 883 is 0.6666666666666714
# mbloss:  0.03220038488507271
# (dataset)error at epoch 884 is 0.6666666666666714
# mbloss:  0.034093547612428665
# (dataset)error at epoch 885 is 0.6666666666666714
# mbloss:  0.031650055199861526
# (dataset)error at epoch 886 is 0.6666666666666714
# mbloss:  0.033446863293647766
# (dataset)error at epoch 887 is 0.6666666666666714
# mbloss:  0.031110383570194244
# (dataset)error at epoch 888 is 0.6666666666666714
# mbloss:  0.0326266773045063
# (dataset)error at epoch 889 is 0.6666666666666714
# mbloss:  0.033033765852451324
# (dataset)error at epoch 890 is 0.6666666666666714
# mbloss:  0.0369751937687397
# (dataset)error at epoch 891 is 0.6666666666666714
# mbloss:  0.03438751399517059
# (dataset)error at epoch 892 is 0.6666666666666714
# mbloss:  0.04152309149503708
# (dataset)error at epoch 893 is 0.6666666666666714
# mbloss:  0.03461187332868576
# (dataset)error at epoch 894 is 0.6666666666666714
# mbloss:  0.041610799729824066
# (dataset)error at epoch 895 is 0.6666666666666714
# mbloss:  0.033600736409425735
# (dataset)error at epoch 896 is 0.6666666666666714
# mbloss:  0.03855887055397034
# (dataset)error at epoch 897 is 0.6666666666666714
# mbloss:  0.031295549124479294
# (dataset)error at epoch 898 is 0.6666666666666714
# mbloss:  0.033396683633327484
# (dataset)error at epoch 899 is 0.6666666666666714
# mbloss:  0.03053979016840458
# (dataset)error at epoch 900 is 0.6666666666666714
# mbloss:  0.032159850001335144
# (dataset)error at epoch 901 is 0.6666666666666714
# mbloss:  0.029417451471090317
# (dataset)error at epoch 902 is 0.6666666666666714
# mbloss:  0.030271902680397034
# (dataset)error at epoch 903 is 0.6666666666666714
# mbloss:  0.030537638813257217
# (dataset)error at epoch 904 is 0.6666666666666714
# mbloss:  0.033068664371967316
# (dataset)error at epoch 905 is 0.6666666666666714
# mbloss:  0.030736923217773438
# (dataset)error at epoch 906 is 0.6666666666666714
# mbloss:  0.03400178253650665
# (dataset)error at epoch 907 is 0.6666666666666714
# mbloss:  0.032372817397117615
# (dataset)error at epoch 908 is 0.6666666666666714
# mbloss:  0.03910299763083458
# (dataset)error at epoch 909 is 0.6666666666666714
# mbloss:  0.032572850584983826
# (dataset)error at epoch 910 is 0.6666666666666714
# mbloss:  0.03901437297463417
# (dataset)error at epoch 911 is 0.6666666666666714
# mbloss:  0.03148817643523216
# (dataset)error at epoch 912 is 0.6666666666666714
# mbloss:  0.03576589375734329
# (dataset)error at epoch 913 is 0.6666666666666714
# mbloss:  0.029011670500040054
# (dataset)error at epoch 914 is 0.6666666666666714
# mbloss:  0.0305037759244442
# (dataset)error at epoch 915 is 0.6666666666666714
# mbloss:  0.027963029220700264
# (dataset)error at epoch 916 is 0.6666666666666714
# mbloss:  0.028637439012527466
# (dataset)error at epoch 917 is 0.6666666666666714
# mbloss:  0.028738290071487427
# (dataset)error at epoch 918 is 0.6666666666666714
# mbloss:  0.030728207901120186
# (dataset)error at epoch 919 is 0.6666666666666714
# mbloss:  0.02799583040177822
# (dataset)error at epoch 920 is 0.6666666666666714
# mbloss:  0.029453180730342865
# (dataset)error at epoch 921 is 0.6666666666666714
# mbloss:  0.02960030920803547
# (dataset)error at epoch 922 is 0.6666666666666714
# mbloss:  0.033686697483062744
# (dataset)error at epoch 923 is 0.6666666666666714
# mbloss:  0.03326979652047157
# (dataset)error at epoch 924 is 0.6666666666666714
# mbloss:  0.03820027410984039
# (dataset)error at epoch 925 is 0.6666666666666714
# mbloss:  0.03273206949234009
# (dataset)error at epoch 926 is 0.6666666666666714
# mbloss:  0.03570223227143288
# (dataset)error at epoch 927 is 0.6666666666666714
# mbloss:  0.03005121275782585
# (dataset)error at epoch 928 is 0.6666666666666714
# mbloss:  0.03264512121677399
# (dataset)error at epoch 929 is 0.6666666666666714
# mbloss:  0.030218100175261497
# (dataset)error at epoch 930 is 0.6666666666666714
# mbloss:  0.035578202456235886
# (dataset)error at epoch 931 is 0.6666666666666714
# mbloss:  0.029046032577753067
# (dataset)error at epoch 932 is 0.6666666666666714
# mbloss:  0.032768938690423965
# (dataset)error at epoch 933 is 0.6666666666666714
# mbloss:  0.029940109699964523
# (dataset)error at epoch 934 is 0.6666666666666714
# mbloss:  0.035792186856269836
# (dataset)error at epoch 935 is 0.6666666666666714
# mbloss:  0.029875002801418304
# (dataset)error at epoch 936 is 0.6666666666666714
# mbloss:  0.03525393083691597
# (dataset)error at epoch 937 is 0.6666666666666714
# mbloss:  0.027771709486842155
# (dataset)error at epoch 938 is 0.6666666666666714
# mbloss:  0.0301497969776392
# (dataset)error at epoch 939 is 0.6666666666666714
# mbloss:  0.02695120871067047
# (dataset)error at epoch 940 is 0.6666666666666714
# mbloss:  0.028493773192167282
# (dataset)error at epoch 941 is 0.6666666666666714
# mbloss:  0.02594643458724022
# (dataset)error at epoch 942 is 0.6666666666666714
# mbloss:  0.027025150135159492
# (dataset)error at epoch 943 is 0.6666666666666714
# mbloss:  0.027229322120547295
# (dataset)error at epoch 944 is 0.6666666666666714
# mbloss:  0.029868418350815773
# (dataset)error at epoch 945 is 0.6666666666666714
# mbloss:  0.028488334268331528
# (dataset)error at epoch 946 is 0.6666666666666714
# mbloss:  0.03336283192038536
# (dataset)error at epoch 947 is 0.6666666666666714
# mbloss:  0.026577448472380638
# (dataset)error at epoch 948 is 0.6666666666666714
# mbloss:  0.028815193101763725
# (dataset)error at epoch 949 is 0.6666666666666714
# mbloss:  0.025934476405382156
# (dataset)error at epoch 950 is 0.6666666666666714
# mbloss:  0.027541041374206543
# (dataset)error at epoch 951 is 0.6666666666666714
# mbloss:  0.02547895349562168
# (dataset)error at epoch 952 is 0.6666666666666714
# mbloss:  0.02701062336564064
# (dataset)error at epoch 953 is 0.6666666666666714
# mbloss:  0.025228479877114296
# (dataset)error at epoch 954 is 0.6666666666666714
# mbloss:  0.026753513142466545
# (dataset)error at epoch 955 is 0.6666666666666714
# mbloss:  0.025048550218343735
# (dataset)error at epoch 956 is 0.6666666666666714
# mbloss:  0.02666521444916725
# (dataset)error at epoch 957 is 0.6666666666666714
# mbloss:  0.025387560948729515
# (dataset)error at epoch 958 is 0.6666666666666714
# mbloss:  0.027554944157600403
# (dataset)error at epoch 959 is 0.6666666666666714
# mbloss:  0.026315899565815926
# (dataset)error at epoch 960 is 0.6666666666666714
# mbloss:  0.030480463057756424
# (dataset)error at epoch 961 is 0.6666666666666714
# mbloss:  0.030975280329585075
# (dataset)error at epoch 962 is 0.6666666666666714
# mbloss:  0.03875023126602173
# (dataset)error at epoch 963 is 0.6666666666666714
# mbloss:  0.0287435632199049
# (dataset)error at epoch 964 is 0.6666666666666714
# mbloss:  0.03658534213900566
# (dataset)error at epoch 965 is 0.6666666666666714
# mbloss:  0.03146704286336899
# (dataset)error at epoch 966 is 2.0
# mbloss:  0.046617455780506134
# (dataset)error at epoch 967 is 0.6666666666666714
# mbloss:  0.03619644418358803
# (dataset)error at epoch 968 is 3.3333333333333286
# mbloss:  0.05230792239308357
# (dataset)error at epoch 969 is 0.6666666666666714
# mbloss:  0.03432343900203705
# (dataset)error at epoch 970 is 0.6666666666666714
# mbloss:  0.04022752121090889
# (dataset)error at epoch 971 is 0.6666666666666714
# mbloss:  0.02759658731520176
# (dataset)error at epoch 972 is 0.6666666666666714
# mbloss:  0.029723595827817917
# (dataset)error at epoch 973 is 0.6666666666666714
# mbloss:  0.025453461334109306
# (dataset)error at epoch 974 is 0.6666666666666714
# mbloss:  0.026802852749824524
# (dataset)error at epoch 975 is 0.6666666666666714
# mbloss:  0.024140706285834312
# (dataset)error at epoch 976 is 0.6666666666666714
# mbloss:  0.024776335805654526
# (dataset)error at epoch 977 is 0.6666666666666714
# mbloss:  0.024636471644043922
# (dataset)error at epoch 978 is 0.6666666666666714
# mbloss:  0.026226786896586418
# (dataset)error at epoch 979 is 0.6666666666666714
# mbloss:  0.025109998881816864
# (dataset)error at epoch 980 is 0.6666666666666714
# mbloss:  0.02744188904762268
# (dataset)error at epoch 981 is 0.6666666666666714
# mbloss:  0.024303974583745003
# (dataset)error at epoch 982 is 0.6666666666666714
# mbloss:  0.026018470525741577
# (dataset)error at epoch 983 is 0.6666666666666714
# mbloss:  0.023816697299480438
# (dataset)error at epoch 984 is 0.6666666666666714
# mbloss:  0.02535315789282322
# (dataset)error at epoch 985 is 0.6666666666666714
# mbloss:  0.0236284788697958
# (dataset)error at epoch 986 is 0.6666666666666714
# mbloss:  0.0251864455640316
# (dataset)error at epoch 987 is 0.6666666666666714
# mbloss:  0.023409849032759666
# (dataset)error at epoch 988 is 0.6666666666666714
# mbloss:  0.024799643084406853
# (dataset)error at epoch 989 is 0.6666666666666714
# mbloss:  0.023120611906051636
# (dataset)error at epoch 990 is 0.6666666666666714
# mbloss:  0.024463506415486336
# (dataset)error at epoch 991 is 0.6666666666666714
# mbloss:  0.022662365809082985
# (dataset)error at epoch 992 is 0.6666666666666714
# mbloss:  0.02351103536784649
# (dataset)error at epoch 993 is 0.6666666666666714
# mbloss:  0.024237073957920074
# (dataset)error at epoch 994 is 0.6666666666666714
# mbloss:  0.028823215514421463
# (dataset)error at epoch 995 is 0.6666666666666714
# mbloss:  0.02867128886282444
# (dataset)error at epoch 996 is 0.6666666666666714
# mbloss:  0.03657255321741104
# (dataset)error at epoch 997 is 0.6666666666666714
# mbloss:  0.03565068170428276
# (dataset)error at epoch 998 is 4.0
# mbloss:  0.05538150668144226
# (dataset)error at epoch 999 is 1.3333333333333286
# mbloss:  0.04106079787015915
# (dataset)error at epoch 1000 is 4.0
# mbloss:  0.0583992525935173
# (dataset)error at epoch 1001 is 0.0
# Test error of loop 2 is 0.0!
# The final model has the architecture: Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=2, out_features=3, bias=False)
#   (2): ReLU()
#   (3): ResBlock1(
#     (af1): ReLU()
#     (l1): Linear(in_features=3, out_features=3, bias=True)
#     (shortcut): Sequential()
#     (l2): Linear(in_features=3, out_features=3, bias=False)
#   )
#   (4): ResBlock1(
#     (af1): ReLU()
#     (l1): Linear(in_features=3, out_features=3, bias=True)
#     (shortcut): Sequential()
#     (l2): Linear(in_features=3, out_features=3, bias=False)
#   )
#   (5): Linear(in_features=3, out_features=2, bias=False)
# )
# norm of values of parameters (parameter-wise) at layer insertion: [tensor(1.8254), tensor(1.7476), tensor(1.5964), tensor(2.1571), tensor(1.7321), tensor(0.), tensor(0.), tensor(2.2407)]

# %%
if T2:
    print('test error: ',check_testerror(vd, model2))
    print('train error: ',check_testerror(td, model2))
# Out:
# test error:  0.0
# train error:  1.1111111111111143

# %%
plot_decision_boundary(model2, data_X, data_y)

# %% [markdown]
# plot results:

# %%
# todo plot
if T2:
    plt.figure(figsize=(20,5))
    plt.grid(which='major', axis='x', zorder=-1.0)
    xfull = range(1,len(mb_losses2)+1)
    yfull = mb_losses2
    begin=0
    end=0
    for i in range(len(end_list)):
        end=end+end_list[i]
        x_curr= xfull[begin:end]
        y_curr= yfull[begin:end]
        begin=end
        plt.plot(x_curr,y_curr,'o')
    plt.xlabel('minibatch iterations')
    plt.ylabel('minibatch loss')

    plt.yscale('log')
    #plt.ylim((0.4,.6))
    #plt.xlim((99300,99800))
    
    plt.grid()
    plt.plot(np.zeros(len(mb_losses2)))

# %%
if True and T2:
    plt.figure(figsize=(20,5))
    l1 = len(grad_norms2[0])
    l2 = len(grad_norms2[1])
    len_t1 = len(grad_norms2[0][0])
    len_t2 = len(grad_norms2[1][0])
    for i in range(l1):
        plt.plot(grad_norms2[0][i], label=f'0_{i}')
    for j in range(l2):
        #print(list(range(len_t1,len_t2+len_t1)))
        plt.plot(list(range(len_t1,len_t2+len_t1)), grad_norms2[1][j],label=f'1_{j}')
    plt.legend()
    plt.yscale('log')
    plt.xlabel('iterations')
    plt.ylabel('layerwise gradient norms scaled by lr')
    #plt.xlim(900,1100)

# %%
# todo plot
if False:
    plt.figure(figsize=(20,5))
    plt.grid(which='major', axis='x', zorder=-1.0)
    xfull = range(1,len(grad_norms2)+1)
    yfull = grad_norms2
    begin=0
    end=0
    for i in range(len(end_list)):
        end=end+end_list[i]
        x_curr= xfull[begin:end]
        y_curr= yfull[begin:end]
        begin=end
        plt.plot(x_curr,y_curr,'o')
    plt.xlabel('minibatch iterations')
    plt.ylabel('squared grad norm')

    plt.yscale('log')
    #plt.ylim((0.4,.6))
    #plt.xlim((99300,99800))
    
    plt.grid()
    plt.plot(np.zeros(len(grad_norms2)))

# %%
if T2:
    plt.figure(figsize=(20,5))
    #plt.ylim((0,100))
    plt.plot([initial_train_acc2]+test_errors2,'o')
    plt.ylim(bottom=0)
    plt.grid()

# %%
plt.figure(figsize=(20,5))

plt.plot(mb_losses1,label='ali max')
if T2:
    plt.plot(mb_losses2, '--',label='ali min')
plt.xlabel('iterations')
plt.ylabel('loss')

plt.yscale('log')

plt.legend()
#plt.ylim((1e-8,1.1))
#plt.xlim((80,100))
plt.show()

# %% [markdown]
# ## Third training

# %%
# build model
if _type=='fwd':
    model_classical = feed_forward(dim_in, dim_out,**kwargs_net_classical)
if _type=='res2':
    model_classical = two_weight_resnet(dim_in, dim_out,**kwargs_net_classical)
if _type=='res1':
    model_classical = one_weight_resnet(dim_in, dim_out,**kwargs_net_classical)

torch.nn.utils.vector_to_parameters(param_init_class,model_classical.parameters())

# %%
print('test error: ',check_testerror(vd, model_classical))
print('train error: ',check_testerror(td, model_classical))
initial_train_acc_class = check_testerror(td, model_classical)
# Out:
# test error:  48.0
# train error:  46.44444444444444

# %%
plot_decision_boundary(model_classical, data_X, data_y)

# %%
# build optimizer
if optimizer_type == 'SGD':
    optimizer_classical = torch.optim.SGD(model_classical.parameters(), lr_init_classical)
if optimizer_type == 'Adam':
    optimizer_classical = torch.optim.Adam(model_classical.parameters(), lr_init_classical)

# build lr scheduler
if lrscheduler_type == 'StepLR':
    step_size = lrscheduler_args_classical['step_size']
    gamma = lrscheduler_args_classical['gamma']
    lrscheduler_classical = torch.optim.lr_scheduler.StepLR(
            optimizer_classical, step_size=step_size, gamma=gamma)

# %%
if T3:
    print('training classically on model', model_classical)
    mblosses_classical, lr_end, test_error_classical, exit_flag_classical, grad_norms_classical, times_classical = train(model_classical,
                                                             train_dataloader=td,
                                                             epochs=epochs_classical,
                                                             optimizer=optimizer_classical,
                                                             scheduler=lrscheduler_classical,
                                                             wanted_testerror=wanted_testerror,
                                                             start_with_backtracking=None,
                                                             check_testerror_between=interval_testerror,
                                                             test_dataloader=vd,
                                                             print_param_flag=False,
                                                             save_grad_norms=save_grad_norms
                                                             )
# Out:
# training classically on model Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=2, out_features=3, bias=False)
#   (2): ReLU()
#   (3): ResBlock1(
#     (af1): ReLU()
#     (l1): Linear(in_features=3, out_features=3, bias=True)
#     (shortcut): Sequential()
#     (l2): Linear(in_features=3, out_features=3, bias=False)
#   )
#   (4): Linear(in_features=3, out_features=2, bias=False)
# )
# mbloss:  0.6812913417816162
# (dataset)error at epoch 0 is 48.0
# mbloss:  0.6809448003768921
# (dataset)error at epoch 1 is 49.33333333333333
# mbloss:  0.6806014180183411
# (dataset)error at epoch 2 is 50.0
# mbloss:  0.6802606582641602
# (dataset)error at epoch 3 is 49.33333333333333
# mbloss:  0.6799336075782776
# (dataset)error at epoch 4 is 49.33333333333333
# mbloss:  0.6796112060546875
# (dataset)error at epoch 5 is 49.33333333333333
# mbloss:  0.6792930364608765
# (dataset)error at epoch 6 is 49.33333333333333
# mbloss:  0.6789785027503967
# (dataset)error at epoch 7 is 49.33333333333333
# mbloss:  0.678666353225708
# (dataset)error at epoch 8 is 49.33333333333333
# mbloss:  0.6783586740493774
# (dataset)error at epoch 9 is 48.66666666666667
# mbloss:  0.6780556440353394
# (dataset)error at epoch 10 is 48.66666666666667
# mbloss:  0.6777569651603699
# (dataset)error at epoch 11 is 50.0
# mbloss:  0.6774620413780212
# (dataset)error at epoch 12 is 50.0
# mbloss:  0.6771703362464905
# (dataset)error at epoch 13 is 50.0
# mbloss:  0.6768833994865417
# (dataset)error at epoch 14 is 50.0
# mbloss:  0.676600456237793
# (dataset)error at epoch 15 is 50.0
# mbloss:  0.6763217449188232
# (dataset)error at epoch 16 is 50.0
# mbloss:  0.6760468482971191
# (dataset)error at epoch 17 is 50.0
# mbloss:  0.6757758259773254
# (dataset)error at epoch 18 is 50.0
# mbloss:  0.6755099892616272
# (dataset)error at epoch 19 is 50.0
# mbloss:  0.6752498149871826
# (dataset)error at epoch 20 is 50.0
# mbloss:  0.6749963164329529
# (dataset)error at epoch 21 is 50.666666666666664
# mbloss:  0.6747470498085022
# (dataset)error at epoch 22 is 50.666666666666664
# mbloss:  0.6745008826255798
# (dataset)error at epoch 23 is 50.666666666666664
# mbloss:  0.674258291721344
# (dataset)error at epoch 24 is 50.666666666666664
# mbloss:  0.6740186810493469
# (dataset)error at epoch 25 is 50.666666666666664
# mbloss:  0.6737834811210632
# (dataset)error at epoch 26 is 50.666666666666664
# mbloss:  0.673551619052887
# (dataset)error at epoch 27 is 51.33333333333333
# mbloss:  0.6733241677284241
# (dataset)error at epoch 28 is 51.33333333333333
# mbloss:  0.6731002330780029
# (dataset)error at epoch 29 is 51.33333333333333
# mbloss:  0.6728763580322266
# (dataset)error at epoch 30 is 52.0
# mbloss:  0.6726546287536621
# (dataset)error at epoch 31 is 52.0
# mbloss:  0.672435998916626
# (dataset)error at epoch 32 is 52.0
# mbloss:  0.6722186803817749
# (dataset)error at epoch 33 is 52.0
# mbloss:  0.6720050573348999
# (dataset)error at epoch 34 is 52.0
# mbloss:  0.67179274559021
# (dataset)error at epoch 35 is 52.0
# mbloss:  0.6715804934501648
# (dataset)error at epoch 36 is 52.0
# mbloss:  0.6713688969612122
# (dataset)error at epoch 37 is 52.0
# mbloss:  0.6711567044258118
# (dataset)error at epoch 38 is 52.0
# mbloss:  0.6709426045417786
# (dataset)error at epoch 39 is 52.666666666666664
# mbloss:  0.6707177758216858
# (dataset)error at epoch 40 is 52.0
# mbloss:  0.6704819798469543
# (dataset)error at epoch 41 is 52.0
# mbloss:  0.6702431440353394
# (dataset)error at epoch 42 is 51.33333333333333
# mbloss:  0.6700035333633423
# (dataset)error at epoch 43 is 51.33333333333333
# mbloss:  0.6697595119476318
# (dataset)error at epoch 44 is 51.33333333333333
# mbloss:  0.6695136427879333
# (dataset)error at epoch 45 is 51.33333333333333
# mbloss:  0.6692603826522827
# (dataset)error at epoch 46 is 51.33333333333333
# mbloss:  0.6689901351928711
# (dataset)error at epoch 47 is 51.33333333333333
# mbloss:  0.6687139272689819
# (dataset)error at epoch 48 is 51.33333333333333
# mbloss:  0.668437659740448
# (dataset)error at epoch 49 is 51.33333333333333
# mbloss:  0.6681627631187439
# (dataset)error at epoch 50 is 50.666666666666664
# mbloss:  0.6678860187530518
# (dataset)error at epoch 51 is 50.666666666666664
# mbloss:  0.6676080822944641
# (dataset)error at epoch 52 is 51.33333333333333
# mbloss:  0.6673297882080078
# (dataset)error at epoch 53 is 51.33333333333333
# mbloss:  0.6670527458190918
# (dataset)error at epoch 54 is 51.33333333333333
# mbloss:  0.6667795777320862
# (dataset)error at epoch 55 is 51.33333333333333
# mbloss:  0.6665369868278503
# (dataset)error at epoch 56 is 51.33333333333333
# mbloss:  0.6663162112236023
# (dataset)error at epoch 57 is 51.33333333333333
# mbloss:  0.6661088466644287
# (dataset)error at epoch 58 is 51.33333333333333
# mbloss:  0.6659088134765625
# (dataset)error at epoch 59 is 51.33333333333333
# mbloss:  0.6657177209854126
# (dataset)error at epoch 60 is 50.666666666666664
# mbloss:  0.6655365824699402
# (dataset)error at epoch 61 is 51.33333333333333
# mbloss:  0.6653650403022766
# (dataset)error at epoch 62 is 51.33333333333333
# mbloss:  0.6652003526687622
# (dataset)error at epoch 63 is 52.0
# mbloss:  0.6650424599647522
# (dataset)error at epoch 64 is 52.0
# mbloss:  0.6648909449577332
# (dataset)error at epoch 65 is 52.666666666666664
# mbloss:  0.6647430658340454
# (dataset)error at epoch 66 is 52.666666666666664
# mbloss:  0.66459721326828
# (dataset)error at epoch 67 is 50.666666666666664
# mbloss:  0.6644572615623474
# (dataset)error at epoch 68 is 50.666666666666664
# mbloss:  0.6643226742744446
# (dataset)error at epoch 69 is 50.666666666666664
# mbloss:  0.6641942262649536
# (dataset)error at epoch 70 is 50.666666666666664
# mbloss:  0.6640708446502686
# (dataset)error at epoch 71 is 50.666666666666664
# mbloss:  0.6639522314071655
# (dataset)error at epoch 72 is 50.666666666666664
# mbloss:  0.6638365387916565
# (dataset)error at epoch 73 is 50.666666666666664
# mbloss:  0.6637253761291504
# (dataset)error at epoch 74 is 50.666666666666664
# mbloss:  0.6636162400245667
# (dataset)error at epoch 75 is 50.666666666666664
# mbloss:  0.6635102033615112
# (dataset)error at epoch 76 is 50.666666666666664
# mbloss:  0.6634098291397095
# (dataset)error at epoch 77 is 50.666666666666664
# mbloss:  0.6633115410804749
# (dataset)error at epoch 78 is 50.666666666666664
# mbloss:  0.6632151007652283
# (dataset)error at epoch 79 is 50.666666666666664
# mbloss:  0.6631226539611816
# (dataset)error at epoch 80 is 50.666666666666664
# mbloss:  0.6630329489707947
# (dataset)error at epoch 81 is 50.666666666666664
# mbloss:  0.6629466414451599
# (dataset)error at epoch 82 is 50.666666666666664
# mbloss:  0.6628617644309998
# (dataset)error at epoch 83 is 50.666666666666664
# mbloss:  0.6627793312072754
# (dataset)error at epoch 84 is 50.666666666666664
# mbloss:  0.6626996994018555
# (dataset)error at epoch 85 is 50.666666666666664
# mbloss:  0.6626212000846863
# (dataset)error at epoch 86 is 50.666666666666664
# mbloss:  0.6625439524650574
# (dataset)error at epoch 87 is 50.666666666666664
# mbloss:  0.6624693274497986
# (dataset)error at epoch 88 is 50.666666666666664
# mbloss:  0.6623978018760681
# (dataset)error at epoch 89 is 50.666666666666664
# mbloss:  0.6623285412788391
# (dataset)error at epoch 90 is 50.666666666666664
# mbloss:  0.6622603535652161
# (dataset)error at epoch 91 is 50.666666666666664
# mbloss:  0.6621893048286438
# (dataset)error at epoch 92 is 50.666666666666664
# mbloss:  0.6621197462081909
# (dataset)error at epoch 93 is 50.666666666666664
# mbloss:  0.6620517373085022
# (dataset)error at epoch 94 is 50.666666666666664
# mbloss:  0.6619848608970642
# (dataset)error at epoch 95 is 50.666666666666664
# mbloss:  0.6619188189506531
# (dataset)error at epoch 96 is 50.666666666666664
# mbloss:  0.6618532538414001
# (dataset)error at epoch 97 is 50.666666666666664
# mbloss:  0.6617885231971741
# (dataset)error at epoch 98 is 50.666666666666664
# mbloss:  0.661727249622345
# (dataset)error at epoch 99 is 50.666666666666664
# mbloss:  0.6616677045822144
# (dataset)error at epoch 100 is 50.666666666666664
# mbloss:  0.6616091132164001
# (dataset)error at epoch 101 is 50.666666666666664
# mbloss:  0.6615512371063232
# (dataset)error at epoch 102 is 50.666666666666664
# mbloss:  0.6614941358566284
# (dataset)error at epoch 103 is 50.666666666666664
# mbloss:  0.661437451839447
# (dataset)error at epoch 104 is 50.666666666666664
# mbloss:  0.6613817811012268
# (dataset)error at epoch 105 is 50.666666666666664
# mbloss:  0.6613259315490723
# (dataset)error at epoch 106 is 50.666666666666664
# mbloss:  0.6612704992294312
# (dataset)error at epoch 107 is 50.666666666666664
# mbloss:  0.661215603351593
# (dataset)error at epoch 108 is 50.666666666666664
# mbloss:  0.6611610054969788
# (dataset)error at epoch 109 is 50.666666666666664
# mbloss:  0.6611078977584839
# (dataset)error at epoch 110 is 50.666666666666664
# mbloss:  0.6610549092292786
# (dataset)error at epoch 111 is 50.666666666666664
# mbloss:  0.6610023379325867
# (dataset)error at epoch 112 is 50.666666666666664
# mbloss:  0.6609500050544739
# (dataset)error at epoch 113 is 50.666666666666664
# mbloss:  0.6608974933624268
# (dataset)error at epoch 114 is 50.666666666666664
# mbloss:  0.6608452200889587
# (dataset)error at epoch 115 is 50.666666666666664
# mbloss:  0.6607940793037415
# (dataset)error at epoch 116 is 50.666666666666664
# mbloss:  0.6607433557510376
# (dataset)error at epoch 117 is 50.666666666666664
# mbloss:  0.66069096326828
# (dataset)error at epoch 118 is 50.666666666666664
# mbloss:  0.6606312394142151
# (dataset)error at epoch 119 is 50.666666666666664
# mbloss:  0.6605718731880188
# (dataset)error at epoch 120 is 50.666666666666664
# mbloss:  0.6605126261711121
# (dataset)error at epoch 121 is 50.666666666666664
# mbloss:  0.6604532599449158
# (dataset)error at epoch 122 is 50.666666666666664
# mbloss:  0.6603940725326538
# (dataset)error at epoch 123 is 50.666666666666664
# mbloss:  0.6603354215621948
# (dataset)error at epoch 124 is 50.666666666666664
# mbloss:  0.6602776646614075
# (dataset)error at epoch 125 is 50.666666666666664
# mbloss:  0.6602202653884888
# (dataset)error at epoch 126 is 50.666666666666664
# mbloss:  0.6601631045341492
# (dataset)error at epoch 127 is 50.666666666666664
# mbloss:  0.6601090431213379
# (dataset)error at epoch 128 is 50.666666666666664
# mbloss:  0.660057783126831
# (dataset)error at epoch 129 is 50.666666666666664
# mbloss:  0.6600061058998108
# (dataset)error at epoch 130 is 50.666666666666664
# mbloss:  0.6599542498588562
# (dataset)error at epoch 131 is 50.666666666666664
# mbloss:  0.6599018573760986
# (dataset)error at epoch 132 is 50.666666666666664
# mbloss:  0.6598491072654724
# (dataset)error at epoch 133 is 50.666666666666664
# mbloss:  0.6597960591316223
# (dataset)error at epoch 134 is 50.666666666666664
# mbloss:  0.6597427129745483
# (dataset)error at epoch 135 is 50.666666666666664
# mbloss:  0.6596888303756714
# (dataset)error at epoch 136 is 50.666666666666664
# mbloss:  0.6596353650093079
# (dataset)error at epoch 137 is 50.666666666666664
# mbloss:  0.6595814824104309
# (dataset)error at epoch 138 is 50.666666666666664
# mbloss:  0.6595271229743958
# (dataset)error at epoch 139 is 50.666666666666664
# mbloss:  0.6594724059104919
# (dataset)error at epoch 140 is 50.666666666666664
# mbloss:  0.6594171524047852
# (dataset)error at epoch 141 is 50.666666666666664
# mbloss:  0.6593614816665649
# (dataset)error at epoch 142 is 50.666666666666664
# mbloss:  0.6593053936958313
# (dataset)error at epoch 143 is 50.666666666666664
# mbloss:  0.659248948097229
# (dataset)error at epoch 144 is 50.666666666666664
# mbloss:  0.6591918468475342
# (dataset)error at epoch 145 is 50.666666666666664
# mbloss:  0.6591343283653259
# (dataset)error at epoch 146 is 50.666666666666664
# mbloss:  0.6590762734413147
# (dataset)error at epoch 147 is 50.666666666666664
# mbloss:  0.6590177416801453
# (dataset)error at epoch 148 is 50.666666666666664
# mbloss:  0.6589587330818176
# (dataset)error at epoch 149 is 50.666666666666664
# mbloss:  0.6588991284370422
# (dataset)error at epoch 150 is 50.666666666666664
# mbloss:  0.6588389873504639
# (dataset)error at epoch 151 is 50.666666666666664
# mbloss:  0.6587784886360168
# (dataset)error at epoch 152 is 50.666666666666664
# mbloss:  0.658717691898346
# (dataset)error at epoch 153 is 50.666666666666664
# mbloss:  0.6586561799049377
# (dataset)error at epoch 154 is 50.666666666666664
# mbloss:  0.658594012260437
# (dataset)error at epoch 155 is 50.666666666666664
# mbloss:  0.6585312485694885
# (dataset)error at epoch 156 is 50.666666666666664
# mbloss:  0.6584680080413818
# (dataset)error at epoch 157 is 50.666666666666664
# mbloss:  0.6584039330482483
# (dataset)error at epoch 158 is 50.666666666666664
# mbloss:  0.6583391427993774
# (dataset)error at epoch 159 is 50.666666666666664
# mbloss:  0.6582732200622559
# (dataset)error at epoch 160 is 50.666666666666664
# mbloss:  0.658206582069397
# (dataset)error at epoch 161 is 50.666666666666664
# mbloss:  0.6581393480300903
# (dataset)error at epoch 162 is 50.666666666666664
# mbloss:  0.6580722332000732
# (dataset)error at epoch 163 is 50.666666666666664
# mbloss:  0.658004641532898
# (dataset)error at epoch 164 is 50.666666666666664
# mbloss:  0.6579362750053406
# (dataset)error at epoch 165 is 50.666666666666664
# mbloss:  0.6578673124313354
# (dataset)error at epoch 166 is 50.666666666666664
# mbloss:  0.6577976942062378
# (dataset)error at epoch 167 is 50.666666666666664
# mbloss:  0.6577277183532715
# (dataset)error at epoch 168 is 50.666666666666664
# mbloss:  0.657657265663147
# (dataset)error at epoch 169 is 50.666666666666664
# mbloss:  0.6575860977172852
# (dataset)error at epoch 170 is 50.666666666666664
# mbloss:  0.657514214515686
# (dataset)error at epoch 171 is 50.666666666666664
# mbloss:  0.6574417948722839
# (dataset)error at epoch 172 is 50.666666666666664
# mbloss:  0.6573684811592102
# (dataset)error at epoch 173 is 50.666666666666664
# mbloss:  0.657294511795044
# (dataset)error at epoch 174 is 50.666666666666664
# mbloss:  0.6572198271751404
# (dataset)error at epoch 175 is 50.666666666666664
# mbloss:  0.6571445465087891
# (dataset)error at epoch 176 is 50.666666666666664
# mbloss:  0.6570687294006348
# (dataset)error at epoch 177 is 50.666666666666664
# mbloss:  0.6569921970367432
# (dataset)error at epoch 178 is 50.666666666666664
# mbloss:  0.6569148302078247
# (dataset)error at epoch 179 is 50.666666666666664
# mbloss:  0.656836748123169
# (dataset)error at epoch 180 is 50.666666666666664
# mbloss:  0.6567578911781311
# (dataset)error at epoch 181 is 50.666666666666664
# mbloss:  0.6566782593727112
# (dataset)error at epoch 182 is 50.666666666666664
# mbloss:  0.6565977931022644
# (dataset)error at epoch 183 is 50.666666666666664
# mbloss:  0.6565163731575012
# (dataset)error at epoch 184 is 50.666666666666664
# mbloss:  0.6564341187477112
# (dataset)error at epoch 185 is 50.666666666666664
# mbloss:  0.6563512086868286
# (dataset)error at epoch 186 is 50.666666666666664
# mbloss:  0.6562672853469849
# (dataset)error at epoch 187 is 50.666666666666664
# mbloss:  0.6561825275421143
# (dataset)error at epoch 188 is 50.666666666666664
# mbloss:  0.6560968160629272
# (dataset)error at epoch 189 is 50.666666666666664
# mbloss:  0.656010091304779
# (dataset)error at epoch 190 is 50.666666666666664
# mbloss:  0.6559223532676697
# (dataset)error at epoch 191 is 50.666666666666664
# mbloss:  0.6558334231376648
# (dataset)error at epoch 192 is 50.666666666666664
# mbloss:  0.6557433605194092
# (dataset)error at epoch 193 is 50.666666666666664
# mbloss:  0.6556528210639954
# (dataset)error at epoch 194 is 50.666666666666664
# mbloss:  0.6555612683296204
# (dataset)error at epoch 195 is 50.0
# mbloss:  0.655468761920929
# (dataset)error at epoch 196 is 50.0
# mbloss:  0.6553752422332764
# (dataset)error at epoch 197 is 50.0
# mbloss:  0.6552807688713074
# (dataset)error at epoch 198 is 50.0
# mbloss:  0.6551852226257324
# (dataset)error at epoch 199 is 50.0
# mbloss:  0.6550887823104858
# (dataset)error at epoch 200 is 50.0
# mbloss:  0.6549913883209229
# (dataset)error at epoch 201 is 50.0
# mbloss:  0.6548929810523987
# (dataset)error at epoch 202 is 50.0
# mbloss:  0.6547935605049133
# (dataset)error at epoch 203 is 50.0
# mbloss:  0.6546929478645325
# (dataset)error at epoch 204 is 50.0
# mbloss:  0.6545913815498352
# (dataset)error at epoch 205 is 50.0
# mbloss:  0.654488742351532
# (dataset)error at epoch 206 is 50.0
# mbloss:  0.6543847918510437
# (dataset)error at epoch 207 is 50.0
# mbloss:  0.6542797684669495
# (dataset)error at epoch 208 is 50.0
# mbloss:  0.6541736125946045
# (dataset)error at epoch 209 is 50.0
# mbloss:  0.6540660858154297
# (dataset)error at epoch 210 is 50.0
# mbloss:  0.6539574265480042
# (dataset)error at epoch 211 is 50.0
# mbloss:  0.6538476347923279
# (dataset)error at epoch 212 is 50.0
# mbloss:  0.653736412525177
# (dataset)error at epoch 213 is 50.0
# mbloss:  0.6536239385604858
# (dataset)error at epoch 214 is 50.0
# mbloss:  0.6535102128982544
# (dataset)error at epoch 215 is 50.0
# mbloss:  0.6533949971199036
# (dataset)error at epoch 216 is 50.0
# mbloss:  0.6532785296440125
# (dataset)error at epoch 217 is 50.0
# mbloss:  0.6531603932380676
# (dataset)error at epoch 218 is 50.0
# mbloss:  0.6530401110649109
# (dataset)error at epoch 219 is 50.0
# mbloss:  0.6529181003570557
# (dataset)error at epoch 220 is 50.0
# mbloss:  0.6527951955795288
# (dataset)error at epoch 221 is 50.0
# mbloss:  0.6526709198951721
# (dataset)error at epoch 222 is 50.0
# mbloss:  0.652545154094696
# (dataset)error at epoch 223 is 50.0
# mbloss:  0.652417778968811
# (dataset)error at epoch 224 is 50.0
# mbloss:  0.652289092540741
# (dataset)error at epoch 225 is 50.0
# mbloss:  0.6521586775779724
# (dataset)error at epoch 226 is 50.0
# mbloss:  0.6520267724990845
# (dataset)error at epoch 227 is 50.0
# mbloss:  0.6518932580947876
# (dataset)error at epoch 228 is 50.0
# mbloss:  0.6517579555511475
# (dataset)error at epoch 229 is 50.0
# mbloss:  0.6516211628913879
# (dataset)error at epoch 230 is 50.0
# mbloss:  0.6514825224876404
# (dataset)error at epoch 231 is 50.0
# mbloss:  0.6513422131538391
# (dataset)error at epoch 232 is 49.33333333333333
# mbloss:  0.6512002348899841
# (dataset)error at epoch 233 is 49.33333333333333
# mbloss:  0.6510562300682068
# (dataset)error at epoch 234 is 49.33333333333333
# mbloss:  0.650910496711731
# (dataset)error at epoch 235 is 49.33333333333333
# mbloss:  0.6507630348205566
# (dataset)error at epoch 236 is 49.33333333333333
# mbloss:  0.6506134867668152
# (dataset)error at epoch 237 is 49.33333333333333
# mbloss:  0.6504620313644409
# (dataset)error at epoch 238 is 49.33333333333333
# mbloss:  0.6503088474273682
# (dataset)error at epoch 239 is 49.33333333333333
# mbloss:  0.6501544713973999
# (dataset)error at epoch 240 is 49.33333333333333
# mbloss:  0.6499974727630615
# (dataset)error at epoch 241 is 49.33333333333333
# mbloss:  0.6498350501060486
# (dataset)error at epoch 242 is 49.33333333333333
# mbloss:  0.6496708393096924
# (dataset)error at epoch 243 is 49.33333333333333
# mbloss:  0.6495050191879272
# (dataset)error at epoch 244 is 49.33333333333333
# mbloss:  0.6493374109268188
# (dataset)error at epoch 245 is 49.33333333333333
# mbloss:  0.6491679549217224
# (dataset)error at epoch 246 is 49.33333333333333
# mbloss:  0.6489967107772827
# (dataset)error at epoch 247 is 49.33333333333333
# mbloss:  0.6488234400749207
# (dataset)error at epoch 248 is 49.33333333333333
# mbloss:  0.6486481428146362
# (dataset)error at epoch 249 is 49.33333333333333
# mbloss:  0.648470938205719
# (dataset)error at epoch 250 is 48.66666666666667
# mbloss:  0.6482915878295898
# (dataset)error at epoch 251 is 48.66666666666667
# mbloss:  0.6481100916862488
# (dataset)error at epoch 252 is 48.66666666666667
# mbloss:  0.647926390171051
# (dataset)error at epoch 253 is 48.66666666666667
# mbloss:  0.647739589214325
# (dataset)error at epoch 254 is 48.66666666666667
# mbloss:  0.6475459337234497
# (dataset)error at epoch 255 is 48.66666666666667
# mbloss:  0.6473501324653625
# (dataset)error at epoch 256 is 48.66666666666667
# mbloss:  0.6471522450447083
# (dataset)error at epoch 257 is 48.66666666666667
# mbloss:  0.6469521522521973
# (dataset)error at epoch 258 is 48.0
# mbloss:  0.6467511057853699
# (dataset)error at epoch 259 is 48.0
# mbloss:  0.6465497016906738
# (dataset)error at epoch 260 is 48.0
# mbloss:  0.6463459730148315
# (dataset)error at epoch 261 is 48.0
# mbloss:  0.6461399793624878
# (dataset)error at epoch 262 is 48.0
# mbloss:  0.6459314823150635
# (dataset)error at epoch 263 is 48.0
# mbloss:  0.6457206010818481
# (dataset)error at epoch 264 is 48.0
# mbloss:  0.6455036997795105
# (dataset)error at epoch 265 is 48.0
# mbloss:  0.6452766060829163
# (dataset)error at epoch 266 is 48.0
# mbloss:  0.6450498700141907
# (dataset)error at epoch 267 is 48.0
# mbloss:  0.6448213458061218
# (dataset)error at epoch 268 is 48.0
# mbloss:  0.6445909142494202
# (dataset)error at epoch 269 is 48.0
# mbloss:  0.6443583369255066
# (dataset)error at epoch 270 is 48.0
# mbloss:  0.6441235542297363
# (dataset)error at epoch 271 is 47.333333333333336
# mbloss:  0.6438853144645691
# (dataset)error at epoch 272 is 47.333333333333336
# mbloss:  0.643630862236023
# (dataset)error at epoch 273 is 47.333333333333336
# mbloss:  0.6433750987052917
# (dataset)error at epoch 274 is 47.333333333333336
# mbloss:  0.6431177854537964
# (dataset)error at epoch 275 is 47.333333333333336
# mbloss:  0.6428571343421936
# (dataset)error at epoch 276 is 47.333333333333336
# mbloss:  0.6425943374633789
# (dataset)error at epoch 277 is 47.333333333333336
# mbloss:  0.6423282623291016
# (dataset)error at epoch 278 is 46.666666666666664
# mbloss:  0.6420460939407349
# (dataset)error at epoch 279 is 46.666666666666664
# mbloss:  0.6417630314826965
# (dataset)error at epoch 280 is 46.666666666666664
# mbloss:  0.6414785385131836
# (dataset)error at epoch 281 is 46.666666666666664
# mbloss:  0.6411917209625244
# (dataset)error at epoch 282 is 46.666666666666664
# mbloss:  0.6409047245979309
# (dataset)error at epoch 283 is 46.666666666666664
# mbloss:  0.6406249403953552
# (dataset)error at epoch 284 is 46.666666666666664
# mbloss:  0.6403433084487915
# (dataset)error at epoch 285 is 46.666666666666664
# mbloss:  0.6400587558746338
# (dataset)error at epoch 286 is 46.666666666666664
# mbloss:  0.6397709846496582
# (dataset)error at epoch 287 is 46.666666666666664
# mbloss:  0.6394799947738647
# (dataset)error at epoch 288 is 46.666666666666664
# mbloss:  0.6391855478286743
# (dataset)error at epoch 289 is 46.666666666666664
# mbloss:  0.6388875246047974
# (dataset)error at epoch 290 is 46.666666666666664
# mbloss:  0.6385861039161682
# (dataset)error at epoch 291 is 46.0
# mbloss:  0.6382809281349182
# (dataset)error at epoch 292 is 46.0
# mbloss:  0.6379719972610474
# (dataset)error at epoch 293 is 46.0
# mbloss:  0.6376564502716064
# (dataset)error at epoch 294 is 46.0
# mbloss:  0.6373182535171509
# (dataset)error at epoch 295 is 46.0
# mbloss:  0.6369785666465759
# (dataset)error at epoch 296 is 46.0
# mbloss:  0.6366364359855652
# (dataset)error at epoch 297 is 45.333333333333336
# mbloss:  0.6362919807434082
# (dataset)error at epoch 298 is 43.99999999999999
# mbloss:  0.6359444856643677
# (dataset)error at epoch 299 is 42.666666666666664
# mbloss:  0.6355923414230347
# (dataset)error at epoch 300 is 42.666666666666664
# mbloss:  0.635234534740448
# (dataset)error at epoch 301 is 42.666666666666664
# mbloss:  0.6348734498023987
# (dataset)error at epoch 302 is 42.666666666666664
# mbloss:  0.6345090270042419
# (dataset)error at epoch 303 is 42.666666666666664
# mbloss:  0.6341410279273987
# (dataset)error at epoch 304 is 42.00000000000001
# mbloss:  0.6337683796882629
# (dataset)error at epoch 305 is 42.00000000000001
# mbloss:  0.6333867907524109
# (dataset)error at epoch 306 is 42.00000000000001
# mbloss:  0.633007287979126
# (dataset)error at epoch 307 is 42.00000000000001
# mbloss:  0.6326220035552979
# (dataset)error at epoch 308 is 42.00000000000001
# mbloss:  0.6322305202484131
# (dataset)error at epoch 309 is 42.00000000000001
# mbloss:  0.6318343877792358
# (dataset)error at epoch 310 is 42.00000000000001
# mbloss:  0.6314356327056885
# (dataset)error at epoch 311 is 42.00000000000001
# mbloss:  0.6310353875160217
# (dataset)error at epoch 312 is 42.00000000000001
# mbloss:  0.630630612373352
# (dataset)error at epoch 313 is 42.666666666666664
# mbloss:  0.6302213072776794
# (dataset)error at epoch 314 is 42.666666666666664
# mbloss:  0.6298070549964905
# (dataset)error at epoch 315 is 42.666666666666664
# mbloss:  0.6293880939483643
# (dataset)error at epoch 316 is 42.666666666666664
# mbloss:  0.6289634108543396
# (dataset)error at epoch 317 is 42.666666666666664
# mbloss:  0.6285150647163391
# (dataset)error at epoch 318 is 42.00000000000001
# mbloss:  0.628066897392273
# (dataset)error at epoch 319 is 41.333333333333336
# mbloss:  0.6276165843009949
# (dataset)error at epoch 320 is 41.333333333333336
# mbloss:  0.6271637678146362
# (dataset)error at epoch 321 is 40.666666666666664
# mbloss:  0.6267079710960388
# (dataset)error at epoch 322 is 40.666666666666664
# mbloss:  0.6262537837028503
# (dataset)error at epoch 323 is 40.666666666666664
# mbloss:  0.6257951259613037
# (dataset)error at epoch 324 is 40.666666666666664
# mbloss:  0.6253366470336914
# (dataset)error at epoch 325 is 40.666666666666664
# mbloss:  0.6248738169670105
# (dataset)error at epoch 326 is 40.666666666666664
# mbloss:  0.6244063377380371
# (dataset)error at epoch 327 is 40.666666666666664
# mbloss:  0.6239343285560608
# (dataset)error at epoch 328 is 40.666666666666664
# mbloss:  0.6234567761421204
# (dataset)error at epoch 329 is 40.666666666666664
# mbloss:  0.6229720115661621
# (dataset)error at epoch 330 is 40.666666666666664
# mbloss:  0.6224803328514099
# (dataset)error at epoch 331 is 40.666666666666664
# mbloss:  0.6219778656959534
# (dataset)error at epoch 332 is 40.666666666666664
# mbloss:  0.6214780211448669
# (dataset)error at epoch 333 is 40.0
# mbloss:  0.620972752571106
# (dataset)error at epoch 334 is 40.0
# mbloss:  0.620461642742157
# (dataset)error at epoch 335 is 40.0
# mbloss:  0.6199454665184021
# (dataset)error at epoch 336 is 40.0
# mbloss:  0.6194239854812622
# (dataset)error at epoch 337 is 40.0
# mbloss:  0.6188974976539612
# (dataset)error at epoch 338 is 40.0
# mbloss:  0.6183659434318542
# (dataset)error at epoch 339 is 40.0
# mbloss:  0.6178302764892578
# (dataset)error at epoch 340 is 40.0
# mbloss:  0.617293655872345
# (dataset)error at epoch 341 is 40.0
# mbloss:  0.6167520880699158
# (dataset)error at epoch 342 is 40.0
# mbloss:  0.6162056922912598
# (dataset)error at epoch 343 is 40.0
# mbloss:  0.6156547665596008
# (dataset)error at epoch 344 is 40.0
# mbloss:  0.6150993704795837
# (dataset)error at epoch 345 is 40.0
# mbloss:  0.6145391464233398
# (dataset)error at epoch 346 is 40.0
# mbloss:  0.6139739751815796
# (dataset)error at epoch 347 is 40.0
# mbloss:  0.6134039759635925
# (dataset)error at epoch 348 is 39.33333333333333
# mbloss:  0.6128290891647339
# (dataset)error at epoch 349 is 39.33333333333333
# mbloss:  0.6122495532035828
# (dataset)error at epoch 350 is 39.33333333333333
# mbloss:  0.6116654276847839
# (dataset)error at epoch 351 is 38.66666666666667
# mbloss:  0.6110768914222717
# (dataset)error at epoch 352 is 38.66666666666667
# mbloss:  0.6104846000671387
# (dataset)error at epoch 353 is 38.66666666666667
# mbloss:  0.6098880171775818
# (dataset)error at epoch 354 is 38.66666666666667
# mbloss:  0.6092867851257324
# (dataset)error at epoch 355 is 38.66666666666667
# mbloss:  0.6086816191673279
# (dataset)error at epoch 356 is 38.66666666666667
# mbloss:  0.6080725193023682
# (dataset)error at epoch 357 is 38.66666666666667
# mbloss:  0.6074614524841309
# (dataset)error at epoch 358 is 38.66666666666667
# mbloss:  0.6068537831306458
# (dataset)error at epoch 359 is 38.66666666666667
# mbloss:  0.6062429547309875
# (dataset)error at epoch 360 is 37.33333333333333
# mbloss:  0.6056284308433533
# (dataset)error at epoch 361 is 37.33333333333333
# mbloss:  0.6050108671188354
# (dataset)error at epoch 362 is 37.33333333333333
# mbloss:  0.6043900847434998
# (dataset)error at epoch 363 is 37.33333333333333
# mbloss:  0.6037665605545044
# (dataset)error at epoch 364 is 37.33333333333333
# mbloss:  0.603140652179718
# (dataset)error at epoch 365 is 37.33333333333333
# mbloss:  0.6025115847587585
# (dataset)error at epoch 366 is 37.33333333333333
# mbloss:  0.601879358291626
# (dataset)error at epoch 367 is 37.33333333333333
# mbloss:  0.6012440919876099
# (dataset)error at epoch 368 is 36.66666666666667
# mbloss:  0.6006060242652893
# (dataset)error at epoch 369 is 36.0
# mbloss:  0.5999649167060852
# (dataset)error at epoch 370 is 36.66666666666667
# mbloss:  0.5993213057518005
# (dataset)error at epoch 371 is 36.66666666666667
# mbloss:  0.5986751317977905
# (dataset)error at epoch 372 is 37.33333333333333
# mbloss:  0.5980263352394104
# (dataset)error at epoch 373 is 37.33333333333333
# mbloss:  0.5973753333091736
# (dataset)error at epoch 374 is 36.66666666666667
# mbloss:  0.5967221260070801
# (dataset)error at epoch 375 is 36.66666666666667
# mbloss:  0.596066951751709
# (dataset)error at epoch 376 is 36.66666666666667
# mbloss:  0.5954098105430603
# (dataset)error at epoch 377 is 36.66666666666667
# mbloss:  0.5947510004043579
# (dataset)error at epoch 378 is 36.66666666666667
# mbloss:  0.5940907001495361
# (dataset)error at epoch 379 is 36.66666666666667
# mbloss:  0.5934287905693054
# (dataset)error at epoch 380 is 36.0
# mbloss:  0.5927670001983643
# (dataset)error at epoch 381 is 36.0
# mbloss:  0.5921039581298828
# (dataset)error at epoch 382 is 36.0
# mbloss:  0.591439962387085
# (dataset)error at epoch 383 is 36.0
# mbloss:  0.5907753109931946
# (dataset)error at epoch 384 is 36.0
# mbloss:  0.5901099443435669
# (dataset)error at epoch 385 is 36.66666666666667
# mbloss:  0.5894441604614258
# (dataset)error at epoch 386 is 36.66666666666667
# mbloss:  0.5887795686721802
# (dataset)error at epoch 387 is 36.66666666666667
# mbloss:  0.5881145596504211
# (dataset)error at epoch 388 is 36.66666666666667
# mbloss:  0.5874500870704651
# (dataset)error at epoch 389 is 36.66666666666667
# mbloss:  0.586786150932312
# (dataset)error at epoch 390 is 36.66666666666667
# mbloss:  0.5861219763755798
# (dataset)error at epoch 391 is 36.66666666666667
# mbloss:  0.5854581594467163
# (dataset)error at epoch 392 is 36.66666666666667
# mbloss:  0.5847905278205872
# (dataset)error at epoch 393 is 36.66666666666667
# mbloss:  0.5841262340545654
# (dataset)error at epoch 394 is 36.66666666666667
# mbloss:  0.5834636092185974
# (dataset)error at epoch 395 is 36.0
# mbloss:  0.5828012824058533
# (dataset)error at epoch 396 is 36.0
# mbloss:  0.5821415781974792
# (dataset)error at epoch 397 is 36.0
# mbloss:  0.5814838409423828
# (dataset)error at epoch 398 is 36.0
# mbloss:  0.5808271169662476
# (dataset)error at epoch 399 is 36.0
# mbloss:  0.5801733136177063
# (dataset)error at epoch 400 is 36.0
# mbloss:  0.5795210599899292
# (dataset)error at epoch 401 is 36.0
# mbloss:  0.5788710713386536
# (dataset)error at epoch 402 is 36.0
# mbloss:  0.5782239437103271
# (dataset)error at epoch 403 is 36.0
# mbloss:  0.577578604221344
# (dataset)error at epoch 404 is 36.0
# mbloss:  0.5769370794296265
# (dataset)error at epoch 405 is 36.0
# mbloss:  0.5762974619865417
# (dataset)error at epoch 406 is 36.0
# mbloss:  0.5756616592407227
# (dataset)error at epoch 407 is 36.0
# mbloss:  0.5750289559364319
# (dataset)error at epoch 408 is 36.0
# mbloss:  0.5743994116783142
# (dataset)error at epoch 409 is 36.0
# mbloss:  0.5737742781639099
# (dataset)error at epoch 410 is 36.66666666666667
# mbloss:  0.5731544494628906
# (dataset)error at epoch 411 is 36.0
# mbloss:  0.5725357532501221
# (dataset)error at epoch 412 is 36.66666666666667
# mbloss:  0.5719243884086609
# (dataset)error at epoch 413 is 36.0
# mbloss:  0.5713160037994385
# (dataset)error at epoch 414 is 36.66666666666667
# mbloss:  0.570712149143219
# (dataset)error at epoch 415 is 36.0
# mbloss:  0.5701136589050293
# (dataset)error at epoch 416 is 36.66666666666667
# mbloss:  0.5695192217826843
# (dataset)error at epoch 417 is 36.66666666666667
# mbloss:  0.5689296722412109
# (dataset)error at epoch 418 is 36.66666666666667
# mbloss:  0.5683465600013733
# (dataset)error at epoch 419 is 36.66666666666667
# mbloss:  0.5677685141563416
# (dataset)error at epoch 420 is 36.66666666666667
# mbloss:  0.5671953558921814
# (dataset)error at epoch 421 is 36.0
# mbloss:  0.5666285157203674
# (dataset)error at epoch 422 is 36.0
# mbloss:  0.5660669803619385
# (dataset)error at epoch 423 is 36.0
# mbloss:  0.5655115246772766
# (dataset)error at epoch 424 is 35.33333333333334
# mbloss:  0.5649620890617371
# (dataset)error at epoch 425 is 35.33333333333334
# mbloss:  0.564418375492096
# (dataset)error at epoch 426 is 34.66666666666667
# mbloss:  0.5638805627822876
# (dataset)error at epoch 427 is 34.0
# mbloss:  0.5633487105369568
# (dataset)error at epoch 428 is 34.0
# mbloss:  0.5628228187561035
# (dataset)error at epoch 429 is 34.0
# mbloss:  0.5623029470443726
# (dataset)error at epoch 430 is 34.0
# mbloss:  0.5617890357971191
# (dataset)error at epoch 431 is 34.0
# mbloss:  0.5612812042236328
# (dataset)error at epoch 432 is 34.0
# mbloss:  0.5607793927192688
# (dataset)error at epoch 433 is 34.0
# mbloss:  0.5602838397026062
# (dataset)error at epoch 434 is 34.0
# mbloss:  0.5597943067550659
# (dataset)error at epoch 435 is 34.0
# mbloss:  0.5593109726905823
# (dataset)error at epoch 436 is 34.0
# mbloss:  0.5588338375091553
# (dataset)error at epoch 437 is 34.0
# mbloss:  0.5583627820014954
# (dataset)error at epoch 438 is 34.0
# mbloss:  0.5578980445861816
# (dataset)error at epoch 439 is 34.0
# mbloss:  0.557439386844635
# (dataset)error at epoch 440 is 34.0
# mbloss:  0.5569868683815002
# (dataset)error at epoch 441 is 34.0
# mbloss:  0.5565406084060669
# (dataset)error at epoch 442 is 34.0
# mbloss:  0.5561005473136902
# (dataset)error at epoch 443 is 34.0
# mbloss:  0.5556666254997253
# (dataset)error at epoch 444 is 34.0
# mbloss:  0.555238664150238
# (dataset)error at epoch 445 is 34.0
# mbloss:  0.5548170804977417
# (dataset)error at epoch 446 is 34.0
# mbloss:  0.5544013977050781
# (dataset)error at epoch 447 is 34.0
# mbloss:  0.5539918541908264
# (dataset)error at epoch 448 is 34.0
# mbloss:  0.5535883903503418
# (dataset)error at epoch 449 is 34.0
# mbloss:  0.5531908273696899
# (dataset)error at epoch 450 is 34.0
# mbloss:  0.5527992844581604
# (dataset)error at epoch 451 is 34.0
# mbloss:  0.5524137020111084
# (dataset)error at epoch 452 is 34.0
# mbloss:  0.5520340204238892
# (dataset)error at epoch 453 is 34.0
# mbloss:  0.5516600608825684
# (dataset)error at epoch 454 is 33.33333333333334
# mbloss:  0.5512920022010803
# (dataset)error at epoch 455 is 33.33333333333334
# mbloss:  0.5509297251701355
# (dataset)error at epoch 456 is 33.33333333333334
# mbloss:  0.5505731105804443
# (dataset)error at epoch 457 is 33.33333333333334
# mbloss:  0.5502222180366516
# (dataset)error at epoch 458 is 33.33333333333334
# mbloss:  0.549876868724823
# (dataset)error at epoch 459 is 33.33333333333334
# mbloss:  0.5495370626449585
# (dataset)error at epoch 460 is 33.33333333333334
# mbloss:  0.5492027997970581
# (dataset)error at epoch 461 is 33.33333333333334
# mbloss:  0.548874020576477
# (dataset)error at epoch 462 is 33.33333333333334
# mbloss:  0.5485506057739258
# (dataset)error at epoch 463 is 33.33333333333334
# mbloss:  0.5482349395751953
# (dataset)error at epoch 464 is 33.33333333333334
# mbloss:  0.54792720079422
# (dataset)error at epoch 465 is 33.33333333333334
# mbloss:  0.5476253032684326
# (dataset)error at epoch 466 is 33.33333333333334
# mbloss:  0.5473290085792542
# (dataset)error at epoch 467 is 33.33333333333334
# mbloss:  0.5470379590988159
# (dataset)error at epoch 468 is 33.33333333333334
# mbloss:  0.5467520952224731
# (dataset)error at epoch 469 is 33.33333333333334
# mbloss:  0.5464714765548706
# (dataset)error at epoch 470 is 33.33333333333334
# mbloss:  0.5461960434913635
# (dataset)error at epoch 471 is 33.33333333333334
# mbloss:  0.5459256172180176
# (dataset)error at epoch 472 is 33.33333333333334
# mbloss:  0.5456605553627014
# (dataset)error at epoch 473 is 33.33333333333334
# mbloss:  0.5454006195068359
# (dataset)error at epoch 474 is 33.33333333333334
# mbloss:  0.5451476573944092
# (dataset)error at epoch 475 is 33.33333333333334
# mbloss:  0.5449001789093018
# (dataset)error at epoch 476 is 33.33333333333334
# mbloss:  0.5446622967720032
# (dataset)error at epoch 477 is 33.33333333333334
# mbloss:  0.5444344282150269
# (dataset)error at epoch 478 is 33.33333333333334
# mbloss:  0.5442214012145996
# (dataset)error at epoch 479 is 32.0
# mbloss:  0.5440309047698975
# (dataset)error at epoch 480 is 34.0
# mbloss:  0.5438750386238098
# (dataset)error at epoch 481 is 32.0
# mbloss:  0.5437812209129333
# (dataset)error at epoch 482 is 34.66666666666667
# mbloss:  0.5437887907028198
# (dataset)error at epoch 483 is 30.666666666666657
# mbloss:  0.5439824461936951
# (dataset)error at epoch 484 is 36.0
# mbloss:  0.5445190668106079
# (dataset)error at epoch 485 is 31.33333333333333
# mbloss:  0.5456531047821045
# (dataset)error at epoch 486 is 37.33333333333333
# mbloss:  0.548012912273407
# (dataset)error at epoch 487 is 31.33333333333333
# mbloss:  0.5522791743278503
# (dataset)error at epoch 488 is 40.0
# mbloss:  0.5610348582267761
# (dataset)error at epoch 489 is 23.33333333333333
# mbloss:  0.5748491287231445
# (dataset)error at epoch 490 is 44.666666666666664
# mbloss:  0.6023106575012207
# (dataset)error at epoch 491 is 29.33333333333333
# mbloss:  0.6320673227310181
# (dataset)error at epoch 492 is 44.666666666666664
# mbloss:  0.68340665102005
# (dataset)error at epoch 493 is 35.33333333333334
# mbloss:  0.6913593411445618
# (dataset)error at epoch 494 is 46.0
# mbloss:  0.7211800813674927
# (dataset)error at epoch 495 is 31.33333333333333
# mbloss:  0.6772997379302979
# (dataset)error at epoch 496 is 44.666666666666664
# mbloss:  0.674307107925415
# (dataset)error at epoch 497 is 28.666666666666657
# mbloss:  0.6322212815284729
# (dataset)error at epoch 498 is 44.666666666666664
# mbloss:  0.6236076951026917
# (dataset)error at epoch 499 is 28.0
# mbloss:  0.5998821258544922
# (dataset)error at epoch 500 is 42.666666666666664
# mbloss:  0.5935987234115601
# (dataset)error at epoch 501 is 25.33333333333333
# mbloss:  0.5808636546134949
# (dataset)error at epoch 502 is 40.666666666666664
# mbloss:  0.5771801471710205
# (dataset)error at epoch 503 is 23.33333333333333
# mbloss:  0.5699934363365173
# (dataset)error at epoch 504 is 38.66666666666667
# mbloss:  0.5679318904876709
# (dataset)error at epoch 505 is 28.0
# mbloss:  0.5636026859283447
# (dataset)error at epoch 506 is 40.0
# mbloss:  0.5624746084213257
# (dataset)error at epoch 507 is 30.0
# mbloss:  0.5597314238548279
# (dataset)error at epoch 508 is 38.66666666666667
# mbloss:  0.5592496395111084
# (dataset)error at epoch 509 is 30.666666666666657
# mbloss:  0.5574347376823425
# (dataset)error at epoch 510 is 38.66666666666667
# mbloss:  0.5574292540550232
# (dataset)error at epoch 511 is 30.666666666666657
# mbloss:  0.5562081933021545
# (dataset)error at epoch 512 is 38.66666666666667
# mbloss:  0.5566089749336243
# (dataset)error at epoch 513 is 30.666666666666657
# mbloss:  0.5558238625526428
# (dataset)error at epoch 514 is 38.66666666666667
# mbloss:  0.5567140579223633
# (dataset)error at epoch 515 is 30.666666666666657
# mbloss:  0.5562619566917419
# (dataset)error at epoch 516 is 38.66666666666667
# mbloss:  0.5575637221336365
# (dataset)error at epoch 517 is 30.0
# mbloss:  0.557421863079071
# (dataset)error at epoch 518 is 39.33333333333333
# mbloss:  0.5592299103736877
# (dataset)error at epoch 519 is 28.666666666666657
# mbloss:  0.5593787431716919
# (dataset)error at epoch 520 is 39.33333333333333
# mbloss:  0.5618036389350891
# (dataset)error at epoch 521 is 26.0
# mbloss:  0.5621984601020813
# (dataset)error at epoch 522 is 38.66666666666667
# mbloss:  0.5653294324874878
# (dataset)error at epoch 523 is 23.33333333333333
# mbloss:  0.5658256411552429
# (dataset)error at epoch 524 is 40.0
# mbloss:  0.5696573257446289
# (dataset)error at epoch 525 is 23.33333333333333
# mbloss:  0.5699954032897949
# (dataset)error at epoch 526 is 40.666666666666664
# mbloss:  0.5743522644042969
# (dataset)error at epoch 527 is 24.0
# mbloss:  0.5741273164749146
# (dataset)error at epoch 528 is 40.666666666666664
# mbloss:  0.5786306858062744
# (dataset)error at epoch 529 is 24.66666666666667
# mbloss:  0.5774271488189697
# (dataset)error at epoch 530 is 40.666666666666664
# mbloss:  0.5815925598144531
# (dataset)error at epoch 531 is 24.66666666666667
# mbloss:  0.5792000889778137
# (dataset)error at epoch 532 is 40.666666666666664
# mbloss:  0.5826367139816284
# (dataset)error at epoch 533 is 24.66666666666667
# mbloss:  0.5791835784912109
# (dataset)error at epoch 534 is 40.666666666666664
# mbloss:  0.5817471742630005
# (dataset)error at epoch 535 is 24.66666666666667
# mbloss:  0.5776446461677551
# (dataset)error at epoch 536 is 40.666666666666664
# mbloss:  0.5794349908828735
# (dataset)error at epoch 537 is 24.66666666666667
# mbloss:  0.5751560926437378
# (dataset)error at epoch 538 is 40.666666666666664
# mbloss:  0.5762701034545898
# (dataset)error at epoch 539 is 24.0
# mbloss:  0.5722533464431763
# (dataset)error at epoch 540 is 40.666666666666664
# mbloss:  0.5729930400848389
# (dataset)error at epoch 541 is 24.0
# mbloss:  0.5694432854652405
# (dataset)error at epoch 542 is 40.0
# mbloss:  0.5700832009315491
# (dataset)error at epoch 543 is 23.33333333333333
# mbloss:  0.5670444965362549
# (dataset)error at epoch 544 is 39.33333333333333
# mbloss:  0.5677132606506348
# (dataset)error at epoch 545 is 23.33333333333333
# mbloss:  0.5651393532752991
# (dataset)error at epoch 546 is 39.33333333333333
# mbloss:  0.5659002065658569
# (dataset)error at epoch 547 is 22.66666666666667
# mbloss:  0.5637308955192566
# (dataset)error at epoch 548 is 39.33333333333333
# mbloss:  0.5646368265151978
# (dataset)error at epoch 549 is 22.66666666666667
# mbloss:  0.5627976059913635
# (dataset)error at epoch 550 is 39.33333333333333
# mbloss:  0.5638718605041504
# (dataset)error at epoch 551 is 22.66666666666667
# mbloss:  0.5622968673706055
# (dataset)error at epoch 552 is 39.33333333333333
# mbloss:  0.5635998249053955
# (dataset)error at epoch 553 is 22.66666666666667
# mbloss:  0.562197208404541
# (dataset)error at epoch 554 is 39.33333333333333
# mbloss:  0.563626229763031
# (dataset)error at epoch 555 is 22.66666666666667
# mbloss:  0.5623319745063782
# (dataset)error at epoch 556 is 39.33333333333333
# mbloss:  0.5640125274658203
# (dataset)error at epoch 557 is 22.66666666666667
# mbloss:  0.5627752542495728
# (dataset)error at epoch 558 is 39.33333333333333
# mbloss:  0.5646198987960815
# (dataset)error at epoch 559 is 23.33333333333333
# mbloss:  0.5633928179740906
# (dataset)error at epoch 560 is 39.33333333333333
# mbloss:  0.5654218196868896
# (dataset)error at epoch 561 is 23.33333333333333
# mbloss:  0.5641400218009949
# (dataset)error at epoch 562 is 39.33333333333333
# mbloss:  0.5662375092506409
# (dataset)error at epoch 563 is 23.33333333333333
# mbloss:  0.5648676156997681
# (dataset)error at epoch 564 is 40.0
# mbloss:  0.5670451521873474
# (dataset)error at epoch 565 is 23.33333333333333
# mbloss:  0.5655372142791748
# (dataset)error at epoch 566 is 40.0
# mbloss:  0.5677006244659424
# (dataset)error at epoch 567 is 23.33333333333333
# mbloss:  0.5660334825515747
# (dataset)error at epoch 568 is 40.0
# mbloss:  0.56815505027771
# (dataset)error at epoch 569 is 24.0
# mbloss:  0.5663243532180786
# (dataset)error at epoch 570 is 40.0
# mbloss:  0.5683457255363464
# (dataset)error at epoch 571 is 24.0
# mbloss:  0.5663630366325378
# (dataset)error at epoch 572 is 40.0
# mbloss:  0.5682550668716431
# (dataset)error at epoch 573 is 24.0
# mbloss:  0.5661561489105225
# (dataset)error at epoch 574 is 40.0
# mbloss:  0.5679088234901428
# (dataset)error at epoch 575 is 24.0
# mbloss:  0.5657364130020142
# (dataset)error at epoch 576 is 40.0
# mbloss:  0.567354679107666
# (dataset)error at epoch 577 is 24.0
# mbloss:  0.5651650428771973
# (dataset)error at epoch 578 is 39.33333333333333
# mbloss:  0.5666751861572266
# (dataset)error at epoch 579 is 23.33333333333333
# mbloss:  0.5644951462745667
# (dataset)error at epoch 580 is 39.33333333333333
# mbloss:  0.5659271478652954
# (dataset)error at epoch 581 is 23.33333333333333
# mbloss:  0.5637648701667786
# (dataset)error at epoch 582 is 39.33333333333333
# mbloss:  0.565220832824707
# (dataset)error at epoch 583 is 23.33333333333333
# mbloss:  0.5631285309791565
# (dataset)error at epoch 584 is 39.33333333333333
# mbloss:  0.5645898580551147
# (dataset)error at epoch 585 is 22.66666666666667
# mbloss:  0.5625594258308411
# (dataset)error at epoch 586 is 39.33333333333333
# mbloss:  0.5640360116958618
# (dataset)error at epoch 587 is 22.66666666666667
# mbloss:  0.5620733499526978
# (dataset)error at epoch 588 is 39.33333333333333
# mbloss:  0.5635901093482971
# (dataset)error at epoch 589 is 22.0
# mbloss:  0.5616861581802368
# (dataset)error at epoch 590 is 39.33333333333333
# mbloss:  0.5632175207138062
# (dataset)error at epoch 591 is 22.0
# mbloss:  0.5613677501678467
# (dataset)error at epoch 592 is 38.66666666666667
# mbloss:  0.5629265904426575
# (dataset)error at epoch 593 is 22.66666666666667
# mbloss:  0.5611273050308228
# (dataset)error at epoch 594 is 38.66666666666667
# mbloss:  0.5627145767211914
# (dataset)error at epoch 595 is 22.66666666666667
# mbloss:  0.5609556436538696
# (dataset)error at epoch 596 is 38.66666666666667
# mbloss:  0.5625656843185425
# (dataset)error at epoch 597 is 22.66666666666667
# mbloss:  0.5608435273170471
# (dataset)error at epoch 598 is 39.33333333333333
# mbloss:  0.5624935030937195
# (dataset)error at epoch 599 is 22.0
# mbloss:  0.5607576966285706
# (dataset)error at epoch 600 is 39.33333333333333
# mbloss:  0.5624639391899109
# (dataset)error at epoch 601 is 22.0
# mbloss:  0.5607123970985413
# (dataset)error at epoch 602 is 39.33333333333333
# mbloss:  0.5624595880508423
# (dataset)error at epoch 603 is 22.0
# mbloss:  0.5606862902641296
# (dataset)error at epoch 604 is 39.33333333333333
# mbloss:  0.5624585747718811
# (dataset)error at epoch 605 is 22.0
# mbloss:  0.5606575608253479
# (dataset)error at epoch 606 is 39.33333333333333
# mbloss:  0.5624222755432129
# (dataset)error at epoch 607 is 21.333333333333343
# mbloss:  0.560596227645874
# (dataset)error at epoch 608 is 39.33333333333333
# mbloss:  0.5623578429222107
# (dataset)error at epoch 609 is 21.333333333333343
# mbloss:  0.5605053305625916
# (dataset)error at epoch 610 is 38.66666666666667
# mbloss:  0.5622522830963135
# (dataset)error at epoch 611 is 21.333333333333343
# mbloss:  0.5603745579719543
# (dataset)error at epoch 612 is 38.66666666666667
# mbloss:  0.5621042251586914
# (dataset)error at epoch 613 is 21.333333333333343
# mbloss:  0.5602319240570068
# (dataset)error at epoch 614 is 38.66666666666667
# mbloss:  0.5619456768035889
# (dataset)error at epoch 615 is 21.333333333333343
# mbloss:  0.5600521564483643
# (dataset)error at epoch 616 is 38.66666666666667
# mbloss:  0.5617337226867676
# (dataset)error at epoch 617 is 21.333333333333343
# mbloss:  0.5598282814025879
# (dataset)error at epoch 618 is 38.66666666666667
# mbloss:  0.5615161061286926
# (dataset)error at epoch 619 is 21.333333333333343
# mbloss:  0.5596029758453369
# (dataset)error at epoch 620 is 38.66666666666667
# mbloss:  0.5612668991088867
# (dataset)error at epoch 621 is 21.333333333333343
# mbloss:  0.5593406558036804
# (dataset)error at epoch 622 is 38.66666666666667
# mbloss:  0.560968279838562
# (dataset)error at epoch 623 is 21.333333333333343
# mbloss:  0.559076726436615
# (dataset)error at epoch 624 is 38.66666666666667
# mbloss:  0.5606930255889893
# (dataset)error at epoch 625 is 22.0
# mbloss:  0.5588141679763794
# (dataset)error at epoch 626 is 38.66666666666667
# mbloss:  0.560416042804718
# (dataset)error at epoch 627 is 22.0
# mbloss:  0.5585554838180542
# (dataset)error at epoch 628 is 38.66666666666667
# mbloss:  0.5601450800895691
# (dataset)error at epoch 629 is 22.0
# mbloss:  0.5583067536354065
# (dataset)error at epoch 630 is 38.0
# mbloss:  0.5598849058151245
# (dataset)error at epoch 631 is 22.0
# mbloss:  0.5580799579620361
# (dataset)error at epoch 632 is 38.0
# mbloss:  0.5596497654914856
# (dataset)error at epoch 633 is 22.0
# mbloss:  0.557874321937561
# (dataset)error at epoch 634 is 38.0
# mbloss:  0.5594586133956909
# (dataset)error at epoch 635 is 22.0
# mbloss:  0.5576813817024231
# (dataset)error at epoch 636 is 38.0
# mbloss:  0.5592942237854004
# (dataset)error at epoch 637 is 22.0
# mbloss:  0.5575268864631653
# (dataset)error at epoch 638 is 38.0
# mbloss:  0.5591630339622498
# (dataset)error at epoch 639 is 22.0
# mbloss:  0.5573951005935669
# (dataset)error at epoch 640 is 38.0
# mbloss:  0.559049129486084
# (dataset)error at epoch 641 is 21.333333333333343
# mbloss:  0.5572786331176758
# (dataset)error at epoch 642 is 38.0
# mbloss:  0.5589374303817749
# (dataset)error at epoch 643 is 21.333333333333343
# mbloss:  0.5571612119674683
# (dataset)error at epoch 644 is 38.0
# mbloss:  0.5588171482086182
# (dataset)error at epoch 645 is 21.333333333333343
# mbloss:  0.5570338368415833
# (dataset)error at epoch 646 is 38.0
# mbloss:  0.5586794018745422
# (dataset)error at epoch 647 is 22.0
# mbloss:  0.5569137334823608
# (dataset)error at epoch 648 is 38.0
# mbloss:  0.5585452318191528
# (dataset)error at epoch 649 is 22.0
# mbloss:  0.5567752122879028
# (dataset)error at epoch 650 is 38.66666666666667
# mbloss:  0.5584203600883484
# (dataset)error at epoch 651 is 21.333333333333343
# ...
# mbloss:  0.23657743632793427
# (dataset)error at epoch 1776 is 8.0
# mbloss:  0.23774218559265137
# (dataset)error at epoch 1777 is 8.0
# mbloss:  0.23693254590034485
# (dataset)error at epoch 1778 is 8.0
# mbloss:  0.238098606467247
# (dataset)error at epoch 1779 is 8.0
# mbloss:  0.2371351569890976
# (dataset)error at epoch 1780 is 8.0
# mbloss:  0.23817777633666992
# (dataset)error at epoch 1781 is 8.0
# mbloss:  0.23711270093917847
# (dataset)error at epoch 1782 is 8.0
# mbloss:  0.2380937933921814
# (dataset)error at epoch 1783 is 8.0
# mbloss:  0.23691970109939575
# (dataset)error at epoch 1784 is 8.0
# mbloss:  0.23769906163215637
# (dataset)error at epoch 1785 is 8.0
# mbloss:  0.23644575476646423
# (dataset)error at epoch 1786 is 8.0
# mbloss:  0.2370588332414627
# (dataset)error at epoch 1787 is 8.0
# mbloss:  0.23575644195079803
# (dataset)error at epoch 1788 is 8.0
# mbloss:  0.23619182407855988
# (dataset)error at epoch 1789 is 8.0
# mbloss:  0.23485319316387177
# (dataset)error at epoch 1790 is 8.0
# mbloss:  0.23502753674983978
# (dataset)error at epoch 1791 is 8.0
# mbloss:  0.23374560475349426
# (dataset)error at epoch 1792 is 8.0
# mbloss:  0.2337331473827362
# (dataset)error at epoch 1793 is 8.0
# mbloss:  0.23253029584884644
# (dataset)error at epoch 1794 is 8.0
# mbloss:  0.2323712706565857
# (dataset)error at epoch 1795 is 8.0
# mbloss:  0.23120975494384766
# (dataset)error at epoch 1796 is 8.0
# mbloss:  0.23092502355575562
# (dataset)error at epoch 1797 is 8.0
# mbloss:  0.2298908531665802
# (dataset)error at epoch 1798 is 8.0
# mbloss:  0.22948631644248962
# (dataset)error at epoch 1799 is 8.0
# mbloss:  0.22859513759613037
# (dataset)error at epoch 1800 is 8.0
# mbloss:  0.2280920296907425
# (dataset)error at epoch 1801 is 8.0
# mbloss:  0.22735512256622314
# (dataset)error at epoch 1802 is 8.0
# mbloss:  0.2267833799123764
# (dataset)error at epoch 1803 is 8.0
# mbloss:  0.226203054189682
# (dataset)error at epoch 1804 is 8.0
# mbloss:  0.22557741403579712
# (dataset)error at epoch 1805 is 8.0
# mbloss:  0.22514885663986206
# (dataset)error at epoch 1806 is 8.0
# mbloss:  0.22448046505451202
# (dataset)error at epoch 1807 is 8.0
# mbloss:  0.22419580817222595
# (dataset)error at epoch 1808 is 8.0
# mbloss:  0.22347086668014526
# (dataset)error at epoch 1809 is 8.0
# mbloss:  0.22332145273685455
# (dataset)error at epoch 1810 is 8.0
# mbloss:  0.22256901860237122
# (dataset)error at epoch 1811 is 8.0
# mbloss:  0.22254206240177155
# (dataset)error at epoch 1812 is 8.0
# mbloss:  0.2217683047056198
# (dataset)error at epoch 1813 is 8.0
# mbloss:  0.22180074453353882
# (dataset)error at epoch 1814 is 8.0
# mbloss:  0.222733736038208
# (dataset)error at epoch 1815 is 8.0
# mbloss:  0.2232275903224945
# (dataset)error at epoch 1816 is 8.0
# mbloss:  0.22492584586143494
# (dataset)error at epoch 1817 is 8.0
# mbloss:  0.22514615952968597
# (dataset)error at epoch 1818 is 7.333333333333343
# mbloss:  0.2275625616312027
# (dataset)error at epoch 1819 is 8.0
# mbloss:  0.2280980795621872
# (dataset)error at epoch 1820 is 7.333333333333343
# mbloss:  0.2313573658466339
# (dataset)error at epoch 1821 is 8.0
# mbloss:  0.23010031878948212
# (dataset)error at epoch 1822 is 7.333333333333343
# mbloss:  0.23375257849693298
# (dataset)error at epoch 1823 is 8.0
# mbloss:  0.23278304934501648
# (dataset)error at epoch 1824 is 7.333333333333343
# mbloss:  0.23715269565582275
# (dataset)error at epoch 1825 is 8.0
# mbloss:  0.23636871576309204
# (dataset)error at epoch 1826 is 7.333333333333343
# mbloss:  0.24166977405548096
# (dataset)error at epoch 1827 is 8.0
# mbloss:  0.24108298122882843
# (dataset)error at epoch 1828 is 8.0
# mbloss:  0.24774621427059174
# (dataset)error at epoch 1829 is 8.0
# mbloss:  0.24745087325572968
# (dataset)error at epoch 1830 is 8.0
# mbloss:  0.25595107674598694
# (dataset)error at epoch 1831 is 8.666666666666671
# mbloss:  0.25621873140335083
# (dataset)error at epoch 1832 is 8.0
# mbloss:  0.2639220654964447
# (dataset)error at epoch 1833 is 8.666666666666671
# mbloss:  0.26293689012527466
# (dataset)error at epoch 1834 is 8.0
# mbloss:  0.2711756229400635
# (dataset)error at epoch 1835 is 8.666666666666671
# mbloss:  0.26970914006233215
# (dataset)error at epoch 1836 is 8.666666666666671
# mbloss:  0.27840545773506165
# (dataset)error at epoch 1837 is 11.333333333333329
# mbloss:  0.27609357237815857
# (dataset)error at epoch 1838 is 8.666666666666671
# mbloss:  0.28493496775627136
# (dataset)error at epoch 1839 is 14.0
# mbloss:  0.2812786400318146
# (dataset)error at epoch 1840 is 8.0
# mbloss:  0.28451013565063477
# (dataset)error at epoch 1841 is 10.666666666666671
# mbloss:  0.2795792520046234
# (dataset)error at epoch 1842 is 8.0
# mbloss:  0.276265949010849
# (dataset)error at epoch 1843 is 8.0
# mbloss:  0.2660752832889557
# (dataset)error at epoch 1844 is 7.333333333333343
# mbloss:  0.2560606002807617
# (dataset)error at epoch 1845 is 8.666666666666671
# mbloss:  0.24393486976623535
# (dataset)error at epoch 1846 is 8.0
# mbloss:  0.23289574682712555
# (dataset)error at epoch 1847 is 8.0
# mbloss:  0.2248201221227646
# (dataset)error at epoch 1848 is 8.0
# mbloss:  0.21927471458911896
# (dataset)error at epoch 1849 is 8.0
# mbloss:  0.21586494147777557
# (dataset)error at epoch 1850 is 8.666666666666671
# mbloss:  0.21296820044517517
# (dataset)error at epoch 1851 is 8.0
# mbloss:  0.21155022084712982
# (dataset)error at epoch 1852 is 8.666666666666671
# mbloss:  0.21052691340446472
# (dataset)error at epoch 1853 is 8.0
# mbloss:  0.2098335474729538
# (dataset)error at epoch 1854 is 8.666666666666671
# mbloss:  0.20924074947834015
# (dataset)error at epoch 1855 is 8.0
# mbloss:  0.20875349640846252
# (dataset)error at epoch 1856 is 8.666666666666671
# mbloss:  0.208335280418396
# (dataset)error at epoch 1857 is 8.0
# mbloss:  0.20797193050384521
# (dataset)error at epoch 1858 is 8.666666666666671
# mbloss:  0.2076326310634613
# (dataset)error at epoch 1859 is 8.0
# mbloss:  0.20733211934566498
# (dataset)error at epoch 1860 is 8.666666666666671
# mbloss:  0.2070511132478714
# (dataset)error at epoch 1861 is 8.0
# mbloss:  0.2068181037902832
# (dataset)error at epoch 1862 is 8.666666666666671
# mbloss:  0.20656464993953705
# (dataset)error at epoch 1863 is 8.0
# mbloss:  0.2063487023115158
# (dataset)error at epoch 1864 is 8.666666666666671
# mbloss:  0.20611880719661713
# (dataset)error at epoch 1865 is 8.0
# mbloss:  0.20593294501304626
# (dataset)error at epoch 1866 is 8.666666666666671
# mbloss:  0.20572032034397125
# (dataset)error at epoch 1867 is 8.0
# mbloss:  0.20555318892002106
# (dataset)error at epoch 1868 is 8.666666666666671
# mbloss:  0.20536504685878754
# (dataset)error at epoch 1869 is 8.0
# mbloss:  0.20520538091659546
# (dataset)error at epoch 1870 is 8.666666666666671
# mbloss:  0.20503254234790802
# (dataset)error at epoch 1871 is 8.0
# mbloss:  0.2048923373222351
# (dataset)error at epoch 1872 is 8.666666666666671
# mbloss:  0.204725444316864
# (dataset)error at epoch 1873 is 8.0
# mbloss:  0.20455403625965118
# (dataset)error at epoch 1874 is 8.666666666666671
# mbloss:  0.2043842375278473
# (dataset)error at epoch 1875 is 8.0
# mbloss:  0.2042427361011505
# (dataset)error at epoch 1876 is 8.666666666666671
# mbloss:  0.20409178733825684
# (dataset)error at epoch 1877 is 8.0
# mbloss:  0.2039860635995865
# (dataset)error at epoch 1878 is 8.666666666666671
# mbloss:  0.20387524366378784
# (dataset)error at epoch 1879 is 8.0
# mbloss:  0.20378926396369934
# (dataset)error at epoch 1880 is 8.666666666666671
# mbloss:  0.20371639728546143
# (dataset)error at epoch 1881 is 8.0
# mbloss:  0.20365609228610992
# (dataset)error at epoch 1882 is 8.666666666666671
# mbloss:  0.2036302536725998
# (dataset)error at epoch 1883 is 8.0
# mbloss:  0.20359915494918823
# (dataset)error at epoch 1884 is 8.666666666666671
# mbloss:  0.20363445580005646
# (dataset)error at epoch 1885 is 8.0
# mbloss:  0.2036563903093338
# (dataset)error at epoch 1886 is 8.666666666666671
# mbloss:  0.20372997224330902
# (dataset)error at epoch 1887 is 8.0
# mbloss:  0.2031153291463852
# (dataset)error at epoch 1888 is 8.666666666666671
# mbloss:  0.20290830731391907
# (dataset)error at epoch 1889 is 8.0
# mbloss:  0.20262610912322998
# (dataset)error at epoch 1890 is 8.666666666666671
# mbloss:  0.2022646814584732
# (dataset)error at epoch 1891 is 8.0
# mbloss:  0.20206935703754425
# (dataset)error at epoch 1892 is 8.0
# mbloss:  0.20213405787944794
# (dataset)error at epoch 1893 is 8.0
# mbloss:  0.2022491842508316
# (dataset)error at epoch 1894 is 8.0
# mbloss:  0.20260600745677948
# (dataset)error at epoch 1895 is 8.0
# mbloss:  0.20298752188682556
# (dataset)error at epoch 1896 is 8.0
# mbloss:  0.20375531911849976
# (dataset)error at epoch 1897 is 8.0
# mbloss:  0.20456421375274658
# (dataset)error at epoch 1898 is 8.0
# mbloss:  0.2060699462890625
# (dataset)error at epoch 1899 is 8.0
# mbloss:  0.2076125293970108
# (dataset)error at epoch 1900 is 7.333333333333343
# mbloss:  0.2103758454322815
# (dataset)error at epoch 1901 is 8.0
# mbloss:  0.21286910772323608
# (dataset)error at epoch 1902 is 7.333333333333343
# mbloss:  0.21596412360668182
# (dataset)error at epoch 1903 is 8.0
# mbloss:  0.21939383447170258
# (dataset)error at epoch 1904 is 7.333333333333343
# mbloss:  0.22502993047237396
# (dataset)error at epoch 1905 is 8.0
# mbloss:  0.23092788457870483
# (dataset)error at epoch 1906 is 8.0
# mbloss:  0.24188806116580963
# (dataset)error at epoch 1907 is 8.0
# mbloss:  0.2555908262729645
# (dataset)error at epoch 1908 is 8.666666666666671
# mbloss:  0.2840012311935425
# (dataset)error at epoch 1909 is 18.0
# mbloss:  0.3354363441467285
# (dataset)error at epoch 1910 is 16.0
# mbloss:  0.47609588503837585
# (dataset)error at epoch 1911 is 34.66666666666667
# mbloss:  1.0507646799087524
# (dataset)error at epoch 1912 is 37.33333333333333
# mbloss:  1.2465531826019287
# (dataset)error at epoch 1913 is 43.333333333333336
# mbloss:  1.985146164894104
# (dataset)error at epoch 1914 is 24.0
# mbloss:  0.5635443925857544
# (dataset)error at epoch 1915 is 7.333333333333343
# mbloss:  0.2777508497238159
# (dataset)error at epoch 1916 is 7.333333333333343
# mbloss:  0.2290390282869339
# (dataset)error at epoch 1917 is 7.333333333333343
# mbloss:  0.21744559705257416
# (dataset)error at epoch 1918 is 7.333333333333343
# mbloss:  0.21290762722492218
# (dataset)error at epoch 1919 is 8.0
# mbloss:  0.21059194207191467
# (dataset)error at epoch 1920 is 7.333333333333343
# mbloss:  0.20890191197395325
# (dataset)error at epoch 1921 is 8.0
# mbloss:  0.20777304470539093
# (dataset)error at epoch 1922 is 8.0
# mbloss:  0.20686596632003784
# (dataset)error at epoch 1923 is 8.0
# mbloss:  0.20602233707904816
# (dataset)error at epoch 1924 is 8.0
# mbloss:  0.20503579080104828
# (dataset)error at epoch 1925 is 8.0
# mbloss:  0.2042548805475235
# (dataset)error at epoch 1926 is 8.0
# mbloss:  0.20354966819286346
# (dataset)error at epoch 1927 is 8.0
# mbloss:  0.20288851857185364
# (dataset)error at epoch 1928 is 8.0
# mbloss:  0.20226985216140747
# (dataset)error at epoch 1929 is 8.0
# mbloss:  0.20168960094451904
# (dataset)error at epoch 1930 is 8.0
# mbloss:  0.2011672407388687
# (dataset)error at epoch 1931 is 8.0
# mbloss:  0.20066961646080017
# (dataset)error at epoch 1932 is 8.0
# mbloss:  0.2002088725566864
# (dataset)error at epoch 1933 is 8.0
# mbloss:  0.19974349439144135
# (dataset)error at epoch 1934 is 8.0
# mbloss:  0.19930922985076904
# (dataset)error at epoch 1935 is 8.0
# mbloss:  0.19888830184936523
# (dataset)error at epoch 1936 is 8.0
# mbloss:  0.19847853481769562
# (dataset)error at epoch 1937 is 8.0
# mbloss:  0.1980784833431244
# (dataset)error at epoch 1938 is 8.0
# mbloss:  0.19768747687339783
# (dataset)error at epoch 1939 is 8.0
# mbloss:  0.19730910658836365
# (dataset)error at epoch 1940 is 7.333333333333343
# mbloss:  0.19691739976406097
# (dataset)error at epoch 1941 is 7.333333333333343
# mbloss:  0.19629241526126862
# (dataset)error at epoch 1942 is 7.333333333333343
# mbloss:  0.19577600061893463
# (dataset)error at epoch 1943 is 7.333333333333343
# mbloss:  0.195275217294693
# (dataset)error at epoch 1944 is 7.333333333333343
# mbloss:  0.19454364478588104
# (dataset)error at epoch 1945 is 7.333333333333343
# mbloss:  0.19392402470111847
# (dataset)error at epoch 1946 is 7.333333333333343
# mbloss:  0.1933421790599823
# (dataset)error at epoch 1947 is 7.333333333333343
# mbloss:  0.1927800327539444
# (dataset)error at epoch 1948 is 7.333333333333343
# mbloss:  0.19223864376544952
# (dataset)error at epoch 1949 is 7.333333333333343
# mbloss:  0.19170618057250977
# (dataset)error at epoch 1950 is 7.333333333333343
# mbloss:  0.19086983799934387
# (dataset)error at epoch 1951 is 7.333333333333343
# mbloss:  0.1901935487985611
# (dataset)error at epoch 1952 is 7.333333333333343
# mbloss:  0.18953226506710052
# (dataset)error at epoch 1953 is 7.333333333333343
# mbloss:  0.1884973645210266
# (dataset)error at epoch 1954 is 7.333333333333343
# mbloss:  0.18753986060619354
# (dataset)error at epoch 1955 is 7.333333333333343
# mbloss:  0.18660488724708557
# (dataset)error at epoch 1956 is 7.333333333333343
# mbloss:  0.18585175275802612
# (dataset)error at epoch 1957 is 7.333333333333343
# mbloss:  0.18512943387031555
# (dataset)error at epoch 1958 is 7.333333333333343
# mbloss:  0.1844140589237213
# (dataset)error at epoch 1959 is 7.333333333333343
# mbloss:  0.18369224667549133
# (dataset)error at epoch 1960 is 7.333333333333343
# mbloss:  0.18297527730464935
# (dataset)error at epoch 1961 is 7.333333333333343
# mbloss:  0.18227338790893555
# (dataset)error at epoch 1962 is 7.333333333333343
# mbloss:  0.18156754970550537
# (dataset)error at epoch 1963 is 7.333333333333343
# mbloss:  0.1805642992258072
# (dataset)error at epoch 1964 is 7.333333333333343
# mbloss:  0.1797235608100891
# (dataset)error at epoch 1965 is 7.333333333333343
# mbloss:  0.17895522713661194
# (dataset)error at epoch 1966 is 7.333333333333343
# mbloss:  0.1782100945711136
# (dataset)error at epoch 1967 is 7.333333333333343
# mbloss:  0.17745307087898254
# (dataset)error at epoch 1968 is 7.333333333333343
# mbloss:  0.17667241394519806
# (dataset)error at epoch 1969 is 7.333333333333343
# mbloss:  0.17586874961853027
# (dataset)error at epoch 1970 is 7.333333333333343
# mbloss:  0.17511364817619324
# (dataset)error at epoch 1971 is 7.333333333333343
# mbloss:  0.17437537014484406
# (dataset)error at epoch 1972 is 7.333333333333343
# mbloss:  0.17364539206027985
# (dataset)error at epoch 1973 is 7.333333333333343
# mbloss:  0.17292147874832153
# (dataset)error at epoch 1974 is 7.333333333333343
# mbloss:  0.1722021996974945
# (dataset)error at epoch 1975 is 7.333333333333343
# mbloss:  0.17148514091968536
# (dataset)error at epoch 1976 is 7.333333333333343
# mbloss:  0.17077472805976868
# (dataset)error at epoch 1977 is 7.333333333333343
# mbloss:  0.17006367444992065
# (dataset)error at epoch 1978 is 7.333333333333343
# mbloss:  0.16934356093406677
# (dataset)error at epoch 1979 is 7.333333333333343
# mbloss:  0.16862627863883972
# (dataset)error at epoch 1980 is 7.333333333333343
# mbloss:  0.16791127622127533
# (dataset)error at epoch 1981 is 7.333333333333343
# mbloss:  0.16718783974647522
# (dataset)error at epoch 1982 is 7.333333333333343
# mbloss:  0.16639184951782227
# (dataset)error at epoch 1983 is 7.333333333333343
# mbloss:  0.16559898853302002
# (dataset)error at epoch 1984 is 7.333333333333343
# mbloss:  0.16480879485607147
# (dataset)error at epoch 1985 is 7.333333333333343
# mbloss:  0.1640397012233734
# (dataset)error at epoch 1986 is 7.333333333333343
# mbloss:  0.16335126757621765
# (dataset)error at epoch 1987 is 7.333333333333343
# mbloss:  0.16260483860969543
# (dataset)error at epoch 1988 is 7.333333333333343
# mbloss:  0.161875918507576
# (dataset)error at epoch 1989 is 7.333333333333343
# mbloss:  0.16120676696300507
# (dataset)error at epoch 1990 is 7.333333333333343
# mbloss:  0.16046003997325897
# (dataset)error at epoch 1991 is 7.333333333333343
# mbloss:  0.15975196659564972
# (dataset)error at epoch 1992 is 7.333333333333343
# mbloss:  0.15877027809619904
# (dataset)error at epoch 1993 is 7.333333333333343
# mbloss:  0.157954141497612
# (dataset)error at epoch 1994 is 7.333333333333343
# mbloss:  0.15712663531303406
# (dataset)error at epoch 1995 is 7.333333333333343
# mbloss:  0.1563771367073059
# (dataset)error at epoch 1996 is 7.333333333333343
# mbloss:  0.1556512862443924
# (dataset)error at epoch 1997 is 7.333333333333343
# mbloss:  0.15493634343147278
# (dataset)error at epoch 1998 is 7.333333333333343
# mbloss:  0.15422756969928741
# (dataset)error at epoch 1999 is 7.333333333333343

# %% [markdown]
# plot results:

# %%
if T3:
    print('test error: ',check_testerror(vd, model_classical))
    print('train error: ',check_testerror(td, model_classical))
# Out:
# test error:  7.333333333333343
# train error:  5.777777777777786

# %%
plot_decision_boundary(model_classical, data_X, data_y)

# %%
if T3:
    plt.figure(figsize=(20,5))
    plt.plot(mblosses_classical,'o')
    plt.yscale('log')
    
    #plt.xlim((-10,3000))
    #plt.ylim((0.68,0.8))

# %%
if True:
    plt.figure(figsize=(20,5))
    l1 = len(grad_norms_classical)
    for i in range(l1):
        plt.plot(grad_norms_classical[i], label=f'0_{i}')
    plt.legend()
    plt.yscale('log')
    plt.xlabel('iterations')
    plt.ylabel('layerwise gradient norms scaled by lr')

# %%
if False:
    plt.figure(figsize=(20,5))
    plt.plot(grad_norms_classical,'o')
    plt.yscale('log')

# %%
if T3:
    plt.figure(figsize=(20,5))
    plt.plot([initial_train_acc_class]+test_error_classical,'o')
    plt.ylim(bottom=0)
    plt.grid()

# %% [markdown]
# ## Comparison of the trainings as plot:

# %%
plt.figure(figsize=(20,5))

#if T2:
#    plt.plot(np.zeros(max(len(mb_losses1),len(mb_losses2))))#,len(mblosses_classical))))
if T3:
    plt.plot(mblosses_classical, label='original net')
if T2:
    plt.plot(mb_losses2, label='abs min')
plt.plot(mb_losses1,label='abs max')

plt.yscale('log')

plt.legend()
#plt.ylim((1e-8,1.1))
#plt.xlim((80,100))
plt.show()

# %%
# li
if True:
    plt.figure(figsize=(20,5))
    l1 = len(grad_norms1[0])
    l2 = len(grad_norms1[1])
    len_t1 = len(grad_norms1[0][0])
    len_t2 = len(grad_norms1[1][0])
    for i in range(l1):
        plt.plot(grad_norms1[0][i], label=f'0_{i}')
    for j in range(l2):
        #print(list(range(len_t1,len_t2+len_t1)))
        plt.plot(list(range(len_t1,len_t2+len_t1)), grad_norms1[1][j], label=f'1_{j}')
    plt.legend()
    plt.yscale('log')
    plt.xlabel('iterations')
    plt.ylabel('layerwise gradient norms scaled by lr')

# %%
if True and T2:
    plt.figure(figsize=(20,5))
    l1 = len(grad_norms2[0])
    l2 = len(grad_norms2[1])
    len_t1 = len(grad_norms2[0][0])
    len_t2 = len(grad_norms2[1][0])
    for i in range(l1):
        plt.plot(grad_norms2[0][i], label=f'0_{i}')
    for j in range(l2):
        #print(list(range(len_t1,len_t2+len_t1)))
        plt.plot(list(range(len_t1,len_t2+len_t1)), grad_norms2[1][j], label=f'1_{j}')
    plt.legend()
    plt.yscale('log')
    plt.xlabel('iterations')
    plt.ylabel('layerwise gradient norms scaled by lr')

# %%
# classical
if True:
    plt.figure(figsize=(20,5))
    l1 = len(grad_norms_classical)
    for i in range(l1):
        plt.plot(grad_norms_classical[i], label=f'0_{i}')
    plt.legend()
    plt.yscale('log')
    plt.xlabel('iterations')
    plt.ylabel('layerwise gradient norms scaled by lr')

# %%
from utils import ema2

# %%
smooth_factor = 0.
s1= ema2(mb_losses1, smooth_factor,no_of_steps_back=1000)
if T2:
    s2= ema2(mb_losses2, smooth_factor, no_of_steps_back=1000)
if T3:
    s3 = ema2(mblosses_classical, smooth_factor, no_of_steps_back=1000)

# %%
plt.figure(figsize=(20,5))
if T2:
    plt.plot(np.zeros(max(len(s1),len(s2))))#,len(s3))))

if T2:
    plt.plot(s2, label='ali min')
plt.plot(s1,label='ali max')
if T3:
    plt.plot(s3, label='classical coarse')
plt.yscale('log')

plt.legend()
#plt.ylim((1e-8,1.1))
#plt.xlim((99800,102000))
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.plot(test_errors1,'o',label='absmax')
if T2:
    plt.plot(test_errors2,'o', label='absmin')
if T3:
    plt.plot(test_error_classical,'o',label='comparison')
plt.grid()
plt.ylim(bottom=0)
plt.legend()
